# %%
import sys
import pprint
from pathlib import Path
project_root = str(Path.cwd().parent)
if project_root not in sys.path:
 sys.path.append(project_root)
 
from pipeline.utils.general import load_json_data
from pipeline.utils.path_manager import PathManager
from evaluation.tail_posture_analysis.reporting import TailPostureReporter
from evaluation.activity_analysis.visualization import PigBehaviorVisualizer

path_manager = PathManager()

# %%
config_tail_posture_evaluation = load_json_data('config_tail_posture.json')

pprint.pprint(config_tail_posture_evaluation, compact=True)
# Out:
# {'analysis_window_days': [1, 3, 5, 7],
#  'comparison_metrics': ['value_at_removal', '1d_window_avg', '3d_window_avg',
#                         '5d_window_avg', '7d_window_avg', '1d_window_slope',
#                         '3d_window_slope', '5d_window_slope', '7d_window_slope',
#                         'abs_change_1d', 'abs_change_3d', 'abs_change_5d',
#                         'abs_change_7d'],
#  'comparison_stats_filename': 'outbreak_vs_control_comparison.csv',
#  'component_analysis_window_days': 10,
#  'component_timepoint_days': [0, 1, 3, 5, 7],
#  'confidence_level': 0.95,
#  'control_components_filename': 'control_posture_components.csv',
#  'control_date_margin': 5,
#  'control_samples_per_pen': 5,
#  'control_stats_filename': 'control_statistics.csv',
#  'days_before_list': [1, 3, 5, 7],
#  'figure_dpi': 600,
#  'max_allowed_consecutive_missing_days': 3,
#  'max_allowed_missing_days_pct': 50.0,
#  'min_control_analysis_dates': 2,
#  'min_control_dates_threshold': 8,
#  'min_outbreaks_for_variation_analysis': 3,
#  'normalize': True,
#  'outbreak_patterns_filename': 'outbreak_patterns.csv',
#  'output_dir': 'results_tail_posture_evaluation',
#  'pattern_stats_filename': 'pattern_statistics.csv',
#  'posture_components_filename': 'posture_components.csv',
#  'pre_outbreak_stats_filename': 'pre_outbreak_statistics_filtered.csv',
#  'random_seed': 42,
#  'resample_freq': 'D',
#  'significance_level': 0.05,
#  'smoothing_method': 'rolling',
#  'smoothing_strength': 3,
#  'threshold_analysis_filename': 'monitoring_threshold_analysis.json',
#  'variation_accel_quantile': 0.33,
#  'variation_erratic_slope_diff': 0.1,
#  'variation_gradual_slope_diff': 0.05,
#  'variation_max_pens_plot': 6,
#  'variation_slope_quantile': 0.33,
#  'violin_width': 0.4,
#  'viz_comparison_filename': 'outbreak_vs_control_comparison.png',
#  'viz_completeness_filename': 'data_completeness_timeline.png',
#  'viz_components_filename': 'posture_component_analysis.png',
#  'viz_pre_outbreak_filename': 'descriptive_pre_outbreak_patterns.png',
#  'viz_variation_filename': 'individual_variation_analysis.png'}

# %%
# Create an analyzer instance
analyzer = TailPostureReporter(config_tail_posture_evaluation)

# Run the complete analysis pipeline
analyzer.run_complete_analysis()
# Out:
# 2025-05-03 09:38:47,213 - tail_posture_descriptive_analysis - INFO - Saved configuration to results_tail_posture_evaluation/analysis_config.txt
# 2025-05-03 09:38:47,214 - evaluation.tail_posture_analysis.utils - INFO - Setting plot style: Font=serif, BaseSize=11pt, Format=png, DPI=600
# 2025-05-03 09:38:47,214 - tail_posture_descriptive_analysis - INFO - Dissertation quality plotting style set.
# 2025-05-03 09:38:47,215 - tail_posture_descriptive_analysis - INFO - Running DESCRIPTIVE tail posture analysis pipeline...
# 2025-05-03 09:38:47,215 - tail_posture_descriptive_analysis - INFO - Loading monitoring pipeline data...
# 2025-05-03 09:38:53,848 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera5/221004_221104: [datetime.date(2022, 11, 3)]
# 2025-05-03 09:38:55,940 - data_analysis_utils - WARNING - Missing 17 day(s) for Kamera5/220510_220529: [datetime.date(2022, 5, 10), datetime.date(2022, 5, 12), datetime.date(2022, 5, 14), datetime.date(2022, 5, 15), datetime.date(2022, 5, 16), datetime.date(2022, 5, 18), datetime.date(2022, 5, 19), datetime.date(2022, 5, 20), datetime.date(2022, 5, 21), datetime.date(2022, 5, 22), datetime.date(2022, 5, 23), datetime.date(2022, 5, 24), datetime.date(2022, 5, 25), datetime.date(2022, 5, 26), datetime.date(2022, 5, 27), datetime.date(2022, 5, 28), datetime.date(2022, 5, 29)]
# 2025-05-03 09:38:55,951 - data_analysis_utils - WARNING - Dataframe became empty after time filtering: /home/jan-hendrik/home/PigMonitoringResearch/pipeline_outputs/monitoring_pipeline/piglet_rearing/Kamera5/220510_220529/Kamera5_2022_05_11_08_18_23-09_18_23.csv. Skipping.
# 2025-05-03 09:38:55,962 - data_analysis_utils - WARNING - Dataframe became empty after time filtering: /home/jan-hendrik/home/PigMonitoringResearch/pipeline_outputs/monitoring_pipeline/piglet_rearing/Kamera5/220510_220529/Kamera5_2022_05_13_08_18_21-09_18_21.csv. Skipping.
# 2025-05-03 09:38:55,977 - data_analysis_utils - WARNING - Loaded 1 non-empty dataframes out of 3 found CSVs for Kamera5/220510_220529.
# 2025-05-03 09:38:55,978 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera5/221219_230126: [datetime.date(2023, 1, 26)]
# 2025-05-03 09:38:58,689 - data_analysis_utils - WARNING - Missing 7 day(s) for Kamera5/220228_220407: [datetime.date(2022, 4, 1), datetime.date(2022, 4, 2), datetime.date(2022, 4, 3), datetime.date(2022, 4, 4), datetime.date(2022, 4, 5), datetime.date(2022, 4, 6), datetime.date(2022, 4, 7)]
# 2025-05-03 09:39:00,680 - data_analysis_utils - WARNING - Missing 6 day(s) for Kamera5/230227_230406: [datetime.date(2023, 3, 8), datetime.date(2023, 3, 9), datetime.date(2023, 3, 10), datetime.date(2023, 3, 11), datetime.date(2023, 3, 12), datetime.date(2023, 3, 13)]
# 2025-05-03 09:39:03,036 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera1/211228_220119: [datetime.date(2022, 1, 1)]
# 2025-05-03 09:39:04,486 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera1/221003_221106: [datetime.date(2022, 11, 3)]
# 2025-05-03 09:39:16,518 - data_analysis_utils - WARNING - Missing 25 day(s) for Kamera1/220505_220530: [datetime.date(2022, 5, 5), datetime.date(2022, 5, 6), datetime.date(2022, 5, 7), datetime.date(2022, 5, 8), datetime.date(2022, 5, 9), datetime.date(2022, 5, 10), datetime.date(2022, 5, 11), datetime.date(2022, 5, 12), datetime.date(2022, 5, 13), datetime.date(2022, 5, 14), datetime.date(2022, 5, 16), datetime.date(2022, 5, 17), datetime.date(2022, 5, 18), datetime.date(2022, 5, 19), datetime.date(2022, 5, 20), datetime.date(2022, 5, 21), datetime.date(2022, 5, 22), datetime.date(2022, 5, 23), datetime.date(2022, 5, 24), datetime.date(2022, 5, 25), datetime.date(2022, 5, 26), datetime.date(2022, 5, 27), datetime.date(2022, 5, 28), datetime.date(2022, 5, 29), datetime.date(2022, 5, 30)]
# 2025-05-03 09:39:19,300 - data_analysis_utils - WARNING - Missing 2 day(s) for Kamera6/221003_221107: [datetime.date(2022, 11, 3), datetime.date(2022, 11, 7)]
# 2025-05-03 09:39:21,444 - data_analysis_utils - WARNING - Missing 6 day(s) for Kamera6/211230_220120: [datetime.date(2022, 1, 15), datetime.date(2022, 1, 16), datetime.date(2022, 1, 17), datetime.date(2022, 1, 18), datetime.date(2022, 1, 19), datetime.date(2022, 1, 20)]
# 2025-05-03 09:39:22,446 - data_analysis_utils - WARNING - Missing 5 day(s) for Kamera6/220725_220905: [datetime.date(2022, 9, 1), datetime.date(2022, 9, 2), datetime.date(2022, 9, 3), datetime.date(2022, 9, 4), datetime.date(2022, 9, 5)]
# 2025-05-03 09:39:24,906 - data_analysis_utils - WARNING - Missing 21 day(s) for Kamera6/220509_220530: [datetime.date(2022, 5, 9), datetime.date(2022, 5, 10), datetime.date(2022, 5, 12), datetime.date(2022, 5, 13), datetime.date(2022, 5, 14), datetime.date(2022, 5, 15), datetime.date(2022, 5, 16), datetime.date(2022, 5, 17), datetime.date(2022, 5, 18), datetime.date(2022, 5, 19), datetime.date(2022, 5, 20), datetime.date(2022, 5, 21), datetime.date(2022, 5, 22), datetime.date(2022, 5, 23), datetime.date(2022, 5, 24), datetime.date(2022, 5, 25), datetime.date(2022, 5, 26), datetime.date(2022, 5, 27), datetime.date(2022, 5, 28), datetime.date(2022, 5, 29), datetime.date(2022, 5, 30)]
# 2025-05-03 09:39:24,922 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera6/221219_230126: [datetime.date(2023, 1, 26)]
# 2025-05-03 09:39:27,653 - data_analysis_utils - WARNING - Missing 6 day(s) for Kamera6/220228_220407: [datetime.date(2022, 3, 31), datetime.date(2022, 4, 1), datetime.date(2022, 4, 3), datetime.date(2022, 4, 4), datetime.date(2022, 4, 6), datetime.date(2022, 4, 7)]
# 2025-05-03 09:39:29,676 - data_analysis_utils - WARNING - Missing 4 day(s) for Kamera6/230515_230622: [datetime.date(2023, 6, 18), datetime.date(2023, 6, 19), datetime.date(2023, 6, 20), datetime.date(2023, 6, 22)]
# 2025-05-03 09:39:32,305 - data_analysis_utils - WARNING - Missing 6 day(s) for Kamera6/230227_230406: [datetime.date(2023, 3, 8), datetime.date(2023, 3, 9), datetime.date(2023, 3, 10), datetime.date(2023, 3, 11), datetime.date(2023, 3, 12), datetime.date(2023, 3, 13)]
# 2025-05-03 09:39:36,104 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera2/221003_221106: [datetime.date(2022, 11, 3)]
# 2025-05-03 09:39:48,224 - data_analysis_utils - WARNING - Missing 24 day(s) for Kamera2/220505_220530: [datetime.date(2022, 5, 5), datetime.date(2022, 5, 6), datetime.date(2022, 5, 7), datetime.date(2022, 5, 8), datetime.date(2022, 5, 9), datetime.date(2022, 5, 10), datetime.date(2022, 5, 12), datetime.date(2022, 5, 13), datetime.date(2022, 5, 14), datetime.date(2022, 5, 16), datetime.date(2022, 5, 17), datetime.date(2022, 5, 18), datetime.date(2022, 5, 19), datetime.date(2022, 5, 20), datetime.date(2022, 5, 21), datetime.date(2022, 5, 22), datetime.date(2022, 5, 23), datetime.date(2022, 5, 24), datetime.date(2022, 5, 25), datetime.date(2022, 5, 26), datetime.date(2022, 5, 27), datetime.date(2022, 5, 28), datetime.date(2022, 5, 29), datetime.date(2022, 5, 30)]
# 2025-05-03 09:39:51,002 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera4/221226_230126: [datetime.date(2023, 1, 26)]
# 2025-05-03 09:39:53,283 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera4/221003_221106: [datetime.date(2022, 11, 3)]
# 2025-05-03 09:39:59,600 - data_analysis_utils - WARNING - Missing 16 day(s) for Kamera4/220725_220905: [datetime.date(2022, 8, 21), datetime.date(2022, 8, 22), datetime.date(2022, 8, 23), datetime.date(2022, 8, 24), datetime.date(2022, 8, 25), datetime.date(2022, 8, 26), datetime.date(2022, 8, 27), datetime.date(2022, 8, 28), datetime.date(2022, 8, 29), datetime.date(2022, 8, 30), datetime.date(2022, 8, 31), datetime.date(2022, 9, 1), datetime.date(2022, 9, 2), datetime.date(2022, 9, 3), datetime.date(2022, 9, 4), datetime.date(2022, 9, 5)]
# 2025-05-03 09:40:01,344 - data_analysis_utils - WARNING - Missing 18 day(s) for Kamera4/220510_220529: [datetime.date(2022, 5, 11), datetime.date(2022, 5, 12), datetime.date(2022, 5, 13), datetime.date(2022, 5, 14), datetime.date(2022, 5, 16), datetime.date(2022, 5, 17), datetime.date(2022, 5, 18), datetime.date(2022, 5, 19), datetime.date(2022, 5, 20), datetime.date(2022, 5, 21), datetime.date(2022, 5, 22), datetime.date(2022, 5, 23), datetime.date(2022, 5, 24), datetime.date(2022, 5, 25), datetime.date(2022, 5, 26), datetime.date(2022, 5, 27), datetime.date(2022, 5, 28), datetime.date(2022, 5, 29)]
# 2025-05-03 09:40:01,374 - data_analysis_utils - WARNING - Missing 7 day(s) for Kamera4/220228_220407: [datetime.date(2022, 3, 31), datetime.date(2022, 4, 1), datetime.date(2022, 4, 3), datetime.date(2022, 4, 4), datetime.date(2022, 4, 5), datetime.date(2022, 4, 6), datetime.date(2022, 4, 7)]
# 2025-05-03 09:40:08,166 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera3/221003_221106: [datetime.date(2022, 11, 3)]
# 2025-05-03 09:40:15,045 - data_analysis_utils - WARNING - Missing 5 day(s) for Kamera3/220725_220905: [datetime.date(2022, 9, 1), datetime.date(2022, 9, 2), datetime.date(2022, 9, 3), datetime.date(2022, 9, 4), datetime.date(2022, 9, 5)]
# 2025-05-03 09:40:17,528 - data_analysis_utils - WARNING - Missing 4 day(s) for Kamera3/221219_230125: [datetime.date(2023, 1, 22), datetime.date(2023, 1, 23), datetime.date(2023, 1, 24), datetime.date(2023, 1, 25)]
# 2025-05-03 09:40:19,973 - data_analysis_utils - WARNING - Missing 24 day(s) for Kamera3/220505_220529: [datetime.date(2022, 5, 5), datetime.date(2022, 5, 6), datetime.date(2022, 5, 7), datetime.date(2022, 5, 8), datetime.date(2022, 5, 9), datetime.date(2022, 5, 10), datetime.date(2022, 5, 11), datetime.date(2022, 5, 12), datetime.date(2022, 5, 13), datetime.date(2022, 5, 14), datetime.date(2022, 5, 15), datetime.date(2022, 5, 16), datetime.date(2022, 5, 18), datetime.date(2022, 5, 19), datetime.date(2022, 5, 20), datetime.date(2022, 5, 21), datetime.date(2022, 5, 22), datetime.date(2022, 5, 23), datetime.date(2022, 5, 24), datetime.date(2022, 5, 25), datetime.date(2022, 5, 26), datetime.date(2022, 5, 27), datetime.date(2022, 5, 28), datetime.date(2022, 5, 29)]
# 2025-05-03 09:40:19,990 - data_analysis_utils - WARNING - Missing 2 day(s) for Kamera3/230227_230406: [datetime.date(2023, 3, 9), datetime.date(2023, 3, 10)]
# 2025-05-03 09:40:22,580 - tail_posture_descriptive_analysis - INFO - Loaded 48 monitoring results in 95.36 seconds
# 2025-05-03 09:40:22,580 - tail_posture_descriptive_analysis - INFO - Dataset contains 6 cameras and 28 datespans.
# 2025-05-03 09:40:22,581 - tail_posture_descriptive_analysis - INFO - Total expected days across all datespans: 1623
# 2025-05-03 09:40:22,581 - tail_posture_descriptive_analysis - INFO - Total missing daily files detected: 214 (13.19%)
# 2025-05-03 09:40:22,581 - tail_posture_descriptive_analysis - INFO - Loaded 48 monitoring results entries.
# 2025-05-03 09:40:22,582 - tail_posture_descriptive_analysis - INFO - Starting preprocessing...
# 2025-05-03 09:40:22,582 - tail_posture_descriptive_analysis - INFO - Preprocessing result 1/48: Kamera1/211228_220119
# 2025-05-03 09:40:22,695 - tail_posture_descriptive_analysis - INFO - Preprocessing result 2/48: Kamera1/220228_220328
# 2025-05-03 09:40:22,830 - tail_posture_descriptive_analysis - INFO - Preprocessing result 3/48: Kamera1/220505_220530
# 2025-05-03 09:40:22,910 - tail_posture_descriptive_analysis - WARNING - Dataset too small for smoothing (length 1). Skipping smoothing.
# 2025-05-03 09:40:22,912 - tail_posture_descriptive_analysis - WARNING - Not enough non-NaN data points (1) for interpolation on Kamera1 - 220505_220530. Skipping.
# 2025-05-03 09:40:22,913 - tail_posture_descriptive_analysis - INFO - Preprocessing result 4/48: Kamera1/220726_220831
# 2025-05-03 09:40:23,079 - tail_posture_descriptive_analysis - INFO - Preprocessing result 5/48: Kamera1/221003_221106
# 2025-05-03 09:40:23,231 - tail_posture_descriptive_analysis - INFO - Preprocessing result 6/48: Kamera1/221219_230125
# 2025-05-03 09:40:23,401 - tail_posture_descriptive_analysis - INFO - Preprocessing result 7/48: Kamera1/230227_230406
# 2025-05-03 09:40:23,575 - tail_posture_descriptive_analysis - INFO - Preprocessing result 8/48: Kamera1/230515_230620
# 2025-05-03 09:40:23,738 - tail_posture_descriptive_analysis - INFO - Preprocessing result 9/48: Kamera2/211227_220119
# 2025-05-03 09:40:23,845 - tail_posture_descriptive_analysis - INFO - Preprocessing result 10/48: Kamera2/220228_220331
# 2025-05-03 09:40:23,982 - tail_posture_descriptive_analysis - INFO - Preprocessing result 11/48: Kamera2/220505_220530
# 2025-05-03 09:40:23,995 - tail_posture_descriptive_analysis - WARNING - Dataset too small for smoothing (length 2). Skipping smoothing.
# 2025-05-03 09:40:24,002 - tail_posture_descriptive_analysis - INFO - Preprocessing result 12/48: Kamera2/220725_220831
# 2025-05-03 09:40:24,169 - tail_posture_descriptive_analysis - INFO - Preprocessing result 13/48: Kamera2/221003_221106
# 2025-05-03 09:40:24,308 - tail_posture_descriptive_analysis - INFO - Preprocessing result 14/48: Kamera2/221219_230125
# 2025-05-03 09:40:24,476 - tail_posture_descriptive_analysis - INFO - Preprocessing result 15/48: Kamera2/230227_230405
# 2025-05-03 09:40:24,855 - tail_posture_descriptive_analysis - INFO - Preprocessing result 16/48: Kamera2/230515_230621
# 2025-05-03 09:40:25,006 - tail_posture_descriptive_analysis - INFO - Preprocessing result 17/48: Kamera3/211222_220119
# 2025-05-03 09:40:25,132 - tail_posture_descriptive_analysis - INFO - Preprocessing result 18/48: Kamera3/220228_220330
# 2025-05-03 09:40:25,265 - tail_posture_descriptive_analysis - INFO - Preprocessing result 19/48: Kamera3/220505_220529
# 2025-05-03 09:40:25,276 - tail_posture_descriptive_analysis - WARNING - Dataset too small for smoothing (length 1). Skipping smoothing.
# 2025-05-03 09:40:25,279 - tail_posture_descriptive_analysis - WARNING - Not enough non-NaN data points (1) for interpolation on Kamera3 - 220505_220529. Skipping.
# 2025-05-03 09:40:25,279 - tail_posture_descriptive_analysis - INFO - Preprocessing result 20/48: Kamera3/220725_220905
# 2025-05-03 09:40:25,441 - tail_posture_descriptive_analysis - INFO - Preprocessing result 21/48: Kamera3/221003_221106
# 2025-05-03 09:40:25,584 - tail_posture_descriptive_analysis - INFO - Preprocessing result 22/48: Kamera3/221219_230125
# 2025-05-03 09:40:25,730 - tail_posture_descriptive_analysis - INFO - Preprocessing result 23/48: Kamera3/230227_230406
# 2025-05-03 09:40:25,890 - tail_posture_descriptive_analysis - INFO - Preprocessing result 24/48: Kamera3/230515_230621
# 2025-05-03 09:40:26,058 - tail_posture_descriptive_analysis - INFO - Preprocessing result 25/48: Kamera4/211229_220119
# 2025-05-03 09:40:26,158 - tail_posture_descriptive_analysis - INFO - Preprocessing result 26/48: Kamera4/220228_220407
# 2025-05-03 09:40:26,294 - tail_posture_descriptive_analysis - INFO - Preprocessing result 27/48: Kamera4/220510_220529
# 2025-05-03 09:40:26,377 - tail_posture_descriptive_analysis - WARNING - Dataset too small for smoothing (length 2). Skipping smoothing.
# 2025-05-03 09:40:26,384 - tail_posture_descriptive_analysis - INFO - Preprocessing result 28/48: Kamera4/220725_220905
# 2025-05-03 09:40:26,501 - tail_posture_descriptive_analysis - INFO - Preprocessing result 29/48: Kamera4/221003_221106
# 2025-05-03 09:40:26,646 - tail_posture_descriptive_analysis - INFO - Preprocessing result 30/48: Kamera4/221226_230126
# 2025-05-03 09:40:26,781 - tail_posture_descriptive_analysis - INFO - Preprocessing result 31/48: Kamera4/230227_230406
# 2025-05-03 09:40:26,956 - tail_posture_descriptive_analysis - INFO - Preprocessing result 32/48: Kamera4/230515_230621
# 2025-05-03 09:40:27,116 - tail_posture_descriptive_analysis - INFO - Preprocessing result 33/48: Kamera5/211231_220119
# 2025-05-03 09:40:27,204 - tail_posture_descriptive_analysis - INFO - Preprocessing result 34/48: Kamera5/220228_220407
# 2025-05-03 09:40:27,349 - tail_posture_descriptive_analysis - INFO - Preprocessing result 35/48: Kamera5/220510_220529
# 2025-05-03 09:40:27,360 - tail_posture_descriptive_analysis - WARNING - Dataset too small for smoothing (length 1). Skipping smoothing.
# 2025-05-03 09:40:27,363 - tail_posture_descriptive_analysis - WARNING - Not enough non-NaN data points (1) for interpolation on Kamera5 - 220510_220529. Skipping.
# 2025-05-03 09:40:27,363 - tail_posture_descriptive_analysis - INFO - Preprocessing result 36/48: Kamera5/220725_220831
# 2025-05-03 09:40:27,530 - tail_posture_descriptive_analysis - INFO - Preprocessing result 37/48: Kamera5/221004_221104
# 2025-05-03 09:40:27,667 - tail_posture_descriptive_analysis - INFO - Preprocessing result 38/48: Kamera5/221219_230126
# 2025-05-03 09:40:27,828 - tail_posture_descriptive_analysis - INFO - Preprocessing result 39/48: Kamera5/230227_230406
# 2025-05-03 09:40:27,970 - tail_posture_descriptive_analysis - INFO - Preprocessing result 40/48: Kamera5/230515_230621
# 2025-05-03 09:40:28,201 - tail_posture_descriptive_analysis - INFO - Preprocessing result 41/48: Kamera6/211230_220120
# 2025-05-03 09:40:28,275 - tail_posture_descriptive_analysis - INFO - Preprocessing result 42/48: Kamera6/220228_220407
# 2025-05-03 09:40:28,414 - tail_posture_descriptive_analysis - INFO - Preprocessing result 43/48: Kamera6/220509_220530
# 2025-05-03 09:40:28,425 - tail_posture_descriptive_analysis - WARNING - Dataset too small for smoothing (length 1). Skipping smoothing.
# 2025-05-03 09:40:28,427 - tail_posture_descriptive_analysis - WARNING - Not enough non-NaN data points (1) for interpolation on Kamera6 - 220509_220530. Skipping.
# 2025-05-03 09:40:28,428 - tail_posture_descriptive_analysis - INFO - Preprocessing result 44/48: Kamera6/220725_220905
# 2025-05-03 09:40:28,587 - tail_posture_descriptive_analysis - INFO - Preprocessing result 45/48: Kamera6/221003_221107
# 2025-05-03 09:40:28,730 - tail_posture_descriptive_analysis - INFO - Preprocessing result 46/48: Kamera6/221219_230126
# 2025-05-03 09:40:28,890 - tail_posture_descriptive_analysis - INFO - Preprocessing result 47/48: Kamera6/230227_230406
# 2025-05-03 09:40:29,032 - tail_posture_descriptive_analysis - INFO - Preprocessing result 48/48: Kamera6/230515_230622
# 2025-05-03 09:40:29,182 - tail_posture_descriptive_analysis - INFO - Preprocessing finished in 6.60 seconds.
# 2025-05-03 09:40:29,183 - tail_posture_descriptive_analysis - INFO - Total processed results after preprocessing: 48
# 2025-05-03 09:40:29,183 - tail_posture_descriptive_analysis - INFO - Analyzing pre-outbreak statistics (using earliest removal date per event)...
# 2025-05-03 09:40:29,184 - tail_posture_descriptive_analysis - INFO - Excluding Kamera1/211228_220119: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:40:29,191 - tail_posture_descriptive_analysis - INFO - Excluding Kamera1/220505_220530 from analysis due to excessive missing days (25/26 = 96.2% > 50.0%)
# 2025-05-03 09:40:29,191 - tail_posture_descriptive_analysis - INFO - Excluding Kamera1/220726_220831: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:40:29,214 - tail_posture_descriptive_analysis - INFO - Excluding Kamera2/211227_220119: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:40:29,215 - tail_posture_descriptive_analysis - INFO - Removal date 2022-04-06 is after last data point for Pen 2. Using last available data point.
# 2025-05-03 09:40:29,221 - tail_posture_descriptive_analysis - INFO - Excluding Kamera2/220505_220530 from analysis due to excessive missing days (24/26 = 92.3% > 50.0%)
# 2025-05-03 09:40:29,221 - tail_posture_descriptive_analysis - INFO - Excluding Kamera2/220725_220831: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:40:29,221 - tail_posture_descriptive_analysis - INFO - Removal date 2022-11-07 is after last data point for Pen 2. Using last available data point.
# 2025-05-03 09:40:29,227 - tail_posture_descriptive_analysis - INFO - Excluding Kamera2/221219_230125: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:40:29,228 - tail_posture_descriptive_analysis - INFO - Excluding Kamera2/230227_230405: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:40:29,234 - tail_posture_descriptive_analysis - INFO - Excluding Kamera3/211222_220119: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:40:29,240 - tail_posture_descriptive_analysis - INFO - Excluding Kamera3/220505_220529 from analysis due to excessive missing days (24/25 = 96.0% > 50.0%)
# 2025-05-03 09:40:29,240 - tail_posture_descriptive_analysis - INFO - Excluding Kamera3/220725_220905: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:40:29,246 - tail_posture_descriptive_analysis - INFO - Excluding Kamera3/221219_230125: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:40:29,247 - tail_posture_descriptive_analysis - INFO - Excluding Kamera3/230227_230406: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:40:29,253 - tail_posture_descriptive_analysis - INFO - Excluding Kamera4/211229_220119: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:40:29,253 - tail_posture_descriptive_analysis - INFO - Excluding Kamera4/220228_220407: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:40:29,254 - tail_posture_descriptive_analysis - INFO - Excluding Kamera4/220510_220529 from analysis due to 4 consecutive missing periods in resampled data (threshold: 3). Raw missing days: 18
# 2025-05-03 09:40:29,254 - tail_posture_descriptive_analysis - INFO - Excluding Kamera4/220725_220905: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:40:29,255 - tail_posture_descriptive_analysis - INFO - Removal date 2022-11-07 is after last data point for Pen 4. Using last available data point.
# 2025-05-03 09:40:29,277 - tail_posture_descriptive_analysis - INFO - Excluding Kamera5/211231_220119: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:40:29,278 - tail_posture_descriptive_analysis - INFO - Excluding Kamera5/220228_220407: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:40:29,278 - tail_posture_descriptive_analysis - INFO - Excluding Kamera5/220510_220529 from analysis due to excessive missing days (17/20 = 85.0% > 50.0%)
# 2025-05-03 09:40:29,290 - tail_posture_descriptive_analysis - INFO - Excluding Kamera5/221219_230126: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:40:29,290 - tail_posture_descriptive_analysis - INFO - Excluding Kamera5/230227_230406 from analysis due to 6 consecutive missing periods in resampled data (threshold: 3). Raw missing days: 6
# 2025-05-03 09:40:29,296 - tail_posture_descriptive_analysis - INFO - Excluding Kamera6/211230_220120: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:40:29,297 - tail_posture_descriptive_analysis - INFO - Excluding Kamera6/220228_220407: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:40:29,297 - tail_posture_descriptive_analysis - INFO - Excluding Kamera6/220509_220530 from analysis due to excessive missing days (21/22 = 95.5% > 50.0%)
# 2025-05-03 09:40:29,297 - tail_posture_descriptive_analysis - INFO - Excluding Kamera6/220725_220905: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:40:29,304 - tail_posture_descriptive_analysis - INFO - Excluding Kamera6/221219_230126: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:40:29,304 - tail_posture_descriptive_analysis - INFO - Excluding Kamera6/230227_230406 from analysis due to 6 consecutive missing periods in resampled data (threshold: 3). Raw missing days: 6
# 2025-05-03 09:40:29,311 - tail_posture_descriptive_analysis - INFO - Attempted to analyze 22 potential tail biting events.
# 2025-05-03 09:40:29,312 - tail_posture_descriptive_analysis - INFO - Successfully analyzed 20 events.
# 2025-05-03 09:40:29,312 - tail_posture_descriptive_analysis - INFO - Excluded 3 events due to >3 consecutive missing days.
# 2025-05-03 09:40:29,312 - tail_posture_descriptive_analysis - INFO - Excluded 5 events due to excessive missing days (>50.0%).
# 2025-05-03 09:40:29,313 - tail_posture_descriptive_analysis - INFO - Excluded -6 events for other reasons (e.g., no valid removal date, empty data).
# 2025-05-03 09:40:29,322 - tail_posture_descriptive_analysis - INFO - Saved descriptive pre-outbreak statistics to results_tail_posture_evaluation/pre_outbreak_statistics_filtered.csv
# 2025-05-03 09:40:29,322 - tail_posture_descriptive_analysis - INFO - Completed pre-outbreak statistics calculation.
# 2025-05-03 09:40:29,323 - tail_posture_descriptive_analysis - INFO - Excluded 3 outbreak events based on missing data/validity checks.
# 2025-05-03 09:40:29,323 - tail_posture_descriptive_analysis - INFO - Analyzing control pen statistics for comparison...
# 2025-05-03 09:40:29,324 - tail_posture_descriptive_analysis - INFO - Found 26 control pen datasets for analysis
# 2025-05-03 09:40:29,350 - tail_posture_descriptive_analysis - INFO - Excluding control pen Kamera1/220505_220530 due to excessive missing days (25/26 = 96.2% > 50.0%)
# 2025-05-03 09:40:29,398 - tail_posture_descriptive_analysis - INFO - Excluding control pen Kamera2/220505_220530 due to excessive missing days (24/26 = 92.3% > 50.0%)
# 2025-05-03 09:40:29,494 - tail_posture_descriptive_analysis - INFO - Excluding control pen Kamera3/220505_220529 due to excessive missing days (24/25 = 96.0% > 50.0%)
# 2025-05-03 09:40:29,682 - tail_posture_descriptive_analysis - INFO - Excluding control pen Kamera5/220510_220529 due to excessive missing days (17/20 = 85.0% > 50.0%)
# 2025-05-03 09:40:29,706 - tail_posture_descriptive_analysis - INFO - Excluding control pen Kamera5/230227_230406 due to 6 consecutive missing periods in resampled data (threshold: 3). Raw missing days: 6
# 2025-05-03 09:40:29,753 - tail_posture_descriptive_analysis - INFO - Excluding control pen Kamera6/220509_220530 due to excessive missing days (21/22 = 95.5% > 50.0%)
# 2025-05-03 09:40:29,803 - tail_posture_descriptive_analysis - INFO - Analyzed 26 control pens.
# 2025-05-03 09:40:29,803 - tail_posture_descriptive_analysis - INFO - Successfully analyzed 20 control pen datasets (from 6 unique pens) with 100 reference points.
# 2025-05-03 09:40:29,804 - tail_posture_descriptive_analysis - INFO - Excluded 1 control pens due to >3 consecutive missing days.
# 2025-05-03 09:40:29,804 - tail_posture_descriptive_analysis - INFO - Excluded 5 control pens due to excessive missing days (>50.0%).
# 2025-05-03 09:40:29,809 - tail_posture_descriptive_analysis - INFO - Saved control pen statistics to results_tail_posture_evaluation/control_statistics.csv
# 2025-05-03 09:40:29,810 - tail_posture_descriptive_analysis - INFO - Completed control pen statistics calculation.
# 2025-05-03 09:40:29,810 - tail_posture_descriptive_analysis - INFO - Analyzing individual variation in outbreak patterns...
# 2025-05-03 09:40:29,814 - tail_posture_descriptive_analysis - INFO - Pattern categorization counts: {'Gradual-decline': 7, 'Sudden-decline': 5, 'Moderate-decline': 5, 'Erratic-decline': 3}
# 2025-05-03 09:40:29,815 - tail_posture_descriptive_analysis - INFO - Pen consistency (excluding 'Undefined'): 0/6 pens (0.0%) have consistent pattern categories.
# 2025-05-03 09:40:29,819 - tail_posture_descriptive_analysis - INFO - Successfully calculated pattern statistics.
# 2025-05-03 09:40:29,820 - tail_posture_descriptive_analysis - INFO - Saved outbreak pattern analysis to results_tail_posture_evaluation/outbreak_patterns.csv
# 2025-05-03 09:40:29,821 - tail_posture_descriptive_analysis - INFO - Saved pattern statistics to results_tail_posture_evaluation/pattern_statistics.csv
# 2025-05-03 09:40:29,822 - tail_posture_descriptive_analysis - INFO - Completed individual outbreak pattern analysis.
# 2025-05-03 09:40:29,822 - tail_posture_descriptive_analysis - INFO - Analyzing individual posture components (upright vs. hanging tails)...
# 2025-05-03 09:40:30,084 - tail_posture_descriptive_analysis - INFO - Saved posture component data to results_tail_posture_evaluation/posture_components.csv
# 2025-05-03 09:40:30,092 - tail_posture_descriptive_analysis - INFO - Saved control posture component data to results_tail_posture_evaluation/control_posture_components.csv
# 2025-05-03 09:40:30,092 - tail_posture_descriptive_analysis - INFO - Completed posture component analysis (upright vs. hanging tails).
# 2025-05-03 09:40:30,093 - tail_posture_descriptive_analysis - ERROR - Error during analyze_and_identify_monitoring_thresholds: 'TailPostureReporter' object has no attribute 'analyze_and_identify_monitoring_thresholds'
# Traceback (most recent call last):
#   File "/home/jan-hendrik/home/PigMonitoringResearch/evaluation/tail_posture_analysis/reporting.py", line 1474, in run_complete_analysis
#     threshold_analysis = self.analyze_and_identify_monitoring_thresholds()
# AttributeError: 'TailPostureReporter' object has no attribute 'analyze_and_identify_monitoring_thresholds'
# 2025-05-03 09:40:30,094 - tail_posture_descriptive_analysis - ERROR - No validation results available. Run validate_monitoring_thresholds() first.
# 2025-05-03 09:40:30,094 - tail_posture_descriptive_analysis - INFO - Visualizing data completeness across all events (enhanced version with exclusions)...
# 2025-05-03 09:40:30,094 - evaluation.tail_posture_analysis.utils - INFO - Setting plot style: Font=serif, BaseSize=11pt, Format=png, DPI=600
# 2025-05-03 09:40:30,100 - tail_posture_descriptive_analysis - INFO - Marked for consecutive exclusion: Kamera4/220510_220529 (pen 4)
# 2025-05-03 09:40:30,100 - tail_posture_descriptive_analysis - INFO - Marked for consecutive exclusion: Kamera5/230227_230406 (pen 5)
# 2025-05-03 09:40:30,100 - tail_posture_descriptive_analysis - INFO - Marked for consecutive exclusion: Kamera6/230227_230406 (pen 6)
# 2025-05-03 09:40:30,101 - tail_posture_descriptive_analysis - INFO - Marked for consecutive exclusion: Kamera5/230227_230406 (pen 5)
# 2025-05-03 09:40:30,101 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion: Kamera1/220505_220530 (pen 1)
# 2025-05-03 09:40:30,101 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion: Kamera2/220505_220530 (pen 2)
# 2025-05-03 09:40:30,102 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion: Kamera3/220505_220529 (pen 3)
# 2025-05-03 09:40:30,102 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion: Kamera5/220510_220529 (pen 5)
# 2025-05-03 09:40:30,102 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion: Kamera6/220509_220530 (pen 6)
# 2025-05-03 09:40:30,103 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion: Kamera1/220505_220530 (pen 1)
# 2025-05-03 09:40:30,103 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion: Kamera2/220505_220530 (pen 2)
# 2025-05-03 09:40:30,103 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion: Kamera3/220505_220529 (pen 3)
# 2025-05-03 09:40:30,103 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion: Kamera5/220510_220529 (pen 5)
# 2025-05-03 09:40:30,104 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion: Kamera6/220509_220530 (pen 6)
# 2025-05-03 09:40:30,104 - tail_posture_descriptive_analysis - INFO - Marked for consecutive exclusion from tail_biting_analysis: Kamera4/220510_220529 (pen 4)
# 2025-05-03 09:40:30,104 - tail_posture_descriptive_analysis - INFO - Marked for consecutive exclusion from tail_biting_analysis: Kamera5/230227_230406 (pen 5)
# 2025-05-03 09:40:30,105 - tail_posture_descriptive_analysis - INFO - Marked for consecutive exclusion from tail_biting_analysis: Kamera6/230227_230406 (pen 6)
# 2025-05-03 09:40:30,105 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion from tail_biting_analysis: Kamera1/220505_220530 (pen 1)
# 2025-05-03 09:40:30,105 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion from tail_biting_analysis: Kamera2/220505_220530 (pen 2)
# 2025-05-03 09:40:30,105 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion from tail_biting_analysis: Kamera3/220505_220529 (pen 3)
# 2025-05-03 09:40:30,106 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion from tail_biting_analysis: Kamera5/220510_220529 (pen 5)
# 2025-05-03 09:40:30,106 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion from tail_biting_analysis: Kamera6/220509_220530 (pen 6)
# 2025-05-03 09:40:30,106 - tail_posture_descriptive_analysis - INFO - Marked for consecutive exclusion from control_analysis: Kamera5/230227_230406 (pen 5)
# 2025-05-03 09:40:30,107 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion from control_analysis: Kamera1/220505_220530 (pen 1)
# 2025-05-03 09:40:30,107 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion from control_analysis: Kamera2/220505_220530 (pen 2)
# 2025-05-03 09:40:30,107 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion from control_analysis: Kamera3/220505_220529 (pen 3)
# 2025-05-03 09:40:30,107 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion from control_analysis: Kamera5/220510_220529 (pen 5)
# 2025-05-03 09:40:30,108 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion from control_analysis: Kamera6/220509_220530 (pen 6)
# 2025-05-03 09:40:30,163 - tail_posture_descriptive_analysis - INFO - Highlighting consecutive exclusion: Kamera4/220510_220529
# 2025-05-03 09:40:30,177 - tail_posture_descriptive_analysis - INFO - Highlighting consecutive exclusion: Kamera6/230227_230406
# 2025-05-03 09:40:30,191 - tail_posture_descriptive_analysis - INFO - Highlighting percentage exclusion: Kamera1/220505_220530
# 2025-05-03 09:40:30,193 - tail_posture_descriptive_analysis - INFO - Highlighting percentage exclusion: Kamera2/220505_220530
# 2025-05-03 09:40:30,196 - tail_posture_descriptive_analysis - INFO - Highlighting percentage exclusion: Kamera3/220505_220529
# 2025-05-03 09:40:30,198 - tail_posture_descriptive_analysis - INFO - Highlighting percentage exclusion: Kamera6/220509_220530
# 2025-05-03 09:40:30,200 - tail_posture_descriptive_analysis - INFO - Highlighting percentage exclusion: Kamera5/220510_220529
# 2025-05-03 09:40:30,210 - tail_posture_descriptive_analysis - INFO - Highlighting consecutive exclusion: Kamera5/230227_230406
# 2025-05-03 09:40:31,735 - tail_posture_descriptive_analysis - INFO - Saved enhanced data completeness visualization with exclusion highlighting to results_tail_posture_evaluation/data_completeness_timeline.png
# 2025-05-03 09:40:31,736 - tail_posture_descriptive_analysis - INFO - Created data completeness visualization: results_tail_posture_evaluation/data_completeness_timeline.png
# 2025-05-03 09:40:31,737 - tail_posture_descriptive_analysis - INFO - Visualizing descriptive pre-outbreak patterns...
# 2025-05-03 09:40:31,737 - evaluation.tail_posture_analysis.utils - INFO - Setting plot style: Font=serif, BaseSize=11pt, Format=png, DPI=600
# /home/jan-hendrik/home/PigMonitoringResearch/evaluation/tail_posture_analysis/visualization.py:371: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7fa6952090d0> has a label of '_child21' which cannot be automatically added to the legend.
#   ax2.legend(handles=legend_handles_traj, loc='lower left', frameon=True, facecolor='white', edgecolor=COLORS.get('grid', 'lightgrey'), fontsize=9)
# 2025-05-03 09:40:33,713 - tail_posture_descriptive_analysis - INFO - Saved pre-outbreak pattern visualization to results_tail_posture_evaluation/descriptive_pre_outbreak_patterns.png
# 2025-05-03 09:40:33,714 - tail_posture_descriptive_analysis - INFO - Created descriptive pre-outbreak patterns visualization: results_tail_posture_evaluation/descriptive_pre_outbreak_patterns.png
# 2025-05-03 09:40:33,714 - tail_posture_descriptive_analysis - INFO - Visualizing comparison between outbreak and control pens...
# 2025-05-03 09:40:33,715 - evaluation.tail_posture_analysis.utils - INFO - Setting plot style: Font=serif, BaseSize=11pt, Format=png, DPI=600
# 2025-05-03 09:40:33,827 - tail_posture_descriptive_analysis - INFO - Comparing outbreak vs control pen statistics...
# 2025-05-03 09:40:33,829 - tail_posture_descriptive_analysis - INFO - Comparison for value_at_removal: Outbreak=-0.036±0.367, Control=0.714±0.124, p=0.0000, Significant=True, Effect Size=4.04
# 2025-05-03 09:40:33,830 - tail_posture_descriptive_analysis - INFO - Comparison for 1d_window_avg: Outbreak=0.022±0.367, Control=0.716±0.121, p=0.0000, Significant=True, Effect Size=3.77
# 2025-05-03 09:40:33,832 - tail_posture_descriptive_analysis - INFO - Comparison for 3d_window_avg: Outbreak=0.162±0.364, Control=0.717±0.118, p=0.0000, Significant=True, Effect Size=3.05
# 2025-05-03 09:40:33,833 - tail_posture_descriptive_analysis - INFO - Comparison for 5d_window_avg: Outbreak=0.288±0.343, Control=0.714±0.117, p=0.0000, Significant=True, Effect Size=2.45
# 2025-05-03 09:40:33,834 - tail_posture_descriptive_analysis - INFO - Comparison for 7d_window_avg: Outbreak=0.383±0.297, Control=0.711±0.117, p=0.0000, Significant=True, Effect Size=2.05
# 2025-05-03 09:40:33,835 - tail_posture_descriptive_analysis - INFO - Comparison for 1d_window_slope: Outbreak=-0.122±0.124, Control=-0.005±0.037, p=0.0001, Significant=True, Effect Size=1.93
# 2025-05-03 09:40:33,836 - tail_posture_descriptive_analysis - INFO - Comparison for 3d_window_slope: Outbreak=-0.140±0.118, Control=-0.001±0.028, p=0.0000, Significant=True, Effect Size=2.61
# 2025-05-03 09:40:33,838 - tail_posture_descriptive_analysis - INFO - Comparison for 5d_window_slope: Outbreak=-0.127±0.089, Control=0.003±0.023, p=0.0000, Significant=True, Effect Size=3.12
# 2025-05-03 09:40:33,839 - tail_posture_descriptive_analysis - INFO - Comparison for 7d_window_slope: Outbreak=-0.106±0.062, Control=0.003±0.020, p=0.0000, Significant=True, Effect Size=3.54
# 2025-05-03 09:40:33,840 - tail_posture_descriptive_analysis - INFO - Comparison for abs_change_1d: Outbreak=-0.122±0.124, Control=-0.005±0.037, p=0.0001, Significant=True, Effect Size=1.93
# 2025-05-03 09:40:33,842 - tail_posture_descriptive_analysis - INFO - Comparison for abs_change_3d: Outbreak=-0.408±0.340, Control=-0.003±0.083, p=0.0000, Significant=True, Effect Size=2.60
# 2025-05-03 09:40:33,843 - tail_posture_descriptive_analysis - INFO - Comparison for abs_change_5d: Outbreak=-0.598±0.367, Control=0.010±0.111, p=0.0000, Significant=True, Effect Size=3.40
# 2025-05-03 09:40:33,844 - tail_posture_descriptive_analysis - INFO - Comparison for abs_change_7d: Outbreak=-0.713±0.355, Control=0.007±0.129, p=0.0000, Significant=True, Effect Size=3.77
# 2025-05-03 09:40:33,845 - tail_posture_descriptive_analysis - INFO - Saved outbreak vs control comparison to results_tail_posture_evaluation/outbreak_vs_control_comparison.csv
# 2025-05-03 09:40:35,692 - tail_posture_descriptive_analysis - INFO - Saved outbreak vs control comparison visualization to results_tail_posture_evaluation/outbreak_vs_control_comparison.png
# 2025-05-03 09:40:35,693 - tail_posture_descriptive_analysis - INFO - Created outbreak vs control comparison visualization: results_tail_posture_evaluation/outbreak_vs_control_comparison.png
# 2025-05-03 09:40:35,693 - tail_posture_descriptive_analysis - WARNING - Skipping control comparison visualization and table generation due to missing outbreak or control statistics.
# 2025-05-03 09:40:35,694 - tail_posture_descriptive_analysis - INFO - Visualizing individual variation in outbreak patterns...
# 2025-05-03 09:40:35,694 - evaluation.tail_posture_analysis.utils - INFO - Setting plot style: Font=serif, BaseSize=11pt, Format=png, DPI=600
# 2025-05-03 09:40:37,414 - tail_posture_descriptive_analysis - INFO - Saved individual variation visualization to results_tail_posture_evaluation/individual_variation_analysis.png
# 2025-05-03 09:40:37,415 - tail_posture_descriptive_analysis - INFO - Created individual variation visualization: results_tail_posture_evaluation/individual_variation_analysis.png
# 2025-05-03 09:40:37,415 - tail_posture_descriptive_analysis - INFO - Visualizing posture components (upright vs. hanging tails)...
# 2025-05-03 09:40:37,415 - evaluation.tail_posture_analysis.utils - INFO - Setting plot style: Font=serif, BaseSize=11pt, Format=png, DPI=600
# 2025-05-03 09:40:38,772 - tail_posture_descriptive_analysis - INFO - Saved posture component visualization to results_tail_posture_evaluation/posture_component_analysis.png
# 2025-05-03 09:40:38,773 - tail_posture_descriptive_analysis - INFO - Created posture component visualization: results_tail_posture_evaluation/posture_component_analysis.png
# 2025-05-03 09:40:38,773 - tail_posture_descriptive_analysis - INFO - Generating descriptive summary report...
# 2025-05-03 09:40:38,828 - tail_posture_descriptive_analysis - INFO - Saved summary report to results_tail_posture_evaluation/analysis_summary_report.txt
# 2025-05-03 09:40:38,829 - tail_posture_descriptive_analysis - INFO - Generated descriptive summary report.
# 2025-05-03 09:40:38,829 - tail_posture_descriptive_analysis - INFO - Descriptive analysis pipeline finished.
# {'dataset': {'num_cameras': 6,
#   'num_datespans_loaded': 48,
#   'relative_removal_positions': {'first_quintile': 0,
#    'second_quintile': 1,
#    'third_quintile': 4,
#    'fourth_quintile': 7,
#    'fifth_quintile': 20},
#   'removal_position_stats': {'avg_position_pct': 84.96483152714428,
#    'median_position_pct': 85.29411764705881,
#    'min_position_pct': 35.13513513513514,
#    'max_position_pct': 168.42105263157893},
#   'removal_date_range': {'first': datetime.date(2022, 3, 23),
#    'last': datetime.date(2023, 6, 19),
#    'span_days': 453},
#   'removal_dates_quarterly': {'2022Q1': 3,
#    '2022Q2': 3,
#    '2022Q3': 1,
#    '2022Q4': 9,
#    '2023Q1': 5,
#    '2023Q2': 11},
#   'removals_per_pen': {'min': 1,
#    'max': 4,
#    'avg': 1.4545454545454546,
#    'total_removals': 32,
#    'pens_with_multiple': 8},
#   'datespan_coverage': {'avg_pct': 85.41666666666669,
#    'min_pct': 51.28205128205128,
#    'max_pct': 100.0,
#    'full_coverage_count': 14},
#   'date_range': {'min': datetime.date(2021, 12, 22),
#    'max': datetime.date(2023, 6, 22),
#    'span_days': 547},
#   'reference_date_range': {'min': datetime.date(2021, 12, 13),
#    'max': datetime.date(2023, 6, 22),
#    'span_days': 556},
#   'pen_types_loaded': {'control': 26, 'tail biting': 22},
#   'total_tb_pens': 22,
#   'total_control_pens': 26},
#  'data_quality': {'total_processed_events': 48,
#   'total_expected_days': 1623,
#   'total_missing_days_files': 214,
#   'overall_missing_days_pct': 13.185459026494147,
#   'total_gt_expected_days': 1872,
#   'total_gt_available_days': 1623,
#   'total_gt_missing_days': 273,
#   'overall_gt_missing_days_pct': 14.583333333333334,
#   'incomplete_camera_datespans': 34,
#   'incomplete_camera_datespans_pct': 70.83333333333334,
#   'missing_days_within_datespan': 214,
#   'missing_days_within_datespan_pct': 13.185459026494147,
#   'avg_missing_days_per_datespan': 4.458333333333333,
#   'min_missing_days_per_datespan': 0,
#   'max_missing_days_per_datespan': 25,
#   'median_missing_days_per_datespan': 1.0,
#   'avg_missing_raw_seconds_pct': 1.3888888888888886,
#   'avg_missing_resampled_periods_pct': 2.3373332459609633,
#   'avg_max_consecutive_missing_resampled': 0.7291666666666666,
#   'events_excluded_for_consecutive_missing': 3,
#   'events_excluded_for_missing_pct': 5,
#   'total_events_excluded_for_missing_data': 8,
#   'missing_data_exclusion_threshold_days': 3,
#   'missing_data_exclusion_threshold_pct': 50.0,
#   'interpolation_method': 'linear'},
#  'outbreak_analysis': {'num_outbreaks_analyzed': 20,
#   'num_pens_analyzed': 6,
#   'value_at_removal': {'count': 20,
#    'mean': -0.03606547010599507,
#    'median': -0.1096846213820207,
#    'std': 0.36664325427308275,
#    'p25': -0.31972834633497776,
#    'p10': -0.4034071822687822},
#   'value_1d_before': {'mean': 0.08544727640479541,
#    'median': 0.07997220673780936,
#    'std': 0.37808209117157243},
#   'value_3d_before': {'mean': 0.372240847676038,
#    'median': 0.4717762473615317,
#    'std': 0.3993857742954584},
#   'value_5d_before': {'mean': 0.561703575799606,
#    'median': 0.6739943655366826,
#    'std': 0.2901343493363984},
#   'value_7d_before': {'mean': 0.6765219585396701,
#    'median': 0.7486493797978429,
#    'std': 0.18086122859876208},
#   'absolute_change': {'1d': {'mean': -0.12151274651079044,
#     'median': -0.10426955874801808,
#     'std': 0.12384301118890569},
#    '3d': {'mean': -0.408306317782033,
#     'median': -0.49117555545635844,
#     'std': 0.33962277486611875},
#    '7d': {'mean': -0.7125874286456652,
#     'median': -0.7569011764456728,
#     'std': 0.3545782683968346}},
#   'percentage_change': {'1d': {'mean': -80.70658053920994,
#     'median': -32.17969390468352,
#     'std': 88.57195660618105},
#    '3d': {'mean': -117.86005675045207,
#     'median': -184.1253805929329,
#     'std': 92.84325119988966},
#    '7d': {'mean': -154.8402009967075,
#     'median': -200.0,
#     'std': 69.72214024698297}},
#   'window_stats': {'3d_window': {'avg': {'mean': 0.1621932999313908,
#      'median': 0.17627285997517686,
#      'std': 0.36375597806457444},
#     'slope': {'mean': -0.1404628510879117,
#      'median': -0.1649196655371164,
#      'std': 0.11761528709300462,
#      'percent_significant': 100.0,
#      'alpha_level': 0.05}},
#    '7d_window': {'avg': {'mean': 0.38343077319294194,
#      'median': 0.4200851633933799,
#      'std': 0.2971330110407575},
#     'slope': {'mean': -0.10623019003081806,
#      'median': -0.11652766671225534,
#      'std': 0.06205869744303334,
#      'percent_significant': 100.0,
#      'alpha_level': 0.05}}}},
#  'control_comparison': {'num_control_pens_analyzed': 6,
#   'num_control_reference_points': 100,
#   'comparison_results': {'value_at_removal': {'outbreak_mean': -0.03606547010599507,
#     'outbreak_std': 0.36664325427308275,
#     'control_mean': 0.713703522505514,
#     'control_std': 0.12362999249024152,
#     'p_value': 2.183134384020525e-11,
#     'is_significant': True,
#     'effect_size': 4.038470404478763},
#    '1d_window_avg': {'outbreak_mean': 0.022159387597092028,
#     'outbreak_std': 0.36698989199239196,
#     'control_mean': 0.7161536423936901,
#     'control_std': 0.1208110938339903,
#     'p_value': 7.508433803540567e-11,
#     'is_significant': True,
#     'effect_size': 3.7675236404559906},
#    '3d_window_avg': {'outbreak_mean': 0.1621932999313908,
#     'outbreak_std': 0.36375597806457444,
#     'control_mean': 0.7172652688115404,
#     'control_std': 0.11844633553837619,
#     'p_value': 1.3658056795455979e-09,
#     'is_significant': True,
#     'effect_size': 3.052055915085218},
#    '5d_window_avg': {'outbreak_mean': 0.28753053294844866,
#     'outbreak_std': 0.34250384651538646,
#     'control_mean': 0.7140191799948202,
#     'control_std': 0.11698997483622478,
#     'p_value': 2.3966698988992984e-08,
#     'is_significant': True,
#     'effect_size': 2.4472239434759686},
#    '7d_window_avg': {'outbreak_mean': 0.38343077319294194,
#     'outbreak_std': 0.2971330110407575,
#     'control_mean': 0.7113099984909564,
#     'control_std': 0.11676440565285659,
#     'p_value': 4.694414317577566e-07,
#     'is_significant': True,
#     'effect_size': 2.047067236692995},
#    '1d_window_slope': {'outbreak_mean': -0.1215127465107904,
#     'outbreak_std': 0.12384301118890563,
#     'control_mean': -0.005113293679671255,
#     'control_std': 0.037083072485997175,
#     'p_value': 0.00010294403340777828,
#     'is_significant': True,
#     'effect_size': 1.9337530951193556},
#    '3d_window_slope': {'outbreak_mean': -0.1404628510879117,
#     'outbreak_std': 0.11761528709300462,
#     'control_mean': -0.0005610812703874818,
#     'control_std': 0.02795150382245906,
#     'p_value': 7.819704052347828e-07,
#     'is_significant': True,
#     'effect_size': 2.6056081431811475},
#    '5d_window_slope': {'outbreak_mean': -0.12668805560657254,
#     'outbreak_std': 0.0890870081057146,
#     'control_mean': 0.002637247643531348,
#     'control_std': 0.02302635773637177,
#     'p_value': 3.434990101962026e-10,
#     'is_significant': True,
#     'effect_size': 3.1158200562416143},
#    '7d_window_slope': {'outbreak_mean': -0.10623019003081806,
#     'outbreak_std': 0.06205869744303334,
#     'control_mean': 0.003076938461257827,
#     'control_std': 0.01987842275166737,
#     'p_value': 1.2208643991929289e-11,
#     'is_significant': True,
#     'effect_size': 3.5433209320360124},
#    'abs_change_1d': {'outbreak_mean': -0.12151274651079044,
#     'outbreak_std': 0.12384301118890569,
#     'control_mean': -0.005113293679671257,
#     'control_std': 0.03708307248599718,
#     'p_value': 0.00010294403340777828,
#     'is_significant': True,
#     'effect_size': 1.9337530951193556},
#    'abs_change_3d': {'outbreak_mean': -0.408306317782033,
#     'outbreak_std': 0.33962277486611875,
#     'control_mean': -0.0025904155791208706,
#     'control_std': 0.08321688491292814,
#     'p_value': 5.638922424929695e-07,
#     'is_significant': True,
#     'effect_size': 2.598273619585708},
#    'abs_change_5d': {'outbreak_mean': -0.597769045905601,
#     'outbreak_std': 0.3666410894344907,
#     'control_mean': 0.010479987664095178,
#     'control_std': 0.11108457540390168,
#     'p_value': 3.69648332560164e-11,
#     'is_significant': True,
#     'effect_size': 3.4003385739728693},
#    'abs_change_7d': {'outbreak_mean': -0.7125874286456652,
#     'outbreak_std': 0.3545782683968346,
#     'control_mean': 0.007373562383341014,
#     'control_std': 0.12937819165650044,
#     'p_value': 2.1937687650670222e-11,
#     'is_significant': True,
#     'effect_size': 3.7705053858766338}},
#   'significant_metrics': ['value_at_removal',
#    '1d_window_avg',
#    '3d_window_avg',
#    '5d_window_avg',
#    '7d_window_avg',
#    '1d_window_slope',
#    '3d_window_slope',
#    '5d_window_slope',
#    '7d_window_slope',
#    'abs_change_1d',
#    'abs_change_3d',
#    'abs_change_5d',
#    'abs_change_7d'],
#   'strong_effect_metrics': ['value_at_removal',
#    '1d_window_avg',
#    '3d_window_avg',
#    '5d_window_avg',
#    '7d_window_avg',
#    '1d_window_slope',
#    '3d_window_slope',
#    '5d_window_slope',
#    '7d_window_slope',
#    'abs_change_1d',
#    'abs_change_3d',
#    'abs_change_5d',
#    'abs_change_7d']},
#  'individual_variation': {'pattern_counts': {'Gradual-decline': 7,
#    'Sudden-decline': 5,
#    'Moderate-decline': 5,
#    'Erratic-decline': 3},
#   'pattern_percentages': {'Gradual-decline': 35.0,
#    'Sudden-decline': 25.0,
#    'Moderate-decline': 25.0,
#    'Erratic-decline': 15.0},
#   'pen_consistency': {'pens_with_multiple': 6,
#    'pens_consistent': 0,
#    'consistency_percentage': 0.0},
#   'Gradual-decline_metrics': {'count': 7,
#    'avg_value_at_removal': 0.0023070806662622407,
#    'avg_abs_change_7d': -0.5800570883273583,
#    'avg_7d_slope': -0.08409674297377752,
#    'avg_3d_slope': -0.07905070854138087},
#   'Sudden-decline_metrics': {'count': 5,
#    'avg_value_at_removal': -0.17788297852120033,
#    'avg_abs_change_7d': -0.935651355704367,
#    'avg_7d_slope': -0.13096480180129227,
#    'avg_3d_slope': -0.27527284007938474},
#   'Moderate-decline_metrics': {'count': 5,
#    'avg_value_at_removal': 0.23843713150364199,
#    'avg_abs_change_7d': -0.5626780100281951,
#    'avg_7d_slope': -0.09043976725005107,
#    'avg_3d_slope': -0.1363473206864862},
#   'Erratic-decline_metrics': {'count': 3,
#    'avg_value_at_removal': -0.3467432438986484,
#    'avg_abs_change_7d': -0.8999007086529947,
#    'avg_7d_slope': -0.1429679181810672,
#    'avg_3d_slope': -0.06593375271307135}},
#  'component_analysis': {'timepoint_stats': {'day_minus_0': {'upright_mean': 0.4819672649470025,
#     'upright_std': 0.1833216271365414,
#     'hanging_mean': 0.5180327350529975,
#     'hanging_std': 0.18332162713654138,
#     'diff_mean': -0.03606547010599507,
#     'diff_std': 0.36664325427308275,
#     'count': 20},
#    'day_minus_1': {'upright_mean': 0.5427236382023976,
#     'upright_std': 0.18904104558578622,
#     'hanging_mean': 0.4572763617976022,
#     'hanging_std': 0.18904104558578622,
#     'diff_mean': 0.08544727640479541,
#     'diff_std': 0.37808209117157243,
#     'count': 20},
#    'day_minus_3': {'upright_mean': 0.686120423838019,
#     'upright_std': 0.19969288714772915,
#     'hanging_mean': 0.31387957616198103,
#     'hanging_std': 0.1996928871477292,
#     'diff_mean': 0.372240847676038,
#     'diff_std': 0.3993857742954584,
#     'count': 20},
#    'day_minus_5': {'upright_mean': 0.7808517878998028,
#     'upright_std': 0.14506717466819918,
#     'hanging_mean': 0.21914821210019703,
#     'hanging_std': 0.1450671746681992,
#     'diff_mean': 0.561703575799606,
#     'diff_std': 0.2901343493363984,
#     'count': 20},
#    'day_minus_7': {'upright_mean': 0.838260979269835,
#     'upright_std': 0.09043061429938104,
#     'hanging_mean': 0.16173902073016497,
#     'hanging_std': 0.09043061429938105,
#     'diff_mean': 0.6765219585396701,
#     'diff_std': 0.18086122859876208,
#     'count': 20}},
#   'day_minus_0_stats': {'upright_mean': 0.4819672649470025,
#    'upright_std': 0.1833216271365414,
#    'hanging_mean': 0.5180327350529975,
#    'hanging_std': 0.18332162713654138,
#    'diff_mean': -0.03606547010599507,
#    'diff_std': 0.36664325427308275,
#    'count': 20},
#   'day_minus_3_stats': {'upright_mean': 0.686120423838019,
#    'upright_std': 0.19969288714772915,
#    'hanging_mean': 0.31387957616198103,
#    'hanging_std': 0.1996928871477292,
#    'diff_mean': 0.372240847676038,
#    'diff_std': 0.3993857742954584,
#    'count': 20},
#   'day_minus_7_stats': {'upright_mean': 0.838260979269835,
#    'upright_std': 0.09043061429938104,
#    'hanging_mean': 0.16173902073016497,
#    'hanging_std': 0.09043061429938105,
#    'diff_mean': 0.6765219585396701,
#    'diff_std': 0.18086122859876208,
#    'count': 20},
#   'change_stats': {'upright_7d_change': -0.3562937143228325,
#    'hanging_7d_change': 0.3562937143228325,
#    'diff_7d_change': -0.7125874286456652,
#    'upright_3d_change': -0.20415315889101648,
#    'hanging_3d_change': 0.20415315889101648,
#    'diff_3d_change': -0.4083063177820331},
#   'contribution_stats': {'upright_contribution_7d': -49.99999999999999,
#    'hanging_contribution_7d': -49.99999999999999,
#    'primary_driver_7d': 'hanging',
#    'upright_contribution_3d': -49.999999999999986,
#    'hanging_contribution_3d': -49.999999999999986,
#    'primary_driver_3d': 'hanging'},
#   'primary_driver_7d': 'hanging',
#   'upright_contribution_7d': -49.99999999999999,
#   'hanging_contribution_7d': -49.99999999999999,
#   'primary_driver_3d': 'hanging',
#   'upright_contribution_3d': -49.999999999999986,
#   'hanging_contribution_3d': -49.999999999999986},
#  'monitoring_thresholds': {'status': 'No monitoring threshold analysis available.'}}

# %%
config_activity_evaluation = load_json_data('config_activity.json')

pprint.pprint(config_activity_evaluation, compact=True)
# Out:
# {'abs_change_outlier_iqr_factor': 3,
#  'analysis_window_days': [1, 3, 5, 7],
#  'comparison_metrics': ['value_at_removal', '1d_window_avg', '3d_window_avg',
#                         '5d_window_avg', '7d_window_avg', '1d_window_slope',
#                         '3d_window_slope', '5d_window_slope', '7d_window_slope',
#                         'abs_change_1d', 'abs_change_3d', 'abs_change_5d',
#                         'abs_change_7d'],
#  'comparison_stats_activity_filename': 'outbreak_vs_control_comparison_activity.csv',
#  'comparison_stats_num_pigs_lying_filename': 'outbreak_vs_control_comparison_num_pigs_lying.csv',
#  'comparison_stats_num_pigs_notLying_filename': 'outbreak_vs_control_comparison_num_pigs_notLying.csv',
#  'confidence_level': 0.95,
#  'control_date_margin': 5,
#  'control_samples_per_pen': 5,
#  'control_stats_activity_filename': 'control_statistics_activity.csv',
#  'control_stats_num_pigs_lying_filename': 'control_statistics_num_pigs_lying.csv',
#  'control_stats_num_pigs_notLying_filename': 'control_statistics_num_pigs_notLying.csv',
#  'days_before_list': [1, 3, 5, 7],
#  'fig_size_behavior': [11, 10],
#  'fig_size_comparison': [11, 10],
#  'fig_size_components': [11, 10],
#  'figure_dpi': 600,
#  'interpolation_method': 'linear',
#  'interpolation_order': 3,
#  'max_allowed_consecutive_missing_days': 3,
#  'max_allowed_missing_days_pct': 50.0,
#  'min_control_analysis_dates': 2,
#  'min_control_dates_threshold': 8,
#  'normalize': True,
#  'output_dir': 'results_activity_evaluation',
#  'pre_outbreak_stats_activity_filename': 'pre_outbreak_statistics_activity_filtered.csv',
#  'pre_outbreak_stats_num_pigs_lying_filename': 'pre_outbreak_statistics_num_pigs_lying_filtered.csv',
#  'pre_outbreak_stats_num_pigs_notLying_filename': 'pre_outbreak_statistics_num_pigs_notLying_filtered.csv',
#  'random_seed': 42,
#  'resample_freq': 'D',
#  'significance_level': 0.05,
#  'smoothing_method': 'rolling',
#  'smoothing_strength': 3,
#  'violin_width': 0.4,
#  'viz_activity_components_filename': 'lying_component_analysis.png',
#  'viz_behavior_activity_filename': 'behavior_analysis_activity.png',
#  'viz_behavior_num_pigs_lying_filename': 'behavior_analysis_num_pigs_lying.png',
#  'viz_behavior_num_pigs_notLying_filename': 'behavior_analysis_num_pigs_notLying.png',
#  'viz_comparison_activity_filename': 'behavior_comparison_activity.png',
#  'viz_comparison_num_pigs_lying_filename': 'behavior_comparison_num_pigs_lying.png',
#  'viz_comparison_num_pigs_notLying_filename': 'behavior_comparison_num_pigs_notLying.png'}

# %%
# Create the behavior visualizer
visualizer = PigBehaviorVisualizer(config=config_activity_evaluation)

# Process all data
visualizer.process_all_data()

# Run the complete analysis
analysis_results = visualizer.run_complete_behavior_analysis()

# Visualize all behavior metrics
viz_files = visualizer.visualize_behavior_metrics()

# Create comparison visualizations between outbreak and control groups
visualizer.visualize_behavior_comparison()

# create visualizations for component analysis
visualizer.visualize_activity_components()
# Out:
# 2025-05-03 09:41:19,834 - tail_posture_descriptive_analysis - INFO - Saved configuration to results_activity_evaluation/analysis_config.txt
# 2025-05-03 09:41:19,834 - evaluation.tail_posture_analysis.utils - INFO - Setting plot style: Font=serif, BaseSize=11pt, Format=png, DPI=600
# 2025-05-03 09:41:19,835 - tail_posture_descriptive_analysis - INFO - Dissertation quality plotting style set for behavior visualization.
# 2025-05-03 09:41:19,835 - tail_posture_descriptive_analysis - INFO - Processing all monitoring results for behavior analysis...
# 2025-05-03 09:41:19,836 - tail_posture_descriptive_analysis - INFO - Loading monitoring pipeline data...
# 2025-05-03 09:41:26,259 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera5/221004_221104: [datetime.date(2022, 11, 3)]
# 2025-05-03 09:41:28,332 - data_analysis_utils - WARNING - Missing 17 day(s) for Kamera5/220510_220529: [datetime.date(2022, 5, 10), datetime.date(2022, 5, 12), datetime.date(2022, 5, 14), datetime.date(2022, 5, 15), datetime.date(2022, 5, 16), datetime.date(2022, 5, 18), datetime.date(2022, 5, 19), datetime.date(2022, 5, 20), datetime.date(2022, 5, 21), datetime.date(2022, 5, 22), datetime.date(2022, 5, 23), datetime.date(2022, 5, 24), datetime.date(2022, 5, 25), datetime.date(2022, 5, 26), datetime.date(2022, 5, 27), datetime.date(2022, 5, 28), datetime.date(2022, 5, 29)]
# 2025-05-03 09:41:28,342 - data_analysis_utils - WARNING - Dataframe became empty after time filtering: /home/jan-hendrik/home/PigMonitoringResearch/pipeline_outputs/monitoring_pipeline/piglet_rearing/Kamera5/220510_220529/Kamera5_2022_05_11_08_18_23-09_18_23.csv. Skipping.
# 2025-05-03 09:41:28,352 - data_analysis_utils - WARNING - Dataframe became empty after time filtering: /home/jan-hendrik/home/PigMonitoringResearch/pipeline_outputs/monitoring_pipeline/piglet_rearing/Kamera5/220510_220529/Kamera5_2022_05_13_08_18_21-09_18_21.csv. Skipping.
# 2025-05-03 09:41:28,366 - data_analysis_utils - WARNING - Loaded 1 non-empty dataframes out of 3 found CSVs for Kamera5/220510_220529.
# 2025-05-03 09:41:28,367 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera5/221219_230126: [datetime.date(2023, 1, 26)]
# 2025-05-03 09:41:30,972 - data_analysis_utils - WARNING - Missing 7 day(s) for Kamera5/220228_220407: [datetime.date(2022, 4, 1), datetime.date(2022, 4, 2), datetime.date(2022, 4, 3), datetime.date(2022, 4, 4), datetime.date(2022, 4, 5), datetime.date(2022, 4, 6), datetime.date(2022, 4, 7)]
# 2025-05-03 09:41:32,946 - data_analysis_utils - WARNING - Missing 6 day(s) for Kamera5/230227_230406: [datetime.date(2023, 3, 8), datetime.date(2023, 3, 9), datetime.date(2023, 3, 10), datetime.date(2023, 3, 11), datetime.date(2023, 3, 12), datetime.date(2023, 3, 13)]
# 2025-05-03 09:41:35,218 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera1/211228_220119: [datetime.date(2022, 1, 1)]
# 2025-05-03 09:41:36,571 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera1/221003_221106: [datetime.date(2022, 11, 3)]
# 2025-05-03 09:41:48,308 - data_analysis_utils - WARNING - Missing 25 day(s) for Kamera1/220505_220530: [datetime.date(2022, 5, 5), datetime.date(2022, 5, 6), datetime.date(2022, 5, 7), datetime.date(2022, 5, 8), datetime.date(2022, 5, 9), datetime.date(2022, 5, 10), datetime.date(2022, 5, 11), datetime.date(2022, 5, 12), datetime.date(2022, 5, 13), datetime.date(2022, 5, 14), datetime.date(2022, 5, 16), datetime.date(2022, 5, 17), datetime.date(2022, 5, 18), datetime.date(2022, 5, 19), datetime.date(2022, 5, 20), datetime.date(2022, 5, 21), datetime.date(2022, 5, 22), datetime.date(2022, 5, 23), datetime.date(2022, 5, 24), datetime.date(2022, 5, 25), datetime.date(2022, 5, 26), datetime.date(2022, 5, 27), datetime.date(2022, 5, 28), datetime.date(2022, 5, 29), datetime.date(2022, 5, 30)]
# 2025-05-03 09:41:50,971 - data_analysis_utils - WARNING - Missing 2 day(s) for Kamera6/221003_221107: [datetime.date(2022, 11, 3), datetime.date(2022, 11, 7)]
# 2025-05-03 09:41:53,091 - data_analysis_utils - WARNING - Missing 6 day(s) for Kamera6/211230_220120: [datetime.date(2022, 1, 15), datetime.date(2022, 1, 16), datetime.date(2022, 1, 17), datetime.date(2022, 1, 18), datetime.date(2022, 1, 19), datetime.date(2022, 1, 20)]
# 2025-05-03 09:41:54,082 - data_analysis_utils - WARNING - Missing 5 day(s) for Kamera6/220725_220905: [datetime.date(2022, 9, 1), datetime.date(2022, 9, 2), datetime.date(2022, 9, 3), datetime.date(2022, 9, 4), datetime.date(2022, 9, 5)]
# 2025-05-03 09:41:56,525 - data_analysis_utils - WARNING - Missing 21 day(s) for Kamera6/220509_220530: [datetime.date(2022, 5, 9), datetime.date(2022, 5, 10), datetime.date(2022, 5, 12), datetime.date(2022, 5, 13), datetime.date(2022, 5, 14), datetime.date(2022, 5, 15), datetime.date(2022, 5, 16), datetime.date(2022, 5, 17), datetime.date(2022, 5, 18), datetime.date(2022, 5, 19), datetime.date(2022, 5, 20), datetime.date(2022, 5, 21), datetime.date(2022, 5, 22), datetime.date(2022, 5, 23), datetime.date(2022, 5, 24), datetime.date(2022, 5, 25), datetime.date(2022, 5, 26), datetime.date(2022, 5, 27), datetime.date(2022, 5, 28), datetime.date(2022, 5, 29), datetime.date(2022, 5, 30)]
# 2025-05-03 09:41:56,540 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera6/221219_230126: [datetime.date(2023, 1, 26)]
# 2025-05-03 09:41:59,147 - data_analysis_utils - WARNING - Missing 6 day(s) for Kamera6/220228_220407: [datetime.date(2022, 3, 31), datetime.date(2022, 4, 1), datetime.date(2022, 4, 3), datetime.date(2022, 4, 4), datetime.date(2022, 4, 6), datetime.date(2022, 4, 7)]
# 2025-05-03 09:42:01,069 - data_analysis_utils - WARNING - Missing 4 day(s) for Kamera6/230515_230622: [datetime.date(2023, 6, 18), datetime.date(2023, 6, 19), datetime.date(2023, 6, 20), datetime.date(2023, 6, 22)]
# 2025-05-03 09:42:03,667 - data_analysis_utils - WARNING - Missing 6 day(s) for Kamera6/230227_230406: [datetime.date(2023, 3, 8), datetime.date(2023, 3, 9), datetime.date(2023, 3, 10), datetime.date(2023, 3, 11), datetime.date(2023, 3, 12), datetime.date(2023, 3, 13)]
# 2025-05-03 09:42:07,363 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera2/221003_221106: [datetime.date(2022, 11, 3)]
# 2025-05-03 09:42:19,233 - data_analysis_utils - WARNING - Missing 24 day(s) for Kamera2/220505_220530: [datetime.date(2022, 5, 5), datetime.date(2022, 5, 6), datetime.date(2022, 5, 7), datetime.date(2022, 5, 8), datetime.date(2022, 5, 9), datetime.date(2022, 5, 10), datetime.date(2022, 5, 12), datetime.date(2022, 5, 13), datetime.date(2022, 5, 14), datetime.date(2022, 5, 16), datetime.date(2022, 5, 17), datetime.date(2022, 5, 18), datetime.date(2022, 5, 19), datetime.date(2022, 5, 20), datetime.date(2022, 5, 21), datetime.date(2022, 5, 22), datetime.date(2022, 5, 23), datetime.date(2022, 5, 24), datetime.date(2022, 5, 25), datetime.date(2022, 5, 26), datetime.date(2022, 5, 27), datetime.date(2022, 5, 28), datetime.date(2022, 5, 29), datetime.date(2022, 5, 30)]
# 2025-05-03 09:42:21,988 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera4/221226_230126: [datetime.date(2023, 1, 26)]
# 2025-05-03 09:42:24,177 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera4/221003_221106: [datetime.date(2022, 11, 3)]
# 2025-05-03 09:42:30,351 - data_analysis_utils - WARNING - Missing 16 day(s) for Kamera4/220725_220905: [datetime.date(2022, 8, 21), datetime.date(2022, 8, 22), datetime.date(2022, 8, 23), datetime.date(2022, 8, 24), datetime.date(2022, 8, 25), datetime.date(2022, 8, 26), datetime.date(2022, 8, 27), datetime.date(2022, 8, 28), datetime.date(2022, 8, 29), datetime.date(2022, 8, 30), datetime.date(2022, 8, 31), datetime.date(2022, 9, 1), datetime.date(2022, 9, 2), datetime.date(2022, 9, 3), datetime.date(2022, 9, 4), datetime.date(2022, 9, 5)]
# 2025-05-03 09:42:32,079 - data_analysis_utils - WARNING - Missing 18 day(s) for Kamera4/220510_220529: [datetime.date(2022, 5, 11), datetime.date(2022, 5, 12), datetime.date(2022, 5, 13), datetime.date(2022, 5, 14), datetime.date(2022, 5, 16), datetime.date(2022, 5, 17), datetime.date(2022, 5, 18), datetime.date(2022, 5, 19), datetime.date(2022, 5, 20), datetime.date(2022, 5, 21), datetime.date(2022, 5, 22), datetime.date(2022, 5, 23), datetime.date(2022, 5, 24), datetime.date(2022, 5, 25), datetime.date(2022, 5, 26), datetime.date(2022, 5, 27), datetime.date(2022, 5, 28), datetime.date(2022, 5, 29)]
# 2025-05-03 09:42:32,107 - data_analysis_utils - WARNING - Missing 7 day(s) for Kamera4/220228_220407: [datetime.date(2022, 3, 31), datetime.date(2022, 4, 1), datetime.date(2022, 4, 3), datetime.date(2022, 4, 4), datetime.date(2022, 4, 5), datetime.date(2022, 4, 6), datetime.date(2022, 4, 7)]
# 2025-05-03 09:42:38,748 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera3/221003_221106: [datetime.date(2022, 11, 3)]
# 2025-05-03 09:42:45,396 - data_analysis_utils - WARNING - Missing 5 day(s) for Kamera3/220725_220905: [datetime.date(2022, 9, 1), datetime.date(2022, 9, 2), datetime.date(2022, 9, 3), datetime.date(2022, 9, 4), datetime.date(2022, 9, 5)]
# 2025-05-03 09:42:47,859 - data_analysis_utils - WARNING - Missing 4 day(s) for Kamera3/221219_230125: [datetime.date(2023, 1, 22), datetime.date(2023, 1, 23), datetime.date(2023, 1, 24), datetime.date(2023, 1, 25)]
# 2025-05-03 09:42:50,209 - data_analysis_utils - WARNING - Missing 24 day(s) for Kamera3/220505_220529: [datetime.date(2022, 5, 5), datetime.date(2022, 5, 6), datetime.date(2022, 5, 7), datetime.date(2022, 5, 8), datetime.date(2022, 5, 9), datetime.date(2022, 5, 10), datetime.date(2022, 5, 11), datetime.date(2022, 5, 12), datetime.date(2022, 5, 13), datetime.date(2022, 5, 14), datetime.date(2022, 5, 15), datetime.date(2022, 5, 16), datetime.date(2022, 5, 18), datetime.date(2022, 5, 19), datetime.date(2022, 5, 20), datetime.date(2022, 5, 21), datetime.date(2022, 5, 22), datetime.date(2022, 5, 23), datetime.date(2022, 5, 24), datetime.date(2022, 5, 25), datetime.date(2022, 5, 26), datetime.date(2022, 5, 27), datetime.date(2022, 5, 28), datetime.date(2022, 5, 29)]
# 2025-05-03 09:42:50,224 - data_analysis_utils - WARNING - Missing 2 day(s) for Kamera3/230227_230406: [datetime.date(2023, 3, 9), datetime.date(2023, 3, 10)]
# 2025-05-03 09:42:52,759 - tail_posture_descriptive_analysis - INFO - Loaded 48 monitoring results in 92.92 seconds
# 2025-05-03 09:42:52,760 - tail_posture_descriptive_analysis - INFO - Dataset contains 6 cameras and 28 datespans.
# 2025-05-03 09:42:52,760 - tail_posture_descriptive_analysis - INFO - Total expected days across all datespans: 1623
# 2025-05-03 09:42:52,760 - tail_posture_descriptive_analysis - INFO - Total missing daily files detected: 214 (13.19%)
# 2025-05-03 09:42:52,999 - tail_posture_descriptive_analysis - WARNING - Dataset too small for smoothing (length 1). Skipping smoothing.
# 2025-05-03 09:42:53,002 - tail_posture_descriptive_analysis - WARNING - Not enough non-NaN data points (1) for interpolation on Kamera1 - 220505_220530. Skipping.
# 2025-05-03 09:42:54,117 - tail_posture_descriptive_analysis - WARNING - Dataset too small for smoothing (length 2). Skipping smoothing.
# 2025-05-03 09:42:55,310 - tail_posture_descriptive_analysis - WARNING - Dataset too small for smoothing (length 1). Skipping smoothing.
# 2025-05-03 09:42:55,313 - tail_posture_descriptive_analysis - WARNING - Not enough non-NaN data points (1) for interpolation on Kamera3 - 220505_220529. Skipping.
# 2025-05-03 09:42:56,468 - tail_posture_descriptive_analysis - WARNING - Dataset too small for smoothing (length 2). Skipping smoothing.
# 2025-05-03 09:42:57,942 - tail_posture_descriptive_analysis - WARNING - Dataset too small for smoothing (length 1). Skipping smoothing.
# 2025-05-03 09:42:57,945 - tail_posture_descriptive_analysis - WARNING - Not enough non-NaN data points (1) for interpolation on Kamera5 - 220510_220529. Skipping.
# 2025-05-03 09:42:58,921 - tail_posture_descriptive_analysis - WARNING - Dataset too small for smoothing (length 1). Skipping smoothing.
# 2025-05-03 09:42:58,924 - tail_posture_descriptive_analysis - WARNING - Not enough non-NaN data points (1) for interpolation on Kamera6 - 220509_220530. Skipping.
# 2025-05-03 09:42:59,680 - tail_posture_descriptive_analysis - INFO - Successfully processed 48 monitoring results.
# 2025-05-03 09:42:59,681 - tail_posture_descriptive_analysis - INFO - Found the following behavior metrics in the data: num_pigs_notLying, num_pigs_lying, activity
# 2025-05-03 09:42:59,682 - tail_posture_descriptive_analysis - INFO - Analyzing pre-outbreak behavior statistics (using earliest removal date per event)...
# 2025-05-03 09:42:59,682 - tail_posture_descriptive_analysis - INFO - Excluding Kamera1/211228_220119: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:42:59,700 - tail_posture_descriptive_analysis - INFO - Excluding Kamera1/220505_220530 from behavior analysis due to excessive missing days (25/26 = 96.2% > 50.0%)
# 2025-05-03 09:42:59,700 - tail_posture_descriptive_analysis - INFO - Excluding Kamera1/220726_220831: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:42:59,766 - tail_posture_descriptive_analysis - INFO - Excluding Kamera2/211227_220119: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:42:59,767 - tail_posture_descriptive_analysis - INFO - Removal date 2022-04-06 is after last data point for Pen 2. Using last available data point.
# 2025-05-03 09:42:59,784 - tail_posture_descriptive_analysis - INFO - Excluding Kamera2/220505_220530 from behavior analysis due to excessive missing days (24/26 = 92.3% > 50.0%)
# 2025-05-03 09:42:59,784 - tail_posture_descriptive_analysis - INFO - Excluding Kamera2/220725_220831: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:42:59,785 - tail_posture_descriptive_analysis - INFO - Removal date 2022-11-07 is after last data point for Pen 2. Using last available data point.
# 2025-05-03 09:42:59,801 - tail_posture_descriptive_analysis - INFO - Excluding Kamera2/221219_230125: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:42:59,802 - tail_posture_descriptive_analysis - INFO - Excluding Kamera2/230227_230405: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:42:59,819 - tail_posture_descriptive_analysis - INFO - Excluding Kamera3/211222_220119: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:42:59,835 - tail_posture_descriptive_analysis - INFO - Excluding Kamera3/220505_220529 from behavior analysis due to excessive missing days (24/25 = 96.0% > 50.0%)
# 2025-05-03 09:42:59,836 - tail_posture_descriptive_analysis - INFO - Excluding Kamera3/220725_220905: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:42:59,853 - tail_posture_descriptive_analysis - INFO - Excluding Kamera3/221219_230125: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:42:59,853 - tail_posture_descriptive_analysis - INFO - Excluding Kamera3/230227_230406: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:42:59,870 - tail_posture_descriptive_analysis - INFO - Excluding Kamera4/211229_220119: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:42:59,870 - tail_posture_descriptive_analysis - INFO - Excluding Kamera4/220228_220407: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:42:59,871 - tail_posture_descriptive_analysis - INFO - Excluding Kamera4/220510_220529 from behavior analysis due to 4 consecutive missing periods in resampled data (threshold: 3). Raw missing days: 18
# 2025-05-03 09:42:59,871 - tail_posture_descriptive_analysis - INFO - Excluding Kamera4/220725_220905: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:42:59,872 - tail_posture_descriptive_analysis - INFO - Removal date 2022-11-07 is after last data point for Pen 4. Using last available data point.
# 2025-05-03 09:42:59,937 - tail_posture_descriptive_analysis - INFO - Excluding Kamera5/211231_220119: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:42:59,938 - tail_posture_descriptive_analysis - INFO - Excluding Kamera5/220228_220407: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:42:59,938 - tail_posture_descriptive_analysis - INFO - Excluding Kamera5/220510_220529 from behavior analysis due to excessive missing days (17/20 = 85.0% > 50.0%)
# 2025-05-03 09:42:59,971 - tail_posture_descriptive_analysis - INFO - Excluding Kamera5/221219_230126: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:42:59,972 - tail_posture_descriptive_analysis - INFO - Excluding Kamera5/230227_230406 from behavior analysis due to 6 consecutive missing periods in resampled data (threshold: 3). Raw missing days: 6
# 2025-05-03 09:42:59,989 - tail_posture_descriptive_analysis - INFO - Excluding Kamera6/211230_220120: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:42:59,989 - tail_posture_descriptive_analysis - INFO - Excluding Kamera6/220228_220407: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:42:59,989 - tail_posture_descriptive_analysis - INFO - Excluding Kamera6/220509_220530 from behavior analysis due to excessive missing days (21/22 = 95.5% > 50.0%)
# 2025-05-03 09:42:59,990 - tail_posture_descriptive_analysis - INFO - Excluding Kamera6/220725_220905: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:43:00,007 - tail_posture_descriptive_analysis - INFO - Excluding Kamera6/221219_230126: Not a tail biting event or missing culprit removal info
# 2025-05-03 09:43:00,007 - tail_posture_descriptive_analysis - INFO - Excluding Kamera6/230227_230406 from behavior analysis due to 6 consecutive missing periods in resampled data (threshold: 3). Raw missing days: 6
# 2025-05-03 09:43:00,027 - tail_posture_descriptive_analysis - INFO - Saved descriptive pre-outbreak statistics for num_pigs_lying to results_activity_evaluation/pre_outbreak_statistics_num_pigs_lying_filtered.csv
# 2025-05-03 09:43:00,030 - tail_posture_descriptive_analysis - INFO - Saved descriptive pre-outbreak statistics for num_pigs_notLying to results_activity_evaluation/pre_outbreak_statistics_num_pigs_notLying_filtered.csv
# 2025-05-03 09:43:00,033 - tail_posture_descriptive_analysis - INFO - Saved descriptive pre-outbreak statistics for activity to results_activity_evaluation/pre_outbreak_statistics_activity_filtered.csv
# 2025-05-03 09:43:00,033 - tail_posture_descriptive_analysis - INFO - Attempted to analyze 22 potential tail biting events for behavior metrics.
# 2025-05-03 09:43:00,034 - tail_posture_descriptive_analysis - INFO - Successfully analyzed at least one metric for 3 events.
# 2025-05-03 09:43:00,034 - tail_posture_descriptive_analysis - INFO - Excluded 3 events due to >3 consecutive missing days.
# 2025-05-03 09:43:00,035 - tail_posture_descriptive_analysis - INFO - Excluded 5 events due to excessive missing days (>50.0%).
# 2025-05-03 09:43:00,035 - tail_posture_descriptive_analysis - INFO - Excluded 11 events for other reasons (e.g., no valid removal date, empty data).
# 2025-05-03 09:43:00,035 - tail_posture_descriptive_analysis - INFO -   - num_pigs_lying: 20 valid analyses
# 2025-05-03 09:43:00,036 - tail_posture_descriptive_analysis - INFO -   - num_pigs_notLying: 20 valid analyses
# 2025-05-03 09:43:00,036 - tail_posture_descriptive_analysis - INFO -   - activity: 20 valid analyses
# 2025-05-03 09:43:00,037 - tail_posture_descriptive_analysis - INFO - Analyzing control pen statistics for behavior metrics comparison...
# 2025-05-03 09:43:00,038 - tail_posture_descriptive_analysis - INFO - Found 26 control pen datasets for behavior analysis
# 2025-05-03 09:43:00,107 - tail_posture_descriptive_analysis - INFO - Excluding control pen Kamera1/220505_220530 due to excessive missing days (25/26 = 96.2% > 50.0%)
# 2025-05-03 09:43:00,247 - tail_posture_descriptive_analysis - INFO - Excluding control pen Kamera2/220505_220530 due to excessive missing days (24/26 = 92.3% > 50.0%)
# 2025-05-03 09:43:00,525 - tail_posture_descriptive_analysis - INFO - Excluding control pen Kamera3/220505_220529 due to excessive missing days (24/25 = 96.0% > 50.0%)
# 2025-05-03 09:43:01,075 - tail_posture_descriptive_analysis - INFO - Excluding control pen Kamera5/220510_220529 due to excessive missing days (17/20 = 85.0% > 50.0%)
# 2025-05-03 09:43:01,146 - tail_posture_descriptive_analysis - INFO - Excluding control pen Kamera5/230227_230406 due to 6 consecutive missing periods in resampled data (threshold: 3). Raw missing days: 6
# 2025-05-03 09:43:01,284 - tail_posture_descriptive_analysis - INFO - Excluding control pen Kamera6/220509_220530 due to excessive missing days (21/22 = 95.5% > 50.0%)
# 2025-05-03 09:43:01,430 - tail_posture_descriptive_analysis - INFO - Saved control pen statistics for num_pigs_lying to results_activity_evaluation/control_statistics_num_pigs_lying.csv
# 2025-05-03 09:43:01,437 - tail_posture_descriptive_analysis - INFO - Saved control pen statistics for num_pigs_notLying to results_activity_evaluation/control_statistics_num_pigs_notLying.csv
# 2025-05-03 09:43:01,444 - tail_posture_descriptive_analysis - INFO - Saved control pen statistics for activity to results_activity_evaluation/control_statistics_activity.csv
# 2025-05-03 09:43:01,445 - tail_posture_descriptive_analysis - INFO - Analyzed 26 control pens for behavior metrics.
# 2025-05-03 09:43:01,446 - tail_posture_descriptive_analysis - INFO -   - num_pigs_lying: 20 control pen datasets with 100 reference points
# 2025-05-03 09:43:01,447 - tail_posture_descriptive_analysis - INFO -   - num_pigs_notLying: 20 control pen datasets with 100 reference points
# 2025-05-03 09:43:01,448 - tail_posture_descriptive_analysis - INFO -   - activity: 20 control pen datasets with 100 reference points
# 2025-05-03 09:43:01,449 - tail_posture_descriptive_analysis - INFO - Excluded 1 control pens due to >3 consecutive missing days.
# 2025-05-03 09:43:01,449 - tail_posture_descriptive_analysis - INFO - Excluded 5 control pens due to excessive missing days (>50.0%).
# 2025-05-03 09:43:01,450 - tail_posture_descriptive_analysis - INFO - Comparing outbreak vs control pen statistics for behavior metrics...
# 2025-05-03 09:43:01,450 - tail_posture_descriptive_analysis - INFO - Comparing num_pigs_lying between outbreak and control pens...
# 2025-05-03 09:43:01,452 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_lying_value_at_removal: Outbreak=12.063±3.141, Control=10.982±3.728, p=0.3329, Significant=False, Effect Size=0.30
# 2025-05-03 09:43:01,453 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_lying_1d_window_avg: Outbreak=12.036±3.074, Control=10.880±3.705, p=0.3022, Significant=False, Effect Size=0.32
# 2025-05-03 09:43:01,454 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_lying_3d_window_avg: Outbreak=12.063±3.019, Control=10.692±3.671, p=0.1730, Significant=False, Effect Size=0.38
# 2025-05-03 09:43:01,455 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_lying_5d_window_avg: Outbreak=12.023±3.009, Control=10.537±3.648, p=0.1519, Significant=False, Effect Size=0.42
# 2025-05-03 09:43:01,457 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_lying_7d_window_avg: Outbreak=11.906±3.013, Control=10.414±3.628, p=0.1479, Significant=False, Effect Size=0.42
# 2025-05-03 09:43:01,458 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_lying_1d_window_slope: Outbreak=0.055±0.641, Control=0.213±0.539, p=0.4407, Significant=False, Effect Size=0.28
# 2025-05-03 09:43:01,459 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_lying_3d_window_slope: Outbreak=-0.031±0.456, Control=0.182±0.385, p=0.0596, Significant=False, Effect Size=0.54
# 2025-05-03 09:43:01,460 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_lying_5d_window_slope: Outbreak=0.029±0.279, Control=0.159±0.352, p=0.1274, Significant=False, Effect Size=0.38
# 2025-05-03 09:43:01,461 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_lying_7d_window_slope: Outbreak=0.088±0.175, Control=0.134±0.295, p=0.3259, Significant=False, Effect Size=0.17
# 2025-05-03 09:43:01,462 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_lying_abs_change_1d: Outbreak=0.055±0.641, Control=0.213±0.539, p=0.4407, Significant=False, Effect Size=0.28
# 2025-05-03 09:43:01,464 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_lying_abs_change_3d: Outbreak=-0.045±1.335, Control=0.546±1.082, p=0.1061, Significant=False, Effect Size=0.52
# 2025-05-03 09:43:01,465 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_lying_abs_change_5d: Outbreak=0.177±1.242, Control=0.800±1.499, p=0.0987, Significant=False, Effect Size=0.43
# 2025-05-03 09:43:01,466 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_lying_abs_change_7d: Outbreak=0.619±1.377, Control=1.075±1.522, p=0.1164, Significant=False, Effect Size=0.30
# 2025-05-03 09:43:01,467 - tail_posture_descriptive_analysis - INFO - Saved outbreak vs control comparison for num_pigs_lying to results_activity_evaluation/outbreak_vs_control_comparison_num_pigs_lying.csv
# 2025-05-03 09:43:01,468 - tail_posture_descriptive_analysis - INFO - Comparing num_pigs_notLying between outbreak and control pens...
# 2025-05-03 09:43:01,469 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_notLying_value_at_removal: Outbreak=8.842±1.948, Control=9.045±1.568, p=0.5239, Significant=False, Effect Size=0.12
# 2025-05-03 09:43:01,470 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_notLying_1d_window_avg: Outbreak=9.006±1.851, Control=9.063±1.539, p=0.7863, Significant=False, Effect Size=0.04
# 2025-05-03 09:43:01,471 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_notLying_3d_window_avg: Outbreak=9.128±1.688, Control=9.101±1.548, p=0.9860, Significant=False, Effect Size=0.02
# 2025-05-03 09:43:01,473 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_notLying_5d_window_avg: Outbreak=9.192±1.503, Control=9.073±1.545, p=0.7917, Significant=False, Effect Size=0.08
# 2025-05-03 09:43:01,474 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_notLying_7d_window_avg: Outbreak=9.300±1.489, Control=9.043±1.565, p=0.5058, Significant=False, Effect Size=0.17
# 2025-05-03 09:43:01,475 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_notLying_1d_window_slope: Outbreak=-0.341±0.687, Control=-0.037±0.613, p=0.1031, Significant=False, Effect Size=0.49
# 2025-05-03 09:43:01,476 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_notLying_3d_window_slope: Outbreak=-0.088±0.422, Control=-0.031±0.461, p=0.7064, Significant=False, Effect Size=0.13
# 2025-05-03 09:43:01,477 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_notLying_5d_window_slope: Outbreak=-0.072±0.296, Control=0.018±0.384, p=0.4001, Significant=False, Effect Size=0.24
# 2025-05-03 09:43:01,479 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_notLying_7d_window_slope: Outbreak=-0.096±0.227, Control=0.031±0.294, p=0.0635, Significant=False, Effect Size=0.45
# 2025-05-03 09:43:01,480 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_notLying_abs_change_1d: Outbreak=-0.341±0.687, Control=-0.037±0.613, p=0.1031, Significant=False, Effect Size=0.49
# 2025-05-03 09:43:01,481 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_notLying_abs_change_3d: Outbreak=-0.295±1.232, Control=-0.057±1.313, p=0.5332, Significant=False, Effect Size=0.18
# 2025-05-03 09:43:01,482 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_notLying_abs_change_5d: Outbreak=-0.518±1.339, Control=0.076±1.650, p=0.1172, Significant=False, Effect Size=0.37
# 2025-05-03 09:43:01,483 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_notLying_abs_change_7d: Outbreak=-0.791±1.585, Control=0.018±1.661, p=0.0781, Significant=False, Effect Size=0.49
# 2025-05-03 09:43:01,485 - tail_posture_descriptive_analysis - INFO - Saved outbreak vs control comparison for num_pigs_notLying to results_activity_evaluation/outbreak_vs_control_comparison_num_pigs_notLying.csv
# 2025-05-03 09:43:01,485 - tail_posture_descriptive_analysis - INFO - Comparing activity between outbreak and control pens...
# 2025-05-03 09:43:01,486 - tail_posture_descriptive_analysis - INFO - Comparison for activity_value_at_removal: Outbreak=0.538±0.158, Control=0.573±0.124, p=0.1915, Significant=False, Effect Size=0.27
# 2025-05-03 09:43:01,487 - tail_posture_descriptive_analysis - INFO - Comparison for activity_1d_window_avg: Outbreak=0.549±0.149, Control=0.576±0.119, p=0.3618, Significant=False, Effect Size=0.22
# 2025-05-03 09:43:01,489 - tail_posture_descriptive_analysis - INFO - Comparison for activity_3d_window_avg: Outbreak=0.553±0.130, Control=0.586±0.115, p=0.2674, Significant=False, Effect Size=0.28
# 2025-05-03 09:43:01,490 - tail_posture_descriptive_analysis - INFO - Comparison for activity_5d_window_avg: Outbreak=0.550±0.109, Control=0.590±0.110, p=0.1205, Significant=False, Effect Size=0.36
# 2025-05-03 09:43:01,491 - tail_posture_descriptive_analysis - INFO - Comparison for activity_7d_window_avg: Outbreak=0.556±0.103, Control=0.593±0.110, p=0.1708, Significant=False, Effect Size=0.34
# 2025-05-03 09:43:01,492 - tail_posture_descriptive_analysis - INFO - Comparison for activity_1d_window_slope: Outbreak=-0.024±0.063, Control=-0.008±0.056, p=0.2012, Significant=False, Effect Size=0.29
# 2025-05-03 09:43:01,494 - tail_posture_descriptive_analysis - INFO - Comparison for activity_3d_window_slope: Outbreak=-0.001±0.047, Control=-0.009±0.038, p=0.5660, Significant=False, Effect Size=0.20
# 2025-05-03 09:43:01,495 - tail_posture_descriptive_analysis - INFO - Comparison for activity_5d_window_slope: Outbreak=0.002±0.032, Control=-0.005±0.029, p=0.1939, Significant=False, Effect Size=0.24
# 2025-05-03 09:43:01,496 - tail_posture_descriptive_analysis - INFO - Comparison for activity_7d_window_slope: Outbreak=-0.004±0.019, Control=-0.004±0.021, p=0.7540, Significant=False, Effect Size=0.01
# 2025-05-03 09:43:01,497 - tail_posture_descriptive_analysis - INFO - Comparison for activity_abs_change_1d: Outbreak=-0.024±0.063, Control=-0.008±0.056, p=0.2012, Significant=False, Effect Size=0.29
# 2025-05-03 09:43:01,498 - tail_posture_descriptive_analysis - INFO - Comparison for activity_abs_change_3d: Outbreak=-0.006±0.127, Control=-0.023±0.106, p=0.8081, Significant=False, Effect Size=0.15
# 2025-05-03 09:43:01,500 - tail_posture_descriptive_analysis - INFO - Comparison for activity_abs_change_5d: Outbreak=-0.006±0.131, Control=-0.025±0.118, p=0.5708, Significant=False, Effect Size=0.16
# 2025-05-03 09:43:01,501 - tail_posture_descriptive_analysis - INFO - Comparison for activity_abs_change_7d: Outbreak=-0.052±0.122, Control=-0.044±0.105, p=0.7951, Significant=False, Effect Size=0.08
# 2025-05-03 09:43:01,502 - tail_posture_descriptive_analysis - INFO - Saved outbreak vs control comparison for activity to results_activity_evaluation/outbreak_vs_control_comparison_activity.csv
# 2025-05-03 09:43:01,502 - tail_posture_descriptive_analysis - INFO - Completed behavior metrics analysis.
# 2025-05-03 09:43:01,503 - tail_posture_descriptive_analysis - INFO - === Behavior Analysis Summary ===
# 2025-05-03 09:43:01,503 - tail_posture_descriptive_analysis - INFO - num_pigs_lying: 20 outbreaks, 100 controls, 13 comparisons
# 2025-05-03 09:43:01,504 - tail_posture_descriptive_analysis - INFO - num_pigs_notLying: 20 outbreaks, 100 controls, 13 comparisons
# 2025-05-03 09:43:01,504 - tail_posture_descriptive_analysis - INFO - activity: 20 outbreaks, 100 controls, 13 comparisons
# 2025-05-03 09:43:01,505 - tail_posture_descriptive_analysis - INFO - Visualizing behavior metrics analysis...
# 2025-05-03 09:43:01,505 - evaluation.tail_posture_analysis.utils - INFO - Setting plot style: Font=serif, BaseSize=11pt, Format=png, DPI=600
# 2025-05-03 09:43:01,505 - tail_posture_descriptive_analysis - INFO - Creating visualization for num_pigs_lying
# /home/jan-hendrik/home/PigMonitoringResearch/evaluation/activity_analysis/visualization.py:404: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7fa52b9b50a0> has a label of '_child21' which cannot be automatically added to the legend.
#   ax3.legend(handles=legend_handles_traj, loc='best', frameon=True, facecolor='white',
# 2025-05-03 09:43:03,316 - tail_posture_descriptive_analysis - INFO - Saved num_pigs_lying visualization to results_activity_evaluation/behavior_analysis_num_pigs_lying.png
# 2025-05-03 09:43:03,317 - tail_posture_descriptive_analysis - INFO - Creating visualization for num_pigs_notLying
# /home/jan-hendrik/home/PigMonitoringResearch/evaluation/activity_analysis/visualization.py:404: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7fa52b663af0> has a label of '_child21' which cannot be automatically added to the legend.
#   ax3.legend(handles=legend_handles_traj, loc='best', frameon=True, facecolor='white',
# 2025-05-03 09:43:05,043 - tail_posture_descriptive_analysis - INFO - Saved num_pigs_notLying visualization to results_activity_evaluation/behavior_analysis_num_pigs_notLying.png
# 2025-05-03 09:43:05,044 - tail_posture_descriptive_analysis - INFO - Creating visualization for activity
# /home/jan-hendrik/home/PigMonitoringResearch/evaluation/activity_analysis/visualization.py:404: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7fa52b327e50> has a label of '_child21' which cannot be automatically added to the legend.
#   ax3.legend(handles=legend_handles_traj, loc='best', frameon=True, facecolor='white',
# 2025-05-03 09:43:06,747 - tail_posture_descriptive_analysis - INFO - Saved activity visualization to results_activity_evaluation/behavior_analysis_activity.png
# 2025-05-03 09:43:06,748 - tail_posture_descriptive_analysis - INFO - Visualizing behavior metrics comparison...
# 2025-05-03 09:43:06,748 - evaluation.tail_posture_analysis.utils - INFO - Setting plot style: Font=serif, BaseSize=11pt, Format=png, DPI=600
# 2025-05-03 09:43:06,749 - tail_posture_descriptive_analysis - INFO - Creating comparison visualization for num_pigs_lying
# 2025-05-03 09:43:08,721 - tail_posture_descriptive_analysis - INFO - Saved num_pigs_lying comparison visualization to results_activity_evaluation/behavior_comparison_num_pigs_lying.png
# 2025-05-03 09:43:08,723 - tail_posture_descriptive_analysis - INFO - Creating comparison visualization for num_pigs_notLying
# 2025-05-03 09:43:10,840 - tail_posture_descriptive_analysis - INFO - Saved num_pigs_notLying comparison visualization to results_activity_evaluation/behavior_comparison_num_pigs_notLying.png
# 2025-05-03 09:43:10,841 - tail_posture_descriptive_analysis - INFO - Creating comparison visualization for activity
# 2025-05-03 09:43:12,779 - tail_posture_descriptive_analysis - INFO - Saved activity comparison visualization to results_activity_evaluation/behavior_comparison_activity.png
# 2025-05-03 09:43:12,781 - tail_posture_descriptive_analysis - INFO - Visualizing lying components (lying vs not lying pigs)...
# 2025-05-03 09:43:12,781 - evaluation.tail_posture_analysis.utils - INFO - Setting plot style: Font=serif, BaseSize=11pt, Format=png, DPI=600
# 2025-05-03 09:43:14,262 - tail_posture_descriptive_analysis - INFO - Saved lying component visualization to results_activity_evaluation/lying_component_analysis.png
# 'results_activity_evaluation/lying_component_analysis.png'
