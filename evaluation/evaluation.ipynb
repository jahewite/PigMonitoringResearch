# %%
import sys
from pathlib import Path
project_root = str(Path.cwd().parent)
if project_root not in sys.path:
 sys.path.append(project_root)

# %%
import pprint

from pipeline.utils.general import load_json_data
from pipeline.utils.path_manager import PathManager
from evaluation.tail_posture_analysis.reporting import TailPostureReporter

path_manager = PathManager()

config = load_json_data('config.json')

pprint.pprint(config, compact=True)
# Out:
# {'analysis_window_days': [1, 3, 5, 7],
#  'comparison_metrics': ['value_at_removal', '1d_window_avg', '3d_window_avg',
#                         '5d_window_avg', '7d_window_avg', '1d_window_slope',
#                         '3d_window_slope', '5d_window_slope', '7d_window_slope',
#                         'abs_change_1d', 'abs_change_3d', 'abs_change_5d',
#                         'abs_change_7d'],
#  'comparison_stats_filename': 'outbreak_vs_control_comparison.csv',
#  'component_analysis_window_days': 10,
#  'component_timepoint_days': [0, 1, 3, 5, 7],
#  'confidence_level': 0.95,
#  'control_components_filename': 'control_posture_components.csv',
#  'control_date_margin': 5,
#  'control_samples_per_pen': 5,
#  'control_stats_filename': 'control_statistics.csv',
#  'days_before_list': [1, 3, 5, 7],
#  'figure_dpi': 600,
#  'max_allowed_consecutive_missing_days': 3,
#  'max_allowed_missing_days_pct': 50.0,
#  'min_control_analysis_dates': 2,
#  'min_control_dates_threshold': 8,
#  'min_outbreaks_for_variation_analysis': 3,
#  'normalize': True,
#  'outbreak_patterns_filename': 'outbreak_patterns.csv',
#  'output_dir': 'results',
#  'pattern_stats_filename': 'pattern_statistics.csv',
#  'posture_components_filename': 'posture_components.csv',
#  'pre_outbreak_stats_filename': 'pre_outbreak_statistics_filtered.csv',
#  'random_seed': 42,
#  'resample_freq': 'D',
#  'significance_level': 0.05,
#  'smoothing_method': 'rolling',
#  'smoothing_strength': 3,
#  'threshold_analysis_filename': 'monitoring_threshold_analysis.json',
#  'variation_accel_quantile': 0.33,
#  'variation_erratic_slope_diff': 0.1,
#  'variation_gradual_slope_diff': 0.05,
#  'variation_max_pens_plot': 6,
#  'variation_slope_quantile': 0.33,
#  'violin_width': 0.4,
#  'viz_comparison_filename': 'outbreak_vs_control_comparison.png',
#  'viz_completeness_filename': 'data_completeness_timeline.png',
#  'viz_components_filename': 'posture_component_analysis.png',
#  'viz_pre_outbreak_filename': 'descriptive_pre_outbreak_patterns.png',
#  'viz_variation_filename': 'individual_variation_analysis.png'}

# %%
# Create an analyzer instance
analyzer = TailPostureReporter(config)

# Run the complete analysis pipeline
analyzer.run_complete_analysis()
# Out:
# 2025-05-02 21:28:23,356 - tail_posture_descriptive_analysis - INFO - Saved configuration to results/analysis_config.txt
# 2025-05-02 21:28:23,357 - evaluation.tail_posture_analysis.utils - INFO - Setting plot style: Font=serif, BaseSize=11pt, Format=png, DPI=600
# 2025-05-02 21:28:23,357 - tail_posture_descriptive_analysis - INFO - Dissertation quality plotting style set.
# 2025-05-02 21:28:23,357 - tail_posture_descriptive_analysis - INFO - Running DESCRIPTIVE tail posture analysis pipeline...
# 2025-05-02 21:28:23,358 - tail_posture_descriptive_analysis - INFO - Loading monitoring pipeline data...
# 2025-05-02 21:28:30,051 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera5/221004_221104: [datetime.date(2022, 11, 3)]
# 2025-05-02 21:28:32,178 - data_analysis_utils - WARNING - Missing 17 day(s) for Kamera5/220510_220529: [datetime.date(2022, 5, 10), datetime.date(2022, 5, 12), datetime.date(2022, 5, 14), datetime.date(2022, 5, 15), datetime.date(2022, 5, 16), datetime.date(2022, 5, 18), datetime.date(2022, 5, 19), datetime.date(2022, 5, 20), datetime.date(2022, 5, 21), datetime.date(2022, 5, 22), datetime.date(2022, 5, 23), datetime.date(2022, 5, 24), datetime.date(2022, 5, 25), datetime.date(2022, 5, 26), datetime.date(2022, 5, 27), datetime.date(2022, 5, 28), datetime.date(2022, 5, 29)]
# 2025-05-02 21:28:32,190 - data_analysis_utils - WARNING - Dataframe became empty after time filtering: /home/jan-hendrik/home/PigMonitoringResearch/pipeline_outputs/monitoring_pipeline/piglet_rearing/Kamera5/220510_220529/Kamera5_2022_05_11_08_18_23-09_18_23.csv. Skipping.
# 2025-05-02 21:28:32,202 - data_analysis_utils - WARNING - Dataframe became empty after time filtering: /home/jan-hendrik/home/PigMonitoringResearch/pipeline_outputs/monitoring_pipeline/piglet_rearing/Kamera5/220510_220529/Kamera5_2022_05_13_08_18_21-09_18_21.csv. Skipping.
# 2025-05-02 21:28:32,217 - data_analysis_utils - WARNING - Loaded 1 non-empty dataframes out of 3 found CSVs for Kamera5/220510_220529.
# 2025-05-02 21:28:32,218 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera5/221219_230126: [datetime.date(2023, 1, 26)]
# 2025-05-02 21:28:34,964 - data_analysis_utils - WARNING - Missing 7 day(s) for Kamera5/220228_220407: [datetime.date(2022, 4, 1), datetime.date(2022, 4, 2), datetime.date(2022, 4, 3), datetime.date(2022, 4, 4), datetime.date(2022, 4, 5), datetime.date(2022, 4, 6), datetime.date(2022, 4, 7)]
# 2025-05-02 21:28:36,986 - data_analysis_utils - WARNING - Missing 6 day(s) for Kamera5/230227_230406: [datetime.date(2023, 3, 8), datetime.date(2023, 3, 9), datetime.date(2023, 3, 10), datetime.date(2023, 3, 11), datetime.date(2023, 3, 12), datetime.date(2023, 3, 13)]
# 2025-05-02 21:28:39,349 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera1/211228_220119: [datetime.date(2022, 1, 1)]
# 2025-05-02 21:28:40,791 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera1/221003_221106: [datetime.date(2022, 11, 3)]
# 2025-05-02 21:28:52,782 - data_analysis_utils - WARNING - Missing 25 day(s) for Kamera1/220505_220530: [datetime.date(2022, 5, 5), datetime.date(2022, 5, 6), datetime.date(2022, 5, 7), datetime.date(2022, 5, 8), datetime.date(2022, 5, 9), datetime.date(2022, 5, 10), datetime.date(2022, 5, 11), datetime.date(2022, 5, 12), datetime.date(2022, 5, 13), datetime.date(2022, 5, 14), datetime.date(2022, 5, 16), datetime.date(2022, 5, 17), datetime.date(2022, 5, 18), datetime.date(2022, 5, 19), datetime.date(2022, 5, 20), datetime.date(2022, 5, 21), datetime.date(2022, 5, 22), datetime.date(2022, 5, 23), datetime.date(2022, 5, 24), datetime.date(2022, 5, 25), datetime.date(2022, 5, 26), datetime.date(2022, 5, 27), datetime.date(2022, 5, 28), datetime.date(2022, 5, 29), datetime.date(2022, 5, 30)]
# 2025-05-02 21:28:55,556 - data_analysis_utils - WARNING - Missing 2 day(s) for Kamera6/221003_221107: [datetime.date(2022, 11, 3), datetime.date(2022, 11, 7)]
# 2025-05-02 21:28:57,701 - data_analysis_utils - WARNING - Missing 6 day(s) for Kamera6/211230_220120: [datetime.date(2022, 1, 15), datetime.date(2022, 1, 16), datetime.date(2022, 1, 17), datetime.date(2022, 1, 18), datetime.date(2022, 1, 19), datetime.date(2022, 1, 20)]
# 2025-05-02 21:28:58,718 - data_analysis_utils - WARNING - Missing 5 day(s) for Kamera6/220725_220905: [datetime.date(2022, 9, 1), datetime.date(2022, 9, 2), datetime.date(2022, 9, 3), datetime.date(2022, 9, 4), datetime.date(2022, 9, 5)]
# 2025-05-02 21:29:01,182 - data_analysis_utils - WARNING - Missing 21 day(s) for Kamera6/220509_220530: [datetime.date(2022, 5, 9), datetime.date(2022, 5, 10), datetime.date(2022, 5, 12), datetime.date(2022, 5, 13), datetime.date(2022, 5, 14), datetime.date(2022, 5, 15), datetime.date(2022, 5, 16), datetime.date(2022, 5, 17), datetime.date(2022, 5, 18), datetime.date(2022, 5, 19), datetime.date(2022, 5, 20), datetime.date(2022, 5, 21), datetime.date(2022, 5, 22), datetime.date(2022, 5, 23), datetime.date(2022, 5, 24), datetime.date(2022, 5, 25), datetime.date(2022, 5, 26), datetime.date(2022, 5, 27), datetime.date(2022, 5, 28), datetime.date(2022, 5, 29), datetime.date(2022, 5, 30)]
# 2025-05-02 21:29:01,197 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera6/221219_230126: [datetime.date(2023, 1, 26)]
# 2025-05-02 21:29:03,922 - data_analysis_utils - WARNING - Missing 6 day(s) for Kamera6/220228_220407: [datetime.date(2022, 3, 31), datetime.date(2022, 4, 1), datetime.date(2022, 4, 3), datetime.date(2022, 4, 4), datetime.date(2022, 4, 6), datetime.date(2022, 4, 7)]
# 2025-05-02 21:29:05,970 - data_analysis_utils - WARNING - Missing 4 day(s) for Kamera6/230515_230622: [datetime.date(2023, 6, 18), datetime.date(2023, 6, 19), datetime.date(2023, 6, 20), datetime.date(2023, 6, 22)]
# 2025-05-02 21:29:08,624 - data_analysis_utils - WARNING - Missing 6 day(s) for Kamera6/230227_230406: [datetime.date(2023, 3, 8), datetime.date(2023, 3, 9), datetime.date(2023, 3, 10), datetime.date(2023, 3, 11), datetime.date(2023, 3, 12), datetime.date(2023, 3, 13)]
# 2025-05-02 21:29:12,490 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera2/221003_221106: [datetime.date(2022, 11, 3)]
# 2025-05-02 21:29:24,727 - data_analysis_utils - WARNING - Missing 24 day(s) for Kamera2/220505_220530: [datetime.date(2022, 5, 5), datetime.date(2022, 5, 6), datetime.date(2022, 5, 7), datetime.date(2022, 5, 8), datetime.date(2022, 5, 9), datetime.date(2022, 5, 10), datetime.date(2022, 5, 12), datetime.date(2022, 5, 13), datetime.date(2022, 5, 14), datetime.date(2022, 5, 16), datetime.date(2022, 5, 17), datetime.date(2022, 5, 18), datetime.date(2022, 5, 19), datetime.date(2022, 5, 20), datetime.date(2022, 5, 21), datetime.date(2022, 5, 22), datetime.date(2022, 5, 23), datetime.date(2022, 5, 24), datetime.date(2022, 5, 25), datetime.date(2022, 5, 26), datetime.date(2022, 5, 27), datetime.date(2022, 5, 28), datetime.date(2022, 5, 29), datetime.date(2022, 5, 30)]
# 2025-05-02 21:29:27,539 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera4/221226_230126: [datetime.date(2023, 1, 26)]
# 2025-05-02 21:29:29,838 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera4/221003_221106: [datetime.date(2022, 11, 3)]
# 2025-05-02 21:29:36,223 - data_analysis_utils - WARNING - Missing 16 day(s) for Kamera4/220725_220905: [datetime.date(2022, 8, 21), datetime.date(2022, 8, 22), datetime.date(2022, 8, 23), datetime.date(2022, 8, 24), datetime.date(2022, 8, 25), datetime.date(2022, 8, 26), datetime.date(2022, 8, 27), datetime.date(2022, 8, 28), datetime.date(2022, 8, 29), datetime.date(2022, 8, 30), datetime.date(2022, 8, 31), datetime.date(2022, 9, 1), datetime.date(2022, 9, 2), datetime.date(2022, 9, 3), datetime.date(2022, 9, 4), datetime.date(2022, 9, 5)]
# 2025-05-02 21:29:37,982 - data_analysis_utils - WARNING - Missing 18 day(s) for Kamera4/220510_220529: [datetime.date(2022, 5, 11), datetime.date(2022, 5, 12), datetime.date(2022, 5, 13), datetime.date(2022, 5, 14), datetime.date(2022, 5, 16), datetime.date(2022, 5, 17), datetime.date(2022, 5, 18), datetime.date(2022, 5, 19), datetime.date(2022, 5, 20), datetime.date(2022, 5, 21), datetime.date(2022, 5, 22), datetime.date(2022, 5, 23), datetime.date(2022, 5, 24), datetime.date(2022, 5, 25), datetime.date(2022, 5, 26), datetime.date(2022, 5, 27), datetime.date(2022, 5, 28), datetime.date(2022, 5, 29)]
# 2025-05-02 21:29:38,013 - data_analysis_utils - WARNING - Missing 7 day(s) for Kamera4/220228_220407: [datetime.date(2022, 3, 31), datetime.date(2022, 4, 1), datetime.date(2022, 4, 3), datetime.date(2022, 4, 4), datetime.date(2022, 4, 5), datetime.date(2022, 4, 6), datetime.date(2022, 4, 7)]
# 2025-05-02 21:29:44,800 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera3/221003_221106: [datetime.date(2022, 11, 3)]
# 2025-05-02 21:29:51,686 - data_analysis_utils - WARNING - Missing 5 day(s) for Kamera3/220725_220905: [datetime.date(2022, 9, 1), datetime.date(2022, 9, 2), datetime.date(2022, 9, 3), datetime.date(2022, 9, 4), datetime.date(2022, 9, 5)]
# 2025-05-02 21:29:54,165 - data_analysis_utils - WARNING - Missing 4 day(s) for Kamera3/221219_230125: [datetime.date(2023, 1, 22), datetime.date(2023, 1, 23), datetime.date(2023, 1, 24), datetime.date(2023, 1, 25)]
# 2025-05-02 21:29:56,614 - data_analysis_utils - WARNING - Missing 24 day(s) for Kamera3/220505_220529: [datetime.date(2022, 5, 5), datetime.date(2022, 5, 6), datetime.date(2022, 5, 7), datetime.date(2022, 5, 8), datetime.date(2022, 5, 9), datetime.date(2022, 5, 10), datetime.date(2022, 5, 11), datetime.date(2022, 5, 12), datetime.date(2022, 5, 13), datetime.date(2022, 5, 14), datetime.date(2022, 5, 15), datetime.date(2022, 5, 16), datetime.date(2022, 5, 18), datetime.date(2022, 5, 19), datetime.date(2022, 5, 20), datetime.date(2022, 5, 21), datetime.date(2022, 5, 22), datetime.date(2022, 5, 23), datetime.date(2022, 5, 24), datetime.date(2022, 5, 25), datetime.date(2022, 5, 26), datetime.date(2022, 5, 27), datetime.date(2022, 5, 28), datetime.date(2022, 5, 29)]
# 2025-05-02 21:29:56,629 - data_analysis_utils - WARNING - Missing 2 day(s) for Kamera3/230227_230406: [datetime.date(2023, 3, 9), datetime.date(2023, 3, 10)]
# 2025-05-02 21:29:59,212 - tail_posture_descriptive_analysis - INFO - Loaded 48 monitoring results in 95.85 seconds
# 2025-05-02 21:29:59,212 - tail_posture_descriptive_analysis - INFO - Dataset contains 6 cameras and 28 datespans.
# 2025-05-02 21:29:59,213 - tail_posture_descriptive_analysis - INFO - Total expected days across all datespans: 1623
# 2025-05-02 21:29:59,213 - tail_posture_descriptive_analysis - INFO - Total missing daily files detected: 214 (13.19%)
# 2025-05-02 21:29:59,213 - tail_posture_descriptive_analysis - INFO - Loaded 48 monitoring results entries.
# 2025-05-02 21:29:59,214 - tail_posture_descriptive_analysis - INFO - Starting preprocessing...
# 2025-05-02 21:29:59,214 - tail_posture_descriptive_analysis - INFO - Preprocessing result 1/48: Kamera1/211228_220119
# 2025-05-02 21:29:59,325 - tail_posture_descriptive_analysis - INFO - Preprocessing result 2/48: Kamera1/220228_220328
# 2025-05-02 21:29:59,460 - tail_posture_descriptive_analysis - INFO - Preprocessing result 3/48: Kamera1/220505_220530
# 2025-05-02 21:29:59,540 - tail_posture_descriptive_analysis - WARNING - Dataset too small for smoothing (length 1). Skipping smoothing.
# 2025-05-02 21:29:59,543 - tail_posture_descriptive_analysis - WARNING - Not enough non-NaN data points (1) for interpolation on Kamera1 - 220505_220530. Skipping.
# 2025-05-02 21:29:59,544 - tail_posture_descriptive_analysis - INFO - Preprocessing result 4/48: Kamera1/220726_220831
# 2025-05-02 21:29:59,710 - tail_posture_descriptive_analysis - INFO - Preprocessing result 5/48: Kamera1/221003_221106
# 2025-05-02 21:29:59,861 - tail_posture_descriptive_analysis - INFO - Preprocessing result 6/48: Kamera1/221219_230125
# 2025-05-02 21:30:00,031 - tail_posture_descriptive_analysis - INFO - Preprocessing result 7/48: Kamera1/230227_230406
# 2025-05-02 21:30:00,204 - tail_posture_descriptive_analysis - INFO - Preprocessing result 8/48: Kamera1/230515_230620
# 2025-05-02 21:30:00,367 - tail_posture_descriptive_analysis - INFO - Preprocessing result 9/48: Kamera2/211227_220119
# 2025-05-02 21:30:00,473 - tail_posture_descriptive_analysis - INFO - Preprocessing result 10/48: Kamera2/220228_220331
# 2025-05-02 21:30:00,611 - tail_posture_descriptive_analysis - INFO - Preprocessing result 11/48: Kamera2/220505_220530
# 2025-05-02 21:30:00,625 - tail_posture_descriptive_analysis - WARNING - Dataset too small for smoothing (length 2). Skipping smoothing.
# 2025-05-02 21:30:00,631 - tail_posture_descriptive_analysis - INFO - Preprocessing result 12/48: Kamera2/220725_220831
# 2025-05-02 21:30:00,799 - tail_posture_descriptive_analysis - INFO - Preprocessing result 13/48: Kamera2/221003_221106
# 2025-05-02 21:30:00,937 - tail_posture_descriptive_analysis - INFO - Preprocessing result 14/48: Kamera2/221219_230125
# 2025-05-02 21:30:01,106 - tail_posture_descriptive_analysis - INFO - Preprocessing result 15/48: Kamera2/230227_230405
# 2025-05-02 21:30:01,484 - tail_posture_descriptive_analysis - INFO - Preprocessing result 16/48: Kamera2/230515_230621
# 2025-05-02 21:30:01,634 - tail_posture_descriptive_analysis - INFO - Preprocessing result 17/48: Kamera3/211222_220119
# 2025-05-02 21:30:01,760 - tail_posture_descriptive_analysis - INFO - Preprocessing result 18/48: Kamera3/220228_220330
# 2025-05-02 21:30:01,892 - tail_posture_descriptive_analysis - INFO - Preprocessing result 19/48: Kamera3/220505_220529
# 2025-05-02 21:30:01,902 - tail_posture_descriptive_analysis - WARNING - Dataset too small for smoothing (length 1). Skipping smoothing.
# 2025-05-02 21:30:01,905 - tail_posture_descriptive_analysis - WARNING - Not enough non-NaN data points (1) for interpolation on Kamera3 - 220505_220529. Skipping.
# 2025-05-02 21:30:01,906 - tail_posture_descriptive_analysis - INFO - Preprocessing result 20/48: Kamera3/220725_220905
# 2025-05-02 21:30:02,066 - tail_posture_descriptive_analysis - INFO - Preprocessing result 21/48: Kamera3/221003_221106
# 2025-05-02 21:30:02,209 - tail_posture_descriptive_analysis - INFO - Preprocessing result 22/48: Kamera3/221219_230125
# 2025-05-02 21:30:02,355 - tail_posture_descriptive_analysis - INFO - Preprocessing result 23/48: Kamera3/230227_230406
# 2025-05-02 21:30:02,513 - tail_posture_descriptive_analysis - INFO - Preprocessing result 24/48: Kamera3/230515_230621
# 2025-05-02 21:30:02,680 - tail_posture_descriptive_analysis - INFO - Preprocessing result 25/48: Kamera4/211229_220119
# 2025-05-02 21:30:02,779 - tail_posture_descriptive_analysis - INFO - Preprocessing result 26/48: Kamera4/220228_220407
# 2025-05-02 21:30:02,915 - tail_posture_descriptive_analysis - INFO - Preprocessing result 27/48: Kamera4/220510_220529
# 2025-05-02 21:30:02,998 - tail_posture_descriptive_analysis - WARNING - Dataset too small for smoothing (length 2). Skipping smoothing.
# 2025-05-02 21:30:03,005 - tail_posture_descriptive_analysis - INFO - Preprocessing result 28/48: Kamera4/220725_220905
# 2025-05-02 21:30:03,123 - tail_posture_descriptive_analysis - INFO - Preprocessing result 29/48: Kamera4/221003_221106
# 2025-05-02 21:30:03,269 - tail_posture_descriptive_analysis - INFO - Preprocessing result 30/48: Kamera4/221226_230126
# 2025-05-02 21:30:03,402 - tail_posture_descriptive_analysis - INFO - Preprocessing result 31/48: Kamera4/230227_230406
# 2025-05-02 21:30:03,577 - tail_posture_descriptive_analysis - INFO - Preprocessing result 32/48: Kamera4/230515_230621
# 2025-05-02 21:30:03,737 - tail_posture_descriptive_analysis - INFO - Preprocessing result 33/48: Kamera5/211231_220119
# 2025-05-02 21:30:03,825 - tail_posture_descriptive_analysis - INFO - Preprocessing result 34/48: Kamera5/220228_220407
# 2025-05-02 21:30:03,970 - tail_posture_descriptive_analysis - INFO - Preprocessing result 35/48: Kamera5/220510_220529
# 2025-05-02 21:30:03,981 - tail_posture_descriptive_analysis - WARNING - Dataset too small for smoothing (length 1). Skipping smoothing.
# 2025-05-02 21:30:03,983 - tail_posture_descriptive_analysis - WARNING - Not enough non-NaN data points (1) for interpolation on Kamera5 - 220510_220529. Skipping.
# 2025-05-02 21:30:03,984 - tail_posture_descriptive_analysis - INFO - Preprocessing result 36/48: Kamera5/220725_220831
# 2025-05-02 21:30:04,150 - tail_posture_descriptive_analysis - INFO - Preprocessing result 37/48: Kamera5/221004_221104
# 2025-05-02 21:30:04,287 - tail_posture_descriptive_analysis - INFO - Preprocessing result 38/48: Kamera5/221219_230126
# 2025-05-02 21:30:04,449 - tail_posture_descriptive_analysis - INFO - Preprocessing result 39/48: Kamera5/230227_230406
# 2025-05-02 21:30:04,592 - tail_posture_descriptive_analysis - INFO - Preprocessing result 40/48: Kamera5/230515_230621
# 2025-05-02 21:30:04,824 - tail_posture_descriptive_analysis - INFO - Preprocessing result 41/48: Kamera6/211230_220120
# 2025-05-02 21:30:04,898 - tail_posture_descriptive_analysis - INFO - Preprocessing result 42/48: Kamera6/220228_220407
# 2025-05-02 21:30:05,039 - tail_posture_descriptive_analysis - INFO - Preprocessing result 43/48: Kamera6/220509_220530
# 2025-05-02 21:30:05,050 - tail_posture_descriptive_analysis - WARNING - Dataset too small for smoothing (length 1). Skipping smoothing.
# 2025-05-02 21:30:05,052 - tail_posture_descriptive_analysis - WARNING - Not enough non-NaN data points (1) for interpolation on Kamera6 - 220509_220530. Skipping.
# 2025-05-02 21:30:05,053 - tail_posture_descriptive_analysis - INFO - Preprocessing result 44/48: Kamera6/220725_220905
# 2025-05-02 21:30:05,212 - tail_posture_descriptive_analysis - INFO - Preprocessing result 45/48: Kamera6/221003_221107
# 2025-05-02 21:30:05,356 - tail_posture_descriptive_analysis - INFO - Preprocessing result 46/48: Kamera6/221219_230126
# 2025-05-02 21:30:05,517 - tail_posture_descriptive_analysis - INFO - Preprocessing result 47/48: Kamera6/230227_230406
# 2025-05-02 21:30:05,661 - tail_posture_descriptive_analysis - INFO - Preprocessing result 48/48: Kamera6/230515_230622
# 2025-05-02 21:30:05,812 - tail_posture_descriptive_analysis - INFO - Preprocessing finished in 6.60 seconds.
# 2025-05-02 21:30:05,812 - tail_posture_descriptive_analysis - INFO - Total processed results after preprocessing: 48
# 2025-05-02 21:30:05,813 - tail_posture_descriptive_analysis - INFO - Analyzing pre-outbreak statistics (using earliest removal date per event)...
# 2025-05-02 21:30:05,813 - tail_posture_descriptive_analysis - INFO - Excluding Kamera1/211228_220119: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:30:05,820 - tail_posture_descriptive_analysis - INFO - Excluding Kamera1/220505_220530 from analysis due to excessive missing days (25/26 = 96.2% > 50.0%)
# 2025-05-02 21:30:05,820 - tail_posture_descriptive_analysis - INFO - Excluding Kamera1/220726_220831: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:30:05,843 - tail_posture_descriptive_analysis - INFO - Excluding Kamera2/211227_220119: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:30:05,844 - tail_posture_descriptive_analysis - INFO - Removal date 2022-04-06 is after last data point for Pen 2. Using last available data point.
# 2025-05-02 21:30:05,850 - tail_posture_descriptive_analysis - INFO - Excluding Kamera2/220505_220530 from analysis due to excessive missing days (24/26 = 92.3% > 50.0%)
# 2025-05-02 21:30:05,850 - tail_posture_descriptive_analysis - INFO - Excluding Kamera2/220725_220831: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:30:05,850 - tail_posture_descriptive_analysis - INFO - Removal date 2022-11-07 is after last data point for Pen 2. Using last available data point.
# 2025-05-02 21:30:05,856 - tail_posture_descriptive_analysis - INFO - Excluding Kamera2/221219_230125: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:30:05,857 - tail_posture_descriptive_analysis - INFO - Excluding Kamera2/230227_230405: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:30:05,863 - tail_posture_descriptive_analysis - INFO - Excluding Kamera3/211222_220119: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:30:05,869 - tail_posture_descriptive_analysis - INFO - Excluding Kamera3/220505_220529 from analysis due to excessive missing days (24/25 = 96.0% > 50.0%)
# 2025-05-02 21:30:05,869 - tail_posture_descriptive_analysis - INFO - Excluding Kamera3/220725_220905: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:30:05,875 - tail_posture_descriptive_analysis - INFO - Excluding Kamera3/221219_230125: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:30:05,876 - tail_posture_descriptive_analysis - INFO - Excluding Kamera3/230227_230406: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:30:05,882 - tail_posture_descriptive_analysis - INFO - Excluding Kamera4/211229_220119: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:30:05,882 - tail_posture_descriptive_analysis - INFO - Excluding Kamera4/220228_220407: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:30:05,883 - tail_posture_descriptive_analysis - INFO - Excluding Kamera4/220510_220529 from analysis due to 4 consecutive missing periods in resampled data (threshold: 3). Raw missing days: 18
# 2025-05-02 21:30:05,883 - tail_posture_descriptive_analysis - INFO - Excluding Kamera4/220725_220905: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:30:05,883 - tail_posture_descriptive_analysis - INFO - Removal date 2022-11-07 is after last data point for Pen 4. Using last available data point.
# 2025-05-02 21:30:05,906 - tail_posture_descriptive_analysis - INFO - Excluding Kamera5/211231_220119: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:30:05,906 - tail_posture_descriptive_analysis - INFO - Excluding Kamera5/220228_220407: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:30:05,907 - tail_posture_descriptive_analysis - INFO - Excluding Kamera5/220510_220529 from analysis due to excessive missing days (17/20 = 85.0% > 50.0%)
# 2025-05-02 21:30:05,918 - tail_posture_descriptive_analysis - INFO - Excluding Kamera5/221219_230126: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:30:05,918 - tail_posture_descriptive_analysis - INFO - Excluding Kamera5/230227_230406 from analysis due to 6 consecutive missing periods in resampled data (threshold: 3). Raw missing days: 6
# 2025-05-02 21:30:05,925 - tail_posture_descriptive_analysis - INFO - Excluding Kamera6/211230_220120: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:30:05,925 - tail_posture_descriptive_analysis - INFO - Excluding Kamera6/220228_220407: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:30:05,925 - tail_posture_descriptive_analysis - INFO - Excluding Kamera6/220509_220530 from analysis due to excessive missing days (21/22 = 95.5% > 50.0%)
# 2025-05-02 21:30:05,926 - tail_posture_descriptive_analysis - INFO - Excluding Kamera6/220725_220905: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:30:05,932 - tail_posture_descriptive_analysis - INFO - Excluding Kamera6/221219_230126: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:30:05,932 - tail_posture_descriptive_analysis - INFO - Excluding Kamera6/230227_230406 from analysis due to 6 consecutive missing periods in resampled data (threshold: 3). Raw missing days: 6
# 2025-05-02 21:30:05,940 - tail_posture_descriptive_analysis - INFO - Attempted to analyze 22 potential tail biting events.
# 2025-05-02 21:30:05,940 - tail_posture_descriptive_analysis - INFO - Successfully analyzed 20 events.
# 2025-05-02 21:30:05,940 - tail_posture_descriptive_analysis - INFO - Excluded 3 events due to >3 consecutive missing days.
# 2025-05-02 21:30:05,941 - tail_posture_descriptive_analysis - INFO - Excluded 5 events due to excessive missing days (>50.0%).
# 2025-05-02 21:30:05,941 - tail_posture_descriptive_analysis - INFO - Excluded -6 events for other reasons (e.g., no valid removal date, empty data).
# 2025-05-02 21:30:05,943 - tail_posture_descriptive_analysis - INFO - Saved descriptive pre-outbreak statistics to results/pre_outbreak_statistics_filtered.csv
# 2025-05-02 21:30:05,944 - tail_posture_descriptive_analysis - INFO - Completed pre-outbreak statistics calculation.
# 2025-05-02 21:30:05,944 - tail_posture_descriptive_analysis - INFO - Excluded 3 outbreak events based on missing data/validity checks.
# 2025-05-02 21:30:05,944 - tail_posture_descriptive_analysis - INFO - Analyzing control pen statistics for comparison...
# 2025-05-02 21:30:05,945 - tail_posture_descriptive_analysis - INFO - Found 26 control pen datasets for analysis
# 2025-05-02 21:30:05,969 - tail_posture_descriptive_analysis - INFO - Excluding control pen Kamera1/220505_220530 due to excessive missing days (25/26 = 96.2% > 50.0%)
# 2025-05-02 21:30:06,016 - tail_posture_descriptive_analysis - INFO - Excluding control pen Kamera2/220505_220530 due to excessive missing days (24/26 = 92.3% > 50.0%)
# 2025-05-02 21:30:06,110 - tail_posture_descriptive_analysis - INFO - Excluding control pen Kamera3/220505_220529 due to excessive missing days (24/25 = 96.0% > 50.0%)
# 2025-05-02 21:30:06,297 - tail_posture_descriptive_analysis - INFO - Excluding control pen Kamera5/220510_220529 due to excessive missing days (17/20 = 85.0% > 50.0%)
# 2025-05-02 21:30:06,321 - tail_posture_descriptive_analysis - INFO - Excluding control pen Kamera5/230227_230406 due to 6 consecutive missing periods in resampled data (threshold: 3). Raw missing days: 6
# 2025-05-02 21:30:06,368 - tail_posture_descriptive_analysis - INFO - Excluding control pen Kamera6/220509_220530 due to excessive missing days (21/22 = 95.5% > 50.0%)
# 2025-05-02 21:30:06,417 - tail_posture_descriptive_analysis - INFO - Analyzed 26 control pens.
# 2025-05-02 21:30:06,418 - tail_posture_descriptive_analysis - INFO - Successfully analyzed 20 control pen datasets (from 6 unique pens) with 100 reference points.
# 2025-05-02 21:30:06,418 - tail_posture_descriptive_analysis - INFO - Excluded 1 control pens due to >3 consecutive missing days.
# 2025-05-02 21:30:06,419 - tail_posture_descriptive_analysis - INFO - Excluded 5 control pens due to excessive missing days (>50.0%).
# 2025-05-02 21:30:06,424 - tail_posture_descriptive_analysis - INFO - Saved control pen statistics to results/control_statistics.csv
# 2025-05-02 21:30:06,425 - tail_posture_descriptive_analysis - INFO - Completed control pen statistics calculation.
# 2025-05-02 21:30:06,425 - tail_posture_descriptive_analysis - INFO - Analyzing individual variation in outbreak patterns...
# 2025-05-02 21:30:06,428 - tail_posture_descriptive_analysis - INFO - Pattern categorization counts: {'Gradual-decline': 7, 'Sudden-decline': 5, 'Moderate-decline': 5, 'Erratic-decline': 3}
# 2025-05-02 21:30:06,430 - tail_posture_descriptive_analysis - INFO - Pen consistency (excluding 'Undefined'): 0/6 pens (0.0%) have consistent pattern categories.
# 2025-05-02 21:30:06,433 - tail_posture_descriptive_analysis - INFO - Successfully calculated pattern statistics.
# 2025-05-02 21:30:06,435 - tail_posture_descriptive_analysis - INFO - Saved outbreak pattern analysis to results/outbreak_patterns.csv
# 2025-05-02 21:30:06,436 - tail_posture_descriptive_analysis - INFO - Saved pattern statistics to results/pattern_statistics.csv
# 2025-05-02 21:30:06,436 - tail_posture_descriptive_analysis - INFO - Completed individual outbreak pattern analysis.
# 2025-05-02 21:30:06,437 - tail_posture_descriptive_analysis - INFO - Analyzing individual posture components (upright vs. hanging tails)...
# 2025-05-02 21:30:06,700 - tail_posture_descriptive_analysis - INFO - Saved posture component data to results/posture_components.csv
# 2025-05-02 21:30:06,708 - tail_posture_descriptive_analysis - INFO - Saved control posture component data to results/control_posture_components.csv
# 2025-05-02 21:30:06,708 - tail_posture_descriptive_analysis - INFO - Completed posture component analysis (upright vs. hanging tails).
# 2025-05-02 21:30:06,709 - tail_posture_descriptive_analysis - ERROR - Error during analyze_and_identify_monitoring_thresholds: 'TailPostureReporter' object has no attribute 'analyze_and_identify_monitoring_thresholds'
# Traceback (most recent call last):
#   File "/home/jan-hendrik/home/PigMonitoringResearch/evaluation/tail_posture_analysis/reporting.py", line 1474, in run_complete_analysis
#     threshold_analysis = self.analyze_and_identify_monitoring_thresholds()
# AttributeError: 'TailPostureReporter' object has no attribute 'analyze_and_identify_monitoring_thresholds'
# 2025-05-02 21:30:06,709 - tail_posture_descriptive_analysis - ERROR - No validation results available. Run validate_monitoring_thresholds() first.
# 2025-05-02 21:30:06,710 - tail_posture_descriptive_analysis - INFO - Visualizing data completeness across all events (enhanced version with exclusions)...
# 2025-05-02 21:30:06,710 - evaluation.tail_posture_analysis.utils - INFO - Setting plot style: Font=serif, BaseSize=11pt, Format=png, DPI=600
# 2025-05-02 21:30:06,716 - tail_posture_descriptive_analysis - INFO - Marked for consecutive exclusion: Kamera4/220510_220529 (pen 4)
# 2025-05-02 21:30:06,716 - tail_posture_descriptive_analysis - INFO - Marked for consecutive exclusion: Kamera5/230227_230406 (pen 5)
# 2025-05-02 21:30:06,716 - tail_posture_descriptive_analysis - INFO - Marked for consecutive exclusion: Kamera6/230227_230406 (pen 6)
# 2025-05-02 21:30:06,717 - tail_posture_descriptive_analysis - INFO - Marked for consecutive exclusion: Kamera5/230227_230406 (pen 5)
# 2025-05-02 21:30:06,717 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion: Kamera1/220505_220530 (pen 1)
# 2025-05-02 21:30:06,718 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion: Kamera2/220505_220530 (pen 2)
# 2025-05-02 21:30:06,718 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion: Kamera3/220505_220529 (pen 3)
# 2025-05-02 21:30:06,718 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion: Kamera5/220510_220529 (pen 5)
# 2025-05-02 21:30:06,718 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion: Kamera6/220509_220530 (pen 6)
# 2025-05-02 21:30:06,719 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion: Kamera1/220505_220530 (pen 1)
# 2025-05-02 21:30:06,719 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion: Kamera2/220505_220530 (pen 2)
# 2025-05-02 21:30:06,720 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion: Kamera3/220505_220529 (pen 3)
# 2025-05-02 21:30:06,720 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion: Kamera5/220510_220529 (pen 5)
# 2025-05-02 21:30:06,720 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion: Kamera6/220509_220530 (pen 6)
# 2025-05-02 21:30:06,720 - tail_posture_descriptive_analysis - INFO - Marked for consecutive exclusion from tail_biting_analysis: Kamera4/220510_220529 (pen 4)
# 2025-05-02 21:30:06,721 - tail_posture_descriptive_analysis - INFO - Marked for consecutive exclusion from tail_biting_analysis: Kamera5/230227_230406 (pen 5)
# 2025-05-02 21:30:06,721 - tail_posture_descriptive_analysis - INFO - Marked for consecutive exclusion from tail_biting_analysis: Kamera6/230227_230406 (pen 6)
# 2025-05-02 21:30:06,721 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion from tail_biting_analysis: Kamera1/220505_220530 (pen 1)
# 2025-05-02 21:30:06,722 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion from tail_biting_analysis: Kamera2/220505_220530 (pen 2)
# 2025-05-02 21:30:06,722 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion from tail_biting_analysis: Kamera3/220505_220529 (pen 3)
# 2025-05-02 21:30:06,722 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion from tail_biting_analysis: Kamera5/220510_220529 (pen 5)
# 2025-05-02 21:30:06,723 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion from tail_biting_analysis: Kamera6/220509_220530 (pen 6)
# 2025-05-02 21:30:06,723 - tail_posture_descriptive_analysis - INFO - Marked for consecutive exclusion from control_analysis: Kamera5/230227_230406 (pen 5)
# 2025-05-02 21:30:06,724 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion from control_analysis: Kamera1/220505_220530 (pen 1)
# 2025-05-02 21:30:06,724 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion from control_analysis: Kamera2/220505_220530 (pen 2)
# 2025-05-02 21:30:06,724 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion from control_analysis: Kamera3/220505_220529 (pen 3)
# 2025-05-02 21:30:06,724 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion from control_analysis: Kamera5/220510_220529 (pen 5)
# 2025-05-02 21:30:06,725 - tail_posture_descriptive_analysis - INFO - Marked for percentage exclusion from control_analysis: Kamera6/220509_220530 (pen 6)
# 2025-05-02 21:30:06,770 - tail_posture_descriptive_analysis - INFO - Highlighting consecutive exclusion: Kamera4/220510_220529
# 2025-05-02 21:30:06,783 - tail_posture_descriptive_analysis - INFO - Highlighting consecutive exclusion: Kamera6/230227_230406
# 2025-05-02 21:30:06,797 - tail_posture_descriptive_analysis - INFO - Highlighting percentage exclusion: Kamera1/220505_220530
# 2025-05-02 21:30:06,799 - tail_posture_descriptive_analysis - INFO - Highlighting percentage exclusion: Kamera2/220505_220530
# 2025-05-02 21:30:06,801 - tail_posture_descriptive_analysis - INFO - Highlighting percentage exclusion: Kamera3/220505_220529
# 2025-05-02 21:30:06,803 - tail_posture_descriptive_analysis - INFO - Highlighting percentage exclusion: Kamera6/220509_220530
# 2025-05-02 21:30:06,805 - tail_posture_descriptive_analysis - INFO - Highlighting percentage exclusion: Kamera5/220510_220529
# 2025-05-02 21:30:06,815 - tail_posture_descriptive_analysis - INFO - Highlighting consecutive exclusion: Kamera5/230227_230406
# 2025-05-02 21:30:08,340 - tail_posture_descriptive_analysis - INFO - Saved enhanced data completeness visualization with exclusion highlighting to results/data_completeness_timeline.png
# 2025-05-02 21:30:08,341 - tail_posture_descriptive_analysis - INFO - Created data completeness visualization: results/data_completeness_timeline.png
# 2025-05-02 21:30:08,342 - tail_posture_descriptive_analysis - INFO - Visualizing descriptive pre-outbreak patterns...
# 2025-05-02 21:30:08,342 - evaluation.tail_posture_analysis.utils - INFO - Setting plot style: Font=serif, BaseSize=11pt, Format=png, DPI=600
# /home/jan-hendrik/home/PigMonitoringResearch/evaluation/tail_posture_analysis/visualization.py:371: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7f1e11e829a0> has a label of '_child21' which cannot be automatically added to the legend.
#   ax2.legend(handles=legend_handles_traj, loc='lower left', frameon=True, facecolor='white', edgecolor=COLORS.get('grid', 'lightgrey'), fontsize=9)
# 2025-05-02 21:30:10,286 - tail_posture_descriptive_analysis - INFO - Saved pre-outbreak pattern visualization to results/descriptive_pre_outbreak_patterns.png
# 2025-05-02 21:30:10,287 - tail_posture_descriptive_analysis - INFO - Created descriptive pre-outbreak patterns visualization: results/descriptive_pre_outbreak_patterns.png
# 2025-05-02 21:30:10,287 - tail_posture_descriptive_analysis - INFO - Visualizing comparison between outbreak and control pens...
# 2025-05-02 21:30:10,288 - evaluation.tail_posture_analysis.utils - INFO - Setting plot style: Font=serif, BaseSize=11pt, Format=png, DPI=600
# 2025-05-02 21:30:10,399 - tail_posture_descriptive_analysis - INFO - Comparing outbreak vs control pen statistics...
# 2025-05-02 21:30:10,400 - tail_posture_descriptive_analysis - INFO - Comparison for value_at_removal: Outbreak=-0.036±0.367, Control=0.734±0.113, p=0.0000, Significant=True, Effect Size=4.28
# 2025-05-02 21:30:10,401 - tail_posture_descriptive_analysis - INFO - Comparison for 1d_window_avg: Outbreak=0.022±0.367, Control=0.734±0.109, p=0.0000, Significant=True, Effect Size=4.00
# 2025-05-02 21:30:10,403 - tail_posture_descriptive_analysis - INFO - Comparison for 3d_window_avg: Outbreak=0.162±0.364, Control=0.734±0.104, p=0.0000, Significant=True, Effect Size=3.28
# 2025-05-02 21:30:10,404 - tail_posture_descriptive_analysis - INFO - Comparison for 5d_window_avg: Outbreak=0.288±0.343, Control=0.732±0.102, p=0.0000, Significant=True, Effect Size=2.67
# 2025-05-02 21:30:10,405 - tail_posture_descriptive_analysis - INFO - Comparison for 7d_window_avg: Outbreak=0.383±0.297, Control=0.727±0.103, p=0.0000, Significant=True, Effect Size=2.27
# 2025-05-02 21:30:10,407 - tail_posture_descriptive_analysis - INFO - Comparison for 1d_window_slope: Outbreak=-0.122±0.124, Control=-0.000±0.032, p=0.0000, Significant=True, Effect Size=2.11
# 2025-05-02 21:30:10,408 - tail_posture_descriptive_analysis - INFO - Comparison for 3d_window_slope: Outbreak=-0.140±0.118, Control=-0.000±0.026, p=0.0000, Significant=True, Effect Size=2.66
# 2025-05-02 21:30:10,409 - tail_posture_descriptive_analysis - INFO - Comparison for 5d_window_slope: Outbreak=-0.127±0.089, Control=0.002±0.020, p=0.0000, Significant=True, Effect Size=3.20
# 2025-05-02 21:30:10,410 - tail_posture_descriptive_analysis - INFO - Comparison for 7d_window_slope: Outbreak=-0.106±0.062, Control=0.004±0.017, p=0.0000, Significant=True, Effect Size=3.73
# 2025-05-02 21:30:10,411 - tail_posture_descriptive_analysis - INFO - Comparison for abs_change_1d: Outbreak=-0.122±0.124, Control=-0.000±0.032, p=0.0000, Significant=True, Effect Size=2.11
# 2025-05-02 21:30:10,413 - tail_posture_descriptive_analysis - INFO - Comparison for abs_change_3d: Outbreak=-0.408±0.340, Control=0.000±0.076, p=0.0000, Significant=True, Effect Size=2.67
# 2025-05-02 21:30:10,414 - tail_posture_descriptive_analysis - INFO - Comparison for abs_change_5d: Outbreak=-0.598±0.367, Control=0.013±0.097, p=0.0000, Significant=True, Effect Size=3.55
# 2025-05-02 21:30:10,415 - tail_posture_descriptive_analysis - INFO - Comparison for abs_change_7d: Outbreak=-0.713±0.355, Control=0.028±0.119, p=0.0000, Significant=True, Effect Size=4.04
# 2025-05-02 21:30:10,416 - tail_posture_descriptive_analysis - INFO - Saved outbreak vs control comparison to results/outbreak_vs_control_comparison.csv
# 2025-05-02 21:30:12,247 - tail_posture_descriptive_analysis - INFO - Saved outbreak vs control comparison visualization to results/outbreak_vs_control_comparison.png
# 2025-05-02 21:30:12,248 - tail_posture_descriptive_analysis - INFO - Created outbreak vs control comparison visualization: results/outbreak_vs_control_comparison.png
# 2025-05-02 21:30:12,248 - tail_posture_descriptive_analysis - WARNING - Skipping control comparison visualization and table generation due to missing outbreak or control statistics.
# 2025-05-02 21:30:12,249 - tail_posture_descriptive_analysis - INFO - Visualizing individual variation in outbreak patterns...
# 2025-05-02 21:30:12,249 - evaluation.tail_posture_analysis.utils - INFO - Setting plot style: Font=serif, BaseSize=11pt, Format=png, DPI=600
# 2025-05-02 21:30:13,968 - tail_posture_descriptive_analysis - INFO - Saved individual variation visualization to results/individual_variation_analysis.png
# 2025-05-02 21:30:13,969 - tail_posture_descriptive_analysis - INFO - Created individual variation visualization: results/individual_variation_analysis.png
# 2025-05-02 21:30:13,970 - tail_posture_descriptive_analysis - INFO - Visualizing posture components (upright vs. hanging tails)...
# 2025-05-02 21:30:13,970 - evaluation.tail_posture_analysis.utils - INFO - Setting plot style: Font=serif, BaseSize=11pt, Format=png, DPI=600
# 2025-05-02 21:30:15,333 - tail_posture_descriptive_analysis - INFO - Saved posture component visualization to results/posture_component_analysis.png
# 2025-05-02 21:30:15,334 - tail_posture_descriptive_analysis - INFO - Created posture component visualization: results/posture_component_analysis.png
# 2025-05-02 21:30:15,334 - tail_posture_descriptive_analysis - INFO - Generating descriptive summary report...
# 2025-05-02 21:30:15,389 - tail_posture_descriptive_analysis - INFO - Saved summary report to results/analysis_summary_report.txt
# 2025-05-02 21:30:15,390 - tail_posture_descriptive_analysis - INFO - Generated descriptive summary report.
# 2025-05-02 21:30:15,390 - tail_posture_descriptive_analysis - INFO - Descriptive analysis pipeline finished.
# {'dataset': {'num_cameras': 6,
#   'num_datespans_loaded': 48,
#   'relative_removal_positions': {'first_quintile': 0,
#    'second_quintile': 1,
#    'third_quintile': 4,
#    'fourth_quintile': 7,
#    'fifth_quintile': 20},
#   'removal_position_stats': {'avg_position_pct': 84.96483152714428,
#    'median_position_pct': 85.29411764705881,
#    'min_position_pct': 35.13513513513514,
#    'max_position_pct': 168.42105263157893},
#   'removal_date_range': {'first': datetime.date(2022, 3, 23),
#    'last': datetime.date(2023, 6, 19),
#    'span_days': 453},
#   'removal_dates_quarterly': {'2022Q1': 3,
#    '2022Q2': 3,
#    '2022Q3': 1,
#    '2022Q4': 9,
#    '2023Q1': 5,
#    '2023Q2': 11},
#   'removals_per_pen': {'min': 1,
#    'max': 4,
#    'avg': 1.4545454545454546,
#    'total_removals': 32,
#    'pens_with_multiple': 8},
#   'datespan_coverage': {'avg_pct': 85.41666666666669,
#    'min_pct': 51.28205128205128,
#    'max_pct': 100.0,
#    'full_coverage_count': 14},
#   'date_range': {'min': datetime.date(2021, 12, 22),
#    'max': datetime.date(2023, 6, 22),
#    'span_days': 547},
#   'reference_date_range': {'min': datetime.date(2021, 12, 13),
#    'max': datetime.date(2023, 6, 22),
#    'span_days': 556},
#   'pen_types_loaded': {'control': 26, 'tail biting': 22},
#   'total_tb_pens': 22,
#   'total_control_pens': 26},
#  'data_quality': {'total_processed_events': 48,
#   'total_expected_days': 1623,
#   'total_missing_days_files': 214,
#   'overall_missing_days_pct': 13.185459026494147,
#   'total_gt_expected_days': 1872,
#   'total_gt_available_days': 1623,
#   'total_gt_missing_days': 273,
#   'overall_gt_missing_days_pct': 14.583333333333334,
#   'incomplete_camera_datespans': 34,
#   'incomplete_camera_datespans_pct': 70.83333333333334,
#   'missing_days_within_datespan': 214,
#   'missing_days_within_datespan_pct': 13.185459026494147,
#   'avg_missing_days_per_datespan': 4.458333333333333,
#   'min_missing_days_per_datespan': 0,
#   'max_missing_days_per_datespan': 25,
#   'median_missing_days_per_datespan': 1.0,
#   'avg_missing_raw_seconds_pct': 1.3888888888888886,
#   'avg_missing_resampled_periods_pct': 2.3373332459609633,
#   'avg_max_consecutive_missing_resampled': 0.7291666666666666,
#   'events_excluded_for_consecutive_missing': 3,
#   'events_excluded_for_missing_pct': 5,
#   'total_events_excluded_for_missing_data': 8,
#   'missing_data_exclusion_threshold_days': 3,
#   'missing_data_exclusion_threshold_pct': 50.0,
#   'interpolation_method': 'linear'},
#  'outbreak_analysis': {'num_outbreaks_analyzed': 20,
#   'num_pens_analyzed': 6,
#   'value_at_removal': {'count': 20,
#    'mean': -0.03606547010599507,
#    'median': -0.1096846213820207,
#    'std': 0.36664325427308275,
#    'p25': -0.31972834633497776,
#    'p10': -0.4034071822687822},
#   'value_1d_before': {'mean': 0.08544727640479541,
#    'median': 0.07997220673780936,
#    'std': 0.37808209117157243},
#   'value_3d_before': {'mean': 0.372240847676038,
#    'median': 0.4717762473615317,
#    'std': 0.3993857742954584},
#   'value_5d_before': {'mean': 0.561703575799606,
#    'median': 0.6739943655366826,
#    'std': 0.2901343493363984},
#   'value_7d_before': {'mean': 0.6765219585396701,
#    'median': 0.7486493797978429,
#    'std': 0.18086122859876208},
#   'absolute_change': {'1d': {'mean': -0.12151274651079044,
#     'median': -0.10426955874801808,
#     'std': 0.12384301118890569},
#    '3d': {'mean': -0.408306317782033,
#     'median': -0.49117555545635844,
#     'std': 0.33962277486611875},
#    '7d': {'mean': -0.7125874286456652,
#     'median': -0.7569011764456728,
#     'std': 0.3545782683968346}},
#   'percentage_change': {'1d': {'mean': -80.70658053920994,
#     'median': -32.17969390468352,
#     'std': 88.57195660618105},
#    '3d': {'mean': -117.86005675045207,
#     'median': -184.1253805929329,
#     'std': 92.84325119988966},
#    '7d': {'mean': -154.8402009967075,
#     'median': -200.0,
#     'std': 69.72214024698297}},
#   'window_stats': {'3d_window': {'avg': {'mean': 0.1621932999313908,
#      'median': 0.17627285997517686,
#      'std': 0.36375597806457444},
#     'slope': {'mean': -0.1404628510879117,
#      'median': -0.1649196655371164,
#      'std': 0.11761528709300462,
#      'percent_significant': 100.0,
#      'alpha_level': 0.05}},
#    '7d_window': {'avg': {'mean': 0.38343077319294194,
#      'median': 0.4200851633933799,
#      'std': 0.2971330110407575},
#     'slope': {'mean': -0.10623019003081806,
#      'median': -0.11652766671225534,
#      'std': 0.06205869744303334,
#      'percent_significant': 100.0,
#      'alpha_level': 0.05}}}},
#  'control_comparison': {'num_control_pens_analyzed': 6,
#   'num_control_reference_points': 100,
#   'comparison_results': {'value_at_removal': {'outbreak_mean': -0.03606547010599507,
#     'outbreak_std': 0.36664325427308275,
#     'control_mean': 0.7341149973424401,
#     'control_std': 0.11289318532345068,
#     'p_value': 1.2208643991929289e-11,
#     'is_significant': True,
#     'effect_size': 4.282893342377059},
#    '1d_window_avg': {'outbreak_mean': 0.022159387597092028,
#     'outbreak_std': 0.36698989199239196,
#     'control_mean': 0.7341331933777375,
#     'control_std': 0.10876100019992124,
#     'p_value': 3.8766250318547576e-11,
#     'is_significant': True,
#     'effect_size': 4.004512349717103},
#    '3d_window_avg': {'outbreak_mean': 0.1621932999313908,
#     'outbreak_std': 0.36375597806457444,
#     'control_mean': 0.7342290343908923,
#     'control_std': 0.1042774451013088,
#     'p_value': 4.1154007644504806e-10,
#     'is_significant': True,
#     'effect_size': 3.2793169680550136},
#    '5d_window_avg': {'outbreak_mean': 0.28753053294844866,
#     'outbreak_std': 0.34250384651538646,
#     'control_mean': 0.732089126532346,
#     'control_std': 0.10229586235060051,
#     'p_value': 1.0561708164563014e-08,
#     'is_significant': True,
#     'effect_size': 2.6726278062910263},
#    '7d_window_avg': {'outbreak_mean': 0.38343077319294194,
#     'outbreak_std': 0.2971330110407575,
#     'control_mean': 0.7274179871761061,
#     'control_std': 0.10263876235113936,
#     'p_value': 1.5238608571450116e-07,
#     'is_significant': True,
#     'effect_size': 2.2655110010816997},
#    '1d_window_slope': {'outbreak_mean': -0.1215127465107904,
#     'outbreak_std': 0.12384301118890563,
#     'control_mean': -3.79743345337083e-05,
#     'control_std': 0.03170981996320333,
#     'p_value': 3.8562964964391644e-05,
#     'is_significant': True,
#     'effect_size': 2.1104069799352376},
#    '3d_window_slope': {'outbreak_mean': -0.1404628510879117,
#     'outbreak_std': 0.11761528709300462,
#     'control_mean': -2.350236127499173e-05,
#     'control_std': 0.0257163413613803,
#     'p_value': 8.712583458869187e-07,
#     'is_significant': True,
#     'effect_size': 2.662507035270571},
#    '5d_window_slope': {'outbreak_mean': -0.12668805560657254,
#     'outbreak_std': 0.0890870081057146,
#     'control_mean': 0.0019265990130011203,
#     'control_std': 0.02014334967569718,
#     'p_value': 2.0813722317153397e-10,
#     'is_significant': True,
#     'effect_size': 3.197103724684297},
#    '7d_window_slope': {'outbreak_mean': -0.10623019003081806,
#     'outbreak_std': 0.06205869744303334,
#     'control_mean': 0.0038744191398375678,
#     'control_std': 0.017297886559841623,
#     'p_value': 8.254726095146849e-12,
#     'is_significant': True,
#     'effect_size': 3.7304106904691654},
#    'abs_change_1d': {'outbreak_mean': -0.12151274651079044,
#     'outbreak_std': 0.12384301118890569,
#     'control_mean': -3.7974334533708575e-05,
#     'control_std': 0.03170981996320334,
#     'p_value': 3.8562964964391644e-05,
#     'is_significant': True,
#     'effect_size': 2.1104069799352376},
#    'abs_change_3d': {'outbreak_mean': -0.408306317782033,
#     'outbreak_std': 0.33962277486611875,
#     'control_mean': 0.0002792244715628811,
#     'control_std': 0.07562425438361069,
#     'p_value': 3.761456426273412e-07,
#     'is_significant': True,
#     'effect_size': 2.6726955356225157},
#    'abs_change_5d': {'outbreak_mean': -0.597769045905601,
#     'outbreak_std': 0.3666410894344907,
#     'control_mean': 0.012633820414701926,
#     'control_std': 0.09749535333277186,
#     'p_value': 1.8891317049040336e-11,
#     'is_significant': True,
#     'effect_size': 3.546718340404186},
#    'abs_change_7d': {'outbreak_mean': -0.7125874286456652,
#     'outbreak_std': 0.3545782683968346,
#     'control_mean': 0.028396213518509104,
#     'control_std': 0.11930987751580398,
#     'p_value': 9.794861795105966e-12,
#     'is_significant': True,
#     'effect_size': 4.038250441504356}},
#   'significant_metrics': ['value_at_removal',
#    '1d_window_avg',
#    '3d_window_avg',
#    '5d_window_avg',
#    '7d_window_avg',
#    '1d_window_slope',
#    '3d_window_slope',
#    '5d_window_slope',
#    '7d_window_slope',
#    'abs_change_1d',
#    'abs_change_3d',
#    'abs_change_5d',
#    'abs_change_7d'],
#   'strong_effect_metrics': ['value_at_removal',
#    '1d_window_avg',
#    '3d_window_avg',
#    '5d_window_avg',
#    '7d_window_avg',
#    '1d_window_slope',
#    '3d_window_slope',
#    '5d_window_slope',
#    '7d_window_slope',
#    'abs_change_1d',
#    'abs_change_3d',
#    'abs_change_5d',
#    'abs_change_7d']},
#  'individual_variation': {'pattern_counts': {'Gradual-decline': 7,
#    'Sudden-decline': 5,
#    'Moderate-decline': 5,
#    'Erratic-decline': 3},
#   'pattern_percentages': {'Gradual-decline': 35.0,
#    'Sudden-decline': 25.0,
#    'Moderate-decline': 25.0,
#    'Erratic-decline': 15.0},
#   'pen_consistency': {'pens_with_multiple': 6,
#    'pens_consistent': 0,
#    'consistency_percentage': 0.0},
#   'Gradual-decline_metrics': {'count': 7,
#    'avg_value_at_removal': 0.0023070806662622407,
#    'avg_abs_change_7d': -0.5800570883273583,
#    'avg_7d_slope': -0.08409674297377752,
#    'avg_3d_slope': -0.07905070854138087},
#   'Sudden-decline_metrics': {'count': 5,
#    'avg_value_at_removal': -0.17788297852120033,
#    'avg_abs_change_7d': -0.935651355704367,
#    'avg_7d_slope': -0.13096480180129227,
#    'avg_3d_slope': -0.27527284007938474},
#   'Moderate-decline_metrics': {'count': 5,
#    'avg_value_at_removal': 0.23843713150364199,
#    'avg_abs_change_7d': -0.5626780100281951,
#    'avg_7d_slope': -0.09043976725005107,
#    'avg_3d_slope': -0.1363473206864862},
#   'Erratic-decline_metrics': {'count': 3,
#    'avg_value_at_removal': -0.3467432438986484,
#    'avg_abs_change_7d': -0.8999007086529947,
#    'avg_7d_slope': -0.1429679181810672,
#    'avg_3d_slope': -0.06593375271307135}},
#  'component_analysis': {'timepoint_stats': {'day_minus_0': {'upright_mean': 0.4819672649470025,
#     'upright_std': 0.1833216271365414,
#     'hanging_mean': 0.5180327350529975,
#     'hanging_std': 0.18332162713654138,
#     'diff_mean': -0.03606547010599507,
#     'diff_std': 0.36664325427308275,
#     'count': 20},
#    'day_minus_1': {'upright_mean': 0.5427236382023976,
#     'upright_std': 0.18904104558578622,
#     'hanging_mean': 0.4572763617976022,
#     'hanging_std': 0.18904104558578622,
#     'diff_mean': 0.08544727640479541,
#     'diff_std': 0.37808209117157243,
#     'count': 20},
#    'day_minus_3': {'upright_mean': 0.686120423838019,
#     'upright_std': 0.19969288714772915,
#     'hanging_mean': 0.31387957616198103,
#     'hanging_std': 0.1996928871477292,
#     'diff_mean': 0.372240847676038,
#     'diff_std': 0.3993857742954584,
#     'count': 20},
#    'day_minus_5': {'upright_mean': 0.7808517878998028,
#     'upright_std': 0.14506717466819918,
#     'hanging_mean': 0.21914821210019703,
#     'hanging_std': 0.1450671746681992,
#     'diff_mean': 0.561703575799606,
#     'diff_std': 0.2901343493363984,
#     'count': 20},
#    'day_minus_7': {'upright_mean': 0.838260979269835,
#     'upright_std': 0.09043061429938104,
#     'hanging_mean': 0.16173902073016497,
#     'hanging_std': 0.09043061429938105,
#     'diff_mean': 0.6765219585396701,
#     'diff_std': 0.18086122859876208,
#     'count': 20}},
#   'day_minus_0_stats': {'upright_mean': 0.4819672649470025,
#    'upright_std': 0.1833216271365414,
#    'hanging_mean': 0.5180327350529975,
#    'hanging_std': 0.18332162713654138,
#    'diff_mean': -0.03606547010599507,
#    'diff_std': 0.36664325427308275,
#    'count': 20},
#   'day_minus_3_stats': {'upright_mean': 0.686120423838019,
#    'upright_std': 0.19969288714772915,
#    'hanging_mean': 0.31387957616198103,
#    'hanging_std': 0.1996928871477292,
#    'diff_mean': 0.372240847676038,
#    'diff_std': 0.3993857742954584,
#    'count': 20},
#   'day_minus_7_stats': {'upright_mean': 0.838260979269835,
#    'upright_std': 0.09043061429938104,
#    'hanging_mean': 0.16173902073016497,
#    'hanging_std': 0.09043061429938105,
#    'diff_mean': 0.6765219585396701,
#    'diff_std': 0.18086122859876208,
#    'count': 20},
#   'change_stats': {'upright_7d_change': -0.3562937143228325,
#    'hanging_7d_change': 0.3562937143228325,
#    'diff_7d_change': -0.7125874286456652,
#    'upright_3d_change': -0.20415315889101648,
#    'hanging_3d_change': 0.20415315889101648,
#    'diff_3d_change': -0.4083063177820331},
#   'contribution_stats': {'upright_contribution_7d': -49.99999999999999,
#    'hanging_contribution_7d': -49.99999999999999,
#    'primary_driver_7d': 'hanging',
#    'upright_contribution_3d': -49.999999999999986,
#    'hanging_contribution_3d': -49.999999999999986,
#    'primary_driver_3d': 'hanging'},
#   'primary_driver_7d': 'hanging',
#   'upright_contribution_7d': -49.99999999999999,
#   'hanging_contribution_7d': -49.99999999999999,
#   'primary_driver_3d': 'hanging',
#   'upright_contribution_3d': -49.999999999999986,
#   'hanging_contribution_3d': -49.999999999999986},
#  'monitoring_thresholds': {'status': 'No monitoring threshold analysis available.'}}

# %%
from evaluation.activity_analysis.pig_activity_analyzer import PigBehaviorAnalyzer
from evaluation.activity_analysis.visualization import PigBehaviorVisualizer

# Create the behavior visualizer
visualizer = PigBehaviorVisualizer(config=config)

# Process all data
visualizer.process_all_data()

# Run the complete analysis
analysis_results = visualizer.run_complete_behavior_analysis()

# Visualize all behavior metrics
viz_files = visualizer.visualize_behavior_metrics()

# Create comparison visualizations between outbreak and control groups
visualizer.visualize_behavior_comparison()

# create visualizations for component analysis
visualizer.visualize_activity_components()
# Out:
# 2025-05-02 21:30:15,407 - tail_posture_descriptive_analysis - INFO - Saved configuration to results/analysis_config.txt
# 2025-05-02 21:30:15,408 - evaluation.tail_posture_analysis.utils - INFO - Setting plot style: Font=serif, BaseSize=11pt, Format=png, DPI=600
# 2025-05-02 21:30:15,408 - tail_posture_descriptive_analysis - INFO - Dissertation quality plotting style set for behavior visualization.
# 2025-05-02 21:30:15,409 - tail_posture_descriptive_analysis - INFO - Processing all monitoring results for behavior analysis...
# 2025-05-02 21:30:15,409 - tail_posture_descriptive_analysis - INFO - Loading monitoring pipeline data...
# 2025-05-02 21:30:21,847 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera5/221004_221104: [datetime.date(2022, 11, 3)]
# 2025-05-02 21:30:23,913 - data_analysis_utils - WARNING - Missing 17 day(s) for Kamera5/220510_220529: [datetime.date(2022, 5, 10), datetime.date(2022, 5, 12), datetime.date(2022, 5, 14), datetime.date(2022, 5, 15), datetime.date(2022, 5, 16), datetime.date(2022, 5, 18), datetime.date(2022, 5, 19), datetime.date(2022, 5, 20), datetime.date(2022, 5, 21), datetime.date(2022, 5, 22), datetime.date(2022, 5, 23), datetime.date(2022, 5, 24), datetime.date(2022, 5, 25), datetime.date(2022, 5, 26), datetime.date(2022, 5, 27), datetime.date(2022, 5, 28), datetime.date(2022, 5, 29)]
# 2025-05-02 21:30:23,924 - data_analysis_utils - WARNING - Dataframe became empty after time filtering: /home/jan-hendrik/home/PigMonitoringResearch/pipeline_outputs/monitoring_pipeline/piglet_rearing/Kamera5/220510_220529/Kamera5_2022_05_11_08_18_23-09_18_23.csv. Skipping.
# 2025-05-02 21:30:23,934 - data_analysis_utils - WARNING - Dataframe became empty after time filtering: /home/jan-hendrik/home/PigMonitoringResearch/pipeline_outputs/monitoring_pipeline/piglet_rearing/Kamera5/220510_220529/Kamera5_2022_05_13_08_18_21-09_18_21.csv. Skipping.
# 2025-05-02 21:30:23,948 - data_analysis_utils - WARNING - Loaded 1 non-empty dataframes out of 3 found CSVs for Kamera5/220510_220529.
# 2025-05-02 21:30:23,949 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera5/221219_230126: [datetime.date(2023, 1, 26)]
# 2025-05-02 21:30:26,540 - data_analysis_utils - WARNING - Missing 7 day(s) for Kamera5/220228_220407: [datetime.date(2022, 4, 1), datetime.date(2022, 4, 2), datetime.date(2022, 4, 3), datetime.date(2022, 4, 4), datetime.date(2022, 4, 5), datetime.date(2022, 4, 6), datetime.date(2022, 4, 7)]
# 2025-05-02 21:30:28,501 - data_analysis_utils - WARNING - Missing 6 day(s) for Kamera5/230227_230406: [datetime.date(2023, 3, 8), datetime.date(2023, 3, 9), datetime.date(2023, 3, 10), datetime.date(2023, 3, 11), datetime.date(2023, 3, 12), datetime.date(2023, 3, 13)]
# 2025-05-02 21:30:30,744 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera1/211228_220119: [datetime.date(2022, 1, 1)]
# 2025-05-02 21:30:32,095 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera1/221003_221106: [datetime.date(2022, 11, 3)]
# 2025-05-02 21:30:43,843 - data_analysis_utils - WARNING - Missing 25 day(s) for Kamera1/220505_220530: [datetime.date(2022, 5, 5), datetime.date(2022, 5, 6), datetime.date(2022, 5, 7), datetime.date(2022, 5, 8), datetime.date(2022, 5, 9), datetime.date(2022, 5, 10), datetime.date(2022, 5, 11), datetime.date(2022, 5, 12), datetime.date(2022, 5, 13), datetime.date(2022, 5, 14), datetime.date(2022, 5, 16), datetime.date(2022, 5, 17), datetime.date(2022, 5, 18), datetime.date(2022, 5, 19), datetime.date(2022, 5, 20), datetime.date(2022, 5, 21), datetime.date(2022, 5, 22), datetime.date(2022, 5, 23), datetime.date(2022, 5, 24), datetime.date(2022, 5, 25), datetime.date(2022, 5, 26), datetime.date(2022, 5, 27), datetime.date(2022, 5, 28), datetime.date(2022, 5, 29), datetime.date(2022, 5, 30)]
# 2025-05-02 21:30:46,592 - data_analysis_utils - WARNING - Missing 2 day(s) for Kamera6/221003_221107: [datetime.date(2022, 11, 3), datetime.date(2022, 11, 7)]
# 2025-05-02 21:30:48,645 - data_analysis_utils - WARNING - Missing 6 day(s) for Kamera6/211230_220120: [datetime.date(2022, 1, 15), datetime.date(2022, 1, 16), datetime.date(2022, 1, 17), datetime.date(2022, 1, 18), datetime.date(2022, 1, 19), datetime.date(2022, 1, 20)]
# 2025-05-02 21:30:49,636 - data_analysis_utils - WARNING - Missing 5 day(s) for Kamera6/220725_220905: [datetime.date(2022, 9, 1), datetime.date(2022, 9, 2), datetime.date(2022, 9, 3), datetime.date(2022, 9, 4), datetime.date(2022, 9, 5)]
# 2025-05-02 21:30:52,080 - data_analysis_utils - WARNING - Missing 21 day(s) for Kamera6/220509_220530: [datetime.date(2022, 5, 9), datetime.date(2022, 5, 10), datetime.date(2022, 5, 12), datetime.date(2022, 5, 13), datetime.date(2022, 5, 14), datetime.date(2022, 5, 15), datetime.date(2022, 5, 16), datetime.date(2022, 5, 17), datetime.date(2022, 5, 18), datetime.date(2022, 5, 19), datetime.date(2022, 5, 20), datetime.date(2022, 5, 21), datetime.date(2022, 5, 22), datetime.date(2022, 5, 23), datetime.date(2022, 5, 24), datetime.date(2022, 5, 25), datetime.date(2022, 5, 26), datetime.date(2022, 5, 27), datetime.date(2022, 5, 28), datetime.date(2022, 5, 29), datetime.date(2022, 5, 30)]
# 2025-05-02 21:30:52,095 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera6/221219_230126: [datetime.date(2023, 1, 26)]
# 2025-05-02 21:30:54,785 - data_analysis_utils - WARNING - Missing 6 day(s) for Kamera6/220228_220407: [datetime.date(2022, 3, 31), datetime.date(2022, 4, 1), datetime.date(2022, 4, 3), datetime.date(2022, 4, 4), datetime.date(2022, 4, 6), datetime.date(2022, 4, 7)]
# 2025-05-02 21:30:56,708 - data_analysis_utils - WARNING - Missing 4 day(s) for Kamera6/230515_230622: [datetime.date(2023, 6, 18), datetime.date(2023, 6, 19), datetime.date(2023, 6, 20), datetime.date(2023, 6, 22)]
# 2025-05-02 21:30:59,236 - data_analysis_utils - WARNING - Missing 6 day(s) for Kamera6/230227_230406: [datetime.date(2023, 3, 8), datetime.date(2023, 3, 9), datetime.date(2023, 3, 10), datetime.date(2023, 3, 11), datetime.date(2023, 3, 12), datetime.date(2023, 3, 13)]
# 2025-05-02 21:31:03,013 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera2/221003_221106: [datetime.date(2022, 11, 3)]
# 2025-05-02 21:31:14,909 - data_analysis_utils - WARNING - Missing 24 day(s) for Kamera2/220505_220530: [datetime.date(2022, 5, 5), datetime.date(2022, 5, 6), datetime.date(2022, 5, 7), datetime.date(2022, 5, 8), datetime.date(2022, 5, 9), datetime.date(2022, 5, 10), datetime.date(2022, 5, 12), datetime.date(2022, 5, 13), datetime.date(2022, 5, 14), datetime.date(2022, 5, 16), datetime.date(2022, 5, 17), datetime.date(2022, 5, 18), datetime.date(2022, 5, 19), datetime.date(2022, 5, 20), datetime.date(2022, 5, 21), datetime.date(2022, 5, 22), datetime.date(2022, 5, 23), datetime.date(2022, 5, 24), datetime.date(2022, 5, 25), datetime.date(2022, 5, 26), datetime.date(2022, 5, 27), datetime.date(2022, 5, 28), datetime.date(2022, 5, 29), datetime.date(2022, 5, 30)]
# 2025-05-02 21:31:17,668 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera4/221226_230126: [datetime.date(2023, 1, 26)]
# 2025-05-02 21:31:19,861 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera4/221003_221106: [datetime.date(2022, 11, 3)]
# 2025-05-02 21:31:26,033 - data_analysis_utils - WARNING - Missing 16 day(s) for Kamera4/220725_220905: [datetime.date(2022, 8, 21), datetime.date(2022, 8, 22), datetime.date(2022, 8, 23), datetime.date(2022, 8, 24), datetime.date(2022, 8, 25), datetime.date(2022, 8, 26), datetime.date(2022, 8, 27), datetime.date(2022, 8, 28), datetime.date(2022, 8, 29), datetime.date(2022, 8, 30), datetime.date(2022, 8, 31), datetime.date(2022, 9, 1), datetime.date(2022, 9, 2), datetime.date(2022, 9, 3), datetime.date(2022, 9, 4), datetime.date(2022, 9, 5)]
# 2025-05-02 21:31:27,763 - data_analysis_utils - WARNING - Missing 18 day(s) for Kamera4/220510_220529: [datetime.date(2022, 5, 11), datetime.date(2022, 5, 12), datetime.date(2022, 5, 13), datetime.date(2022, 5, 14), datetime.date(2022, 5, 16), datetime.date(2022, 5, 17), datetime.date(2022, 5, 18), datetime.date(2022, 5, 19), datetime.date(2022, 5, 20), datetime.date(2022, 5, 21), datetime.date(2022, 5, 22), datetime.date(2022, 5, 23), datetime.date(2022, 5, 24), datetime.date(2022, 5, 25), datetime.date(2022, 5, 26), datetime.date(2022, 5, 27), datetime.date(2022, 5, 28), datetime.date(2022, 5, 29)]
# 2025-05-02 21:31:27,791 - data_analysis_utils - WARNING - Missing 7 day(s) for Kamera4/220228_220407: [datetime.date(2022, 3, 31), datetime.date(2022, 4, 1), datetime.date(2022, 4, 3), datetime.date(2022, 4, 4), datetime.date(2022, 4, 5), datetime.date(2022, 4, 6), datetime.date(2022, 4, 7)]
# 2025-05-02 21:31:34,431 - data_analysis_utils - WARNING - Missing 1 day(s) for Kamera3/221003_221106: [datetime.date(2022, 11, 3)]
# 2025-05-02 21:31:41,091 - data_analysis_utils - WARNING - Missing 5 day(s) for Kamera3/220725_220905: [datetime.date(2022, 9, 1), datetime.date(2022, 9, 2), datetime.date(2022, 9, 3), datetime.date(2022, 9, 4), datetime.date(2022, 9, 5)]
# 2025-05-02 21:31:43,570 - data_analysis_utils - WARNING - Missing 4 day(s) for Kamera3/221219_230125: [datetime.date(2023, 1, 22), datetime.date(2023, 1, 23), datetime.date(2023, 1, 24), datetime.date(2023, 1, 25)]
# 2025-05-02 21:31:45,922 - data_analysis_utils - WARNING - Missing 24 day(s) for Kamera3/220505_220529: [datetime.date(2022, 5, 5), datetime.date(2022, 5, 6), datetime.date(2022, 5, 7), datetime.date(2022, 5, 8), datetime.date(2022, 5, 9), datetime.date(2022, 5, 10), datetime.date(2022, 5, 11), datetime.date(2022, 5, 12), datetime.date(2022, 5, 13), datetime.date(2022, 5, 14), datetime.date(2022, 5, 15), datetime.date(2022, 5, 16), datetime.date(2022, 5, 18), datetime.date(2022, 5, 19), datetime.date(2022, 5, 20), datetime.date(2022, 5, 21), datetime.date(2022, 5, 22), datetime.date(2022, 5, 23), datetime.date(2022, 5, 24), datetime.date(2022, 5, 25), datetime.date(2022, 5, 26), datetime.date(2022, 5, 27), datetime.date(2022, 5, 28), datetime.date(2022, 5, 29)]
# 2025-05-02 21:31:45,937 - data_analysis_utils - WARNING - Missing 2 day(s) for Kamera3/230227_230406: [datetime.date(2023, 3, 9), datetime.date(2023, 3, 10)]
# 2025-05-02 21:31:48,477 - tail_posture_descriptive_analysis - INFO - Loaded 48 monitoring results in 93.07 seconds
# 2025-05-02 21:31:48,477 - tail_posture_descriptive_analysis - INFO - Dataset contains 6 cameras and 28 datespans.
# 2025-05-02 21:31:48,478 - tail_posture_descriptive_analysis - INFO - Total expected days across all datespans: 1623
# 2025-05-02 21:31:48,478 - tail_posture_descriptive_analysis - INFO - Total missing daily files detected: 214 (13.19%)
# 2025-05-02 21:31:49,463 - tail_posture_descriptive_analysis - WARNING - Dataset too small for smoothing (length 1). Skipping smoothing.
# 2025-05-02 21:31:49,466 - tail_posture_descriptive_analysis - WARNING - Not enough non-NaN data points (1) for interpolation on Kamera1 - 220505_220530. Skipping.
# 2025-05-02 21:31:54,862 - tail_posture_descriptive_analysis - WARNING - Dataset too small for smoothing (length 2). Skipping smoothing.
# 2025-05-02 21:32:00,436 - tail_posture_descriptive_analysis - WARNING - Dataset too small for smoothing (length 1). Skipping smoothing.
# 2025-05-02 21:32:00,440 - tail_posture_descriptive_analysis - WARNING - Not enough non-NaN data points (1) for interpolation on Kamera3 - 220505_220529. Skipping.
# 2025-05-02 21:32:05,025 - tail_posture_descriptive_analysis - WARNING - Dataset too small for smoothing (length 2). Skipping smoothing.
# 2025-05-02 21:32:09,759 - tail_posture_descriptive_analysis - WARNING - Dataset too small for smoothing (length 1). Skipping smoothing.
# 2025-05-02 21:32:09,761 - tail_posture_descriptive_analysis - WARNING - Not enough non-NaN data points (1) for interpolation on Kamera5 - 220510_220529. Skipping.
# 2025-05-02 21:32:14,649 - tail_posture_descriptive_analysis - WARNING - Dataset too small for smoothing (length 1). Skipping smoothing.
# 2025-05-02 21:32:14,652 - tail_posture_descriptive_analysis - WARNING - Not enough non-NaN data points (1) for interpolation on Kamera6 - 220509_220530. Skipping.
# 2025-05-02 21:32:18,829 - tail_posture_descriptive_analysis - INFO - Successfully processed 48 monitoring results.
# 2025-05-02 21:32:18,830 - tail_posture_descriptive_analysis - INFO - Found the following behavior metrics in the data: num_pigs_notLying, activity, num_pigs_lying
# 2025-05-02 21:32:18,831 - tail_posture_descriptive_analysis - INFO - Analyzing pre-outbreak behavior statistics (using earliest removal date per event)...
# 2025-05-02 21:32:18,832 - tail_posture_descriptive_analysis - INFO - Excluding Kamera1/211228_220119: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:32:18,850 - tail_posture_descriptive_analysis - INFO - Excluding Kamera1/220505_220530 from behavior analysis due to excessive missing days (25/26 = 96.2% > 50.0%)
# 2025-05-02 21:32:18,850 - tail_posture_descriptive_analysis - INFO - Excluding Kamera1/220726_220831: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:32:18,915 - tail_posture_descriptive_analysis - INFO - Excluding Kamera2/211227_220119: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:32:18,916 - tail_posture_descriptive_analysis - INFO - Removal date 2022-04-06 is after last data point for Pen 2. Using last available data point.
# 2025-05-02 21:32:18,932 - tail_posture_descriptive_analysis - INFO - Excluding Kamera2/220505_220530 from behavior analysis due to excessive missing days (24/26 = 92.3% > 50.0%)
# 2025-05-02 21:32:18,933 - tail_posture_descriptive_analysis - INFO - Excluding Kamera2/220725_220831: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:32:18,933 - tail_posture_descriptive_analysis - INFO - Removal date 2022-11-07 is after last data point for Pen 2. Using last available data point.
# 2025-05-02 21:32:18,950 - tail_posture_descriptive_analysis - INFO - Excluding Kamera2/221219_230125: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:32:18,951 - tail_posture_descriptive_analysis - INFO - Excluding Kamera2/230227_230405: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:32:18,973 - tail_posture_descriptive_analysis - INFO - Excluding Kamera3/211222_220119: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:32:18,990 - tail_posture_descriptive_analysis - INFO - Excluding Kamera3/220505_220529 from behavior analysis due to excessive missing days (24/25 = 96.0% > 50.0%)
# 2025-05-02 21:32:18,990 - tail_posture_descriptive_analysis - INFO - Excluding Kamera3/220725_220905: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:32:19,007 - tail_posture_descriptive_analysis - INFO - Excluding Kamera3/221219_230125: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:32:19,007 - tail_posture_descriptive_analysis - INFO - Excluding Kamera3/230227_230406: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:32:19,024 - tail_posture_descriptive_analysis - INFO - Excluding Kamera4/211229_220119: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:32:19,024 - tail_posture_descriptive_analysis - INFO - Excluding Kamera4/220228_220407: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:32:19,024 - tail_posture_descriptive_analysis - INFO - Excluding Kamera4/220510_220529 from behavior analysis due to 4 consecutive missing periods in resampled data (threshold: 3). Raw missing days: 18
# 2025-05-02 21:32:19,025 - tail_posture_descriptive_analysis - INFO - Excluding Kamera4/220725_220905: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:32:19,025 - tail_posture_descriptive_analysis - INFO - Removal date 2022-11-07 is after last data point for Pen 4. Using last available data point.
# 2025-05-02 21:32:19,090 - tail_posture_descriptive_analysis - INFO - Excluding Kamera5/211231_220119: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:32:19,090 - tail_posture_descriptive_analysis - INFO - Excluding Kamera5/220228_220407: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:32:19,091 - tail_posture_descriptive_analysis - INFO - Excluding Kamera5/220510_220529 from behavior analysis due to excessive missing days (17/20 = 85.0% > 50.0%)
# 2025-05-02 21:32:19,123 - tail_posture_descriptive_analysis - INFO - Excluding Kamera5/221219_230126: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:32:19,123 - tail_posture_descriptive_analysis - INFO - Excluding Kamera5/230227_230406 from behavior analysis due to 6 consecutive missing periods in resampled data (threshold: 3). Raw missing days: 6
# 2025-05-02 21:32:19,140 - tail_posture_descriptive_analysis - INFO - Excluding Kamera6/211230_220120: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:32:19,140 - tail_posture_descriptive_analysis - INFO - Excluding Kamera6/220228_220407: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:32:19,142 - tail_posture_descriptive_analysis - INFO - Excluding Kamera6/220509_220530 from behavior analysis due to excessive missing days (21/22 = 95.5% > 50.0%)
# 2025-05-02 21:32:19,142 - tail_posture_descriptive_analysis - INFO - Excluding Kamera6/220725_220905: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:32:19,160 - tail_posture_descriptive_analysis - INFO - Excluding Kamera6/221219_230126: Not a tail biting event or missing culprit removal info
# 2025-05-02 21:32:19,160 - tail_posture_descriptive_analysis - INFO - Excluding Kamera6/230227_230406 from behavior analysis due to 6 consecutive missing periods in resampled data (threshold: 3). Raw missing days: 6
# 2025-05-02 21:32:19,180 - tail_posture_descriptive_analysis - INFO - Saved descriptive pre-outbreak statistics for num_pigs_lying to results/pre_outbreak_statistics_num_pigs_lying_filtered.csv
# 2025-05-02 21:32:19,183 - tail_posture_descriptive_analysis - INFO - Saved descriptive pre-outbreak statistics for num_pigs_notLying to results/pre_outbreak_statistics_num_pigs_notLying_filtered.csv
# 2025-05-02 21:32:19,186 - tail_posture_descriptive_analysis - INFO - Saved descriptive pre-outbreak statistics for activity to results/pre_outbreak_statistics_activity_filtered.csv
# 2025-05-02 21:32:19,187 - tail_posture_descriptive_analysis - INFO - Attempted to analyze 22 potential tail biting events for behavior metrics.
# 2025-05-02 21:32:19,187 - tail_posture_descriptive_analysis - INFO - Successfully analyzed at least one metric for 3 events.
# 2025-05-02 21:32:19,188 - tail_posture_descriptive_analysis - INFO - Excluded 3 events due to >3 consecutive missing days.
# 2025-05-02 21:32:19,188 - tail_posture_descriptive_analysis - INFO - Excluded 5 events due to excessive missing days (>50.0%).
# 2025-05-02 21:32:19,188 - tail_posture_descriptive_analysis - INFO - Excluded 11 events for other reasons (e.g., no valid removal date, empty data).
# 2025-05-02 21:32:19,189 - tail_posture_descriptive_analysis - INFO -   - num_pigs_lying: 20 valid analyses
# 2025-05-02 21:32:19,190 - tail_posture_descriptive_analysis - INFO -   - num_pigs_notLying: 20 valid analyses
# 2025-05-02 21:32:19,190 - tail_posture_descriptive_analysis - INFO -   - activity: 20 valid analyses
# 2025-05-02 21:32:19,191 - tail_posture_descriptive_analysis - INFO - Analyzing control pen statistics for behavior metrics comparison...
# 2025-05-02 21:32:19,191 - tail_posture_descriptive_analysis - INFO - Found 26 control pen datasets for behavior analysis
# 2025-05-02 21:32:19,261 - tail_posture_descriptive_analysis - INFO - Excluding control pen Kamera1/220505_220530 due to excessive missing days (25/26 = 96.2% > 50.0%)
# 2025-05-02 21:32:19,398 - tail_posture_descriptive_analysis - INFO - Excluding control pen Kamera2/220505_220530 due to excessive missing days (24/26 = 92.3% > 50.0%)
# 2025-05-02 21:32:19,669 - tail_posture_descriptive_analysis - INFO - Excluding control pen Kamera3/220505_220529 due to excessive missing days (24/25 = 96.0% > 50.0%)
# 2025-05-02 21:32:20,212 - tail_posture_descriptive_analysis - INFO - Excluding control pen Kamera5/220510_220529 due to excessive missing days (17/20 = 85.0% > 50.0%)
# 2025-05-02 21:32:20,281 - tail_posture_descriptive_analysis - INFO - Excluding control pen Kamera5/230227_230406 due to 6 consecutive missing periods in resampled data (threshold: 3). Raw missing days: 6
# 2025-05-02 21:32:20,416 - tail_posture_descriptive_analysis - INFO - Excluding control pen Kamera6/220509_220530 due to excessive missing days (21/22 = 95.5% > 50.0%)
# 2025-05-02 21:32:20,560 - tail_posture_descriptive_analysis - INFO - Saved control pen statistics for num_pigs_lying to results/control_statistics_num_pigs_lying.csv
# 2025-05-02 21:32:20,568 - tail_posture_descriptive_analysis - INFO - Saved control pen statistics for num_pigs_notLying to results/control_statistics_num_pigs_notLying.csv
# 2025-05-02 21:32:20,575 - tail_posture_descriptive_analysis - INFO - Saved control pen statistics for activity to results/control_statistics_activity.csv
# 2025-05-02 21:32:20,576 - tail_posture_descriptive_analysis - INFO - Analyzed 26 control pens for behavior metrics.
# 2025-05-02 21:32:20,577 - tail_posture_descriptive_analysis - INFO -   - num_pigs_lying: 20 control pen datasets with 100 reference points
# 2025-05-02 21:32:20,578 - tail_posture_descriptive_analysis - INFO -   - num_pigs_notLying: 20 control pen datasets with 100 reference points
# 2025-05-02 21:32:20,579 - tail_posture_descriptive_analysis - INFO -   - activity: 20 control pen datasets with 100 reference points
# 2025-05-02 21:32:20,579 - tail_posture_descriptive_analysis - INFO - Excluded 1 control pens due to >3 consecutive missing days.
# 2025-05-02 21:32:20,580 - tail_posture_descriptive_analysis - INFO - Excluded 5 control pens due to excessive missing days (>50.0%).
# 2025-05-02 21:32:20,580 - tail_posture_descriptive_analysis - INFO - Comparing outbreak vs control pen statistics for behavior metrics...
# 2025-05-02 21:32:20,581 - tail_posture_descriptive_analysis - INFO - Comparing num_pigs_lying between outbreak and control pens...
# 2025-05-02 21:32:20,582 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_lying_value_at_removal: Outbreak=12.063±3.141, Control=11.076±3.498, p=0.3259, Significant=False, Effect Size=0.29
# 2025-05-02 21:32:20,584 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_lying_1d_window_avg: Outbreak=12.036±3.074, Control=10.979±3.531, p=0.2990, Significant=False, Effect Size=0.31
# 2025-05-02 21:32:20,585 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_lying_3d_window_avg: Outbreak=12.063±3.019, Control=10.774±3.563, p=0.1708, Significant=False, Effect Size=0.37
# 2025-05-02 21:32:20,587 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_lying_5d_window_avg: Outbreak=12.023±3.009, Control=10.589±3.527, p=0.1420, Significant=False, Effect Size=0.42
# 2025-05-02 21:32:20,588 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_lying_7d_window_avg: Outbreak=11.906±3.013, Control=10.421±3.523, p=0.1291, Significant=False, Effect Size=0.43
# 2025-05-02 21:32:20,589 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_lying_1d_window_slope: Outbreak=0.055±0.641, Control=0.202±0.557, p=0.4365, Significant=False, Effect Size=0.26
# 2025-05-02 21:32:20,591 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_lying_3d_window_slope: Outbreak=-0.031±0.456, Control=0.204±0.456, p=0.0499, Significant=True, Effect Size=0.51
# 2025-05-02 21:32:20,593 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_lying_5d_window_slope: Outbreak=0.029±0.279, Control=0.187±0.420, p=0.0467, Significant=True, Effect Size=0.39
# 2025-05-02 21:32:20,594 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_lying_7d_window_slope: Outbreak=0.088±0.175, Control=0.148±0.363, p=0.1239, Significant=False, Effect Size=0.18
# 2025-05-02 21:32:20,596 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_lying_abs_change_1d: Outbreak=0.055±0.641, Control=0.202±0.557, p=0.4365, Significant=False, Effect Size=0.26
# 2025-05-02 21:32:20,597 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_lying_abs_change_3d: Outbreak=-0.045±1.335, Control=0.606±1.354, p=0.0777, Significant=False, Effect Size=0.48
# 2025-05-02 21:32:20,599 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_lying_abs_change_5d: Outbreak=0.177±1.242, Control=0.902±1.834, p=0.0394, Significant=True, Effect Size=0.41
# 2025-05-02 21:32:20,600 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_lying_abs_change_7d: Outbreak=0.619±1.377, Control=1.379±1.476, p=0.0248, Significant=True, Effect Size=0.52
# 2025-05-02 21:32:20,601 - tail_posture_descriptive_analysis - INFO - Saved outbreak vs control comparison for num_pigs_lying to results/outbreak_vs_control_comparison_num_pigs_lying.csv
# 2025-05-02 21:32:20,601 - tail_posture_descriptive_analysis - INFO - Comparing num_pigs_notLying between outbreak and control pens...
# 2025-05-02 21:32:20,603 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_notLying_value_at_removal: Outbreak=8.842±1.948, Control=9.060±1.530, p=0.4618, Significant=False, Effect Size=0.14
# 2025-05-02 21:32:20,604 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_notLying_1d_window_avg: Outbreak=9.006±1.851, Control=9.075±1.548, p=0.7274, Significant=False, Effect Size=0.04
# 2025-05-02 21:32:20,605 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_notLying_3d_window_avg: Outbreak=9.128±1.688, Control=9.131±1.590, p=0.9916, Significant=False, Effect Size=0.00
# 2025-05-02 21:32:20,606 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_notLying_5d_window_avg: Outbreak=9.192±1.503, Control=9.185±1.603, p=0.9019, Significant=False, Effect Size=0.00
# 2025-05-02 21:32:20,608 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_notLying_7d_window_avg: Outbreak=9.300±1.489, Control=9.214±1.601, p=0.8465, Significant=False, Effect Size=0.05
# 2025-05-02 21:32:20,609 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_notLying_1d_window_slope: Outbreak=-0.341±0.687, Control=-0.030±0.589, p=0.1364, Significant=False, Effect Size=0.51
# 2025-05-02 21:32:20,610 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_notLying_3d_window_slope: Outbreak=-0.088±0.422, Control=-0.059±0.386, p=0.6396, Significant=False, Effect Size=0.07
# 2025-05-02 21:32:20,611 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_notLying_5d_window_slope: Outbreak=-0.072±0.296, Control=-0.054±0.311, p=0.8354, Significant=False, Effect Size=0.06
# 2025-05-02 21:32:20,612 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_notLying_7d_window_slope: Outbreak=-0.096±0.227, Control=-0.032±0.258, p=0.2797, Significant=False, Effect Size=0.25
# 2025-05-02 21:32:20,614 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_notLying_abs_change_1d: Outbreak=-0.341±0.687, Control=-0.030±0.589, p=0.1364, Significant=False, Effect Size=0.51
# 2025-05-02 21:32:20,615 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_notLying_abs_change_3d: Outbreak=-0.295±1.232, Control=-0.165±1.132, p=0.4704, Significant=False, Effect Size=0.11
# 2025-05-02 21:32:20,616 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_notLying_abs_change_5d: Outbreak=-0.518±1.339, Control=-0.237±1.401, p=0.3259, Significant=False, Effect Size=0.20
# 2025-05-02 21:32:20,617 - tail_posture_descriptive_analysis - INFO - Comparison for num_pigs_notLying_abs_change_7d: Outbreak=-0.791±1.585, Control=-0.274±1.480, p=0.2451, Significant=False, Effect Size=0.34
# 2025-05-02 21:32:20,618 - tail_posture_descriptive_analysis - INFO - Saved outbreak vs control comparison for num_pigs_notLying to results/outbreak_vs_control_comparison_num_pigs_notLying.csv
# 2025-05-02 21:32:20,619 - tail_posture_descriptive_analysis - INFO - Comparing activity between outbreak and control pens...
# 2025-05-02 21:32:20,620 - tail_posture_descriptive_analysis - INFO - Comparison for activity_value_at_removal: Outbreak=0.538±0.158, Control=0.574±0.121, p=0.1664, Significant=False, Effect Size=0.29
# 2025-05-02 21:32:20,621 - tail_posture_descriptive_analysis - INFO - Comparison for activity_1d_window_avg: Outbreak=0.549±0.149, Control=0.577±0.122, p=0.3581, Significant=False, Effect Size=0.22
# 2025-05-02 21:32:20,622 - tail_posture_descriptive_analysis - INFO - Comparison for activity_3d_window_avg: Outbreak=0.553±0.130, Control=0.587±0.120, p=0.2735, Significant=False, Effect Size=0.28
# 2025-05-02 21:32:20,624 - tail_posture_descriptive_analysis - INFO - Comparison for activity_5d_window_avg: Outbreak=0.550±0.109, Control=0.597±0.116, p=0.0766, Significant=False, Effect Size=0.41
# 2025-05-02 21:32:20,625 - tail_posture_descriptive_analysis - INFO - Comparison for activity_7d_window_avg: Outbreak=0.556±0.103, Control=0.604±0.113, p=0.0676, Significant=False, Effect Size=0.43
# 2025-05-02 21:32:20,626 - tail_posture_descriptive_analysis - INFO - Comparison for activity_1d_window_slope: Outbreak=-0.024±0.063, Control=-0.005±0.050, p=0.2704, Significant=False, Effect Size=0.36
# 2025-05-02 21:32:20,627 - tail_posture_descriptive_analysis - INFO - Comparison for activity_3d_window_slope: Outbreak=-0.001±0.047, Control=-0.011±0.033, p=0.5013, Significant=False, Effect Size=0.27
# 2025-05-02 21:32:20,629 - tail_posture_descriptive_analysis - INFO - Comparison for activity_5d_window_slope: Outbreak=0.002±0.032, Control=-0.010±0.025, p=0.0507, Significant=False, Effect Size=0.46
# 2025-05-02 21:32:20,630 - tail_posture_descriptive_analysis - INFO - Comparison for activity_7d_window_slope: Outbreak=-0.004±0.019, Control=-0.008±0.020, p=0.3655, Significant=False, Effect Size=0.21
# 2025-05-02 21:32:20,631 - tail_posture_descriptive_analysis - INFO - Comparison for activity_abs_change_1d: Outbreak=-0.024±0.063, Control=-0.005±0.050, p=0.2704, Significant=False, Effect Size=0.36
# 2025-05-02 21:32:20,632 - tail_posture_descriptive_analysis - INFO - Comparison for activity_abs_change_3d: Outbreak=-0.006±0.127, Control=-0.029±0.093, p=0.6295, Significant=False, Effect Size=0.23
# 2025-05-02 21:32:20,633 - tail_posture_descriptive_analysis - INFO - Comparison for activity_abs_change_5d: Outbreak=-0.006±0.131, Control=-0.044±0.109, p=0.2165, Significant=False, Effect Size=0.34
# 2025-05-02 21:32:20,635 - tail_posture_descriptive_analysis - INFO - Comparison for activity_abs_change_7d: Outbreak=-0.052±0.122, Control=-0.058±0.098, p=0.9053, Significant=False, Effect Size=0.06
# 2025-05-02 21:32:20,636 - tail_posture_descriptive_analysis - INFO - Saved outbreak vs control comparison for activity to results/outbreak_vs_control_comparison_activity.csv
# 2025-05-02 21:32:20,636 - tail_posture_descriptive_analysis - INFO - Completed behavior metrics analysis.
# 2025-05-02 21:32:20,636 - tail_posture_descriptive_analysis - INFO - === Behavior Analysis Summary ===
# 2025-05-02 21:32:20,637 - tail_posture_descriptive_analysis - INFO - num_pigs_lying: 20 outbreaks, 100 controls, 13 comparisons
# 2025-05-02 21:32:20,638 - tail_posture_descriptive_analysis - INFO - num_pigs_notLying: 20 outbreaks, 100 controls, 13 comparisons
# 2025-05-02 21:32:20,639 - tail_posture_descriptive_analysis - INFO - activity: 20 outbreaks, 100 controls, 13 comparisons
# 2025-05-02 21:32:20,639 - tail_posture_descriptive_analysis - INFO - Visualizing behavior metrics analysis...
# 2025-05-02 21:32:20,640 - evaluation.tail_posture_analysis.utils - INFO - Setting plot style: Font=serif, BaseSize=11pt, Format=png, DPI=600
# 2025-05-02 21:32:20,640 - tail_posture_descriptive_analysis - INFO - Creating visualization for num_pigs_lying
# /home/jan-hendrik/home/PigMonitoringResearch/evaluation/activity_analysis/visualization.py:404: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7f1cb0404a00> has a label of '_child21' which cannot be automatically added to the legend.
#   ax3.legend(handles=legend_handles_traj, loc='best', frameon=True, facecolor='white',
# 2025-05-02 21:32:22,464 - tail_posture_descriptive_analysis - INFO - Saved num_pigs_lying visualization to results/behavior_analysis_num_pigs_lying.png
# 2025-05-02 21:32:22,465 - tail_posture_descriptive_analysis - INFO - Creating visualization for num_pigs_notLying
# /home/jan-hendrik/home/PigMonitoringResearch/evaluation/activity_analysis/visualization.py:404: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7f1cb004f940> has a label of '_child21' which cannot be automatically added to the legend.
#   ax3.legend(handles=legend_handles_traj, loc='best', frameon=True, facecolor='white',
# 2025-05-02 21:32:24,202 - tail_posture_descriptive_analysis - INFO - Saved num_pigs_notLying visualization to results/behavior_analysis_num_pigs_notLying.png
# 2025-05-02 21:32:24,204 - tail_posture_descriptive_analysis - INFO - Creating visualization for activity
# /home/jan-hendrik/home/PigMonitoringResearch/evaluation/activity_analysis/visualization.py:404: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7f1cafc97ee0> has a label of '_child21' which cannot be automatically added to the legend.
#   ax3.legend(handles=legend_handles_traj, loc='best', frameon=True, facecolor='white',
# 2025-05-02 21:32:25,931 - tail_posture_descriptive_analysis - INFO - Saved activity visualization to results/behavior_analysis_activity.png
# 2025-05-02 21:32:25,932 - tail_posture_descriptive_analysis - INFO - Visualizing behavior metrics comparison...
# 2025-05-02 21:32:25,933 - evaluation.tail_posture_analysis.utils - INFO - Setting plot style: Font=serif, BaseSize=11pt, Format=png, DPI=600
# 2025-05-02 21:32:25,933 - tail_posture_descriptive_analysis - INFO - Creating comparison visualization for num_pigs_lying
# 2025-05-02 21:32:28,023 - tail_posture_descriptive_analysis - INFO - Saved num_pigs_lying comparison visualization to results/behavior_comparison_num_pigs_lying.png
# 2025-05-02 21:32:28,024 - tail_posture_descriptive_analysis - INFO - Creating comparison visualization for num_pigs_notLying
# 2025-05-02 21:32:30,021 - tail_posture_descriptive_analysis - INFO - Saved num_pigs_notLying comparison visualization to results/behavior_comparison_num_pigs_notLying.png
# 2025-05-02 21:32:30,021 - tail_posture_descriptive_analysis - INFO - Creating comparison visualization for activity
# 2025-05-02 21:32:31,944 - tail_posture_descriptive_analysis - INFO - Saved activity comparison visualization to results/behavior_comparison_activity.png
# 2025-05-02 21:32:31,945 - tail_posture_descriptive_analysis - INFO - Visualizing lying components (lying vs not lying pigs)...
# 2025-05-02 21:32:31,946 - evaluation.tail_posture_analysis.utils - INFO - Setting plot style: Font=serif, BaseSize=11pt, Format=png, DPI=600
# 2025-05-02 21:32:33,429 - tail_posture_descriptive_analysis - INFO - Saved lying component visualization to results/lying_component_analysis.png
# 'results/lying_component_analysis.png'
