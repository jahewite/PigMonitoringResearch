# %%
from path_setup import add_project_root_to_path

add_project_root_to_path()
# Out:
# Project root added to sys.path: /Users/jan-hendrikwitte/Documents/DigiSchwein/monitoiring_pipeline

# %%
from pipeline.utils.path_manager import PathManager
from pipeline.utils.video_file_utils import get_frame_of_video
from pipeline.utils.visualization import inference_on_single_image

path_manager = PathManager()

path_to_test_clip = path_manager.path_to_test_clip
print(f"Path to test clip: {path_to_test_clip}")
# Out:
# Path to test clip: /Users/jan-hendrikwitte/Documents/DigiSchwein/monitoiring_pipeline/assets/test_clips/test_1.mp4
# /Users/jan-hendrikwitte/Documents/DigiSchwein/monitoiring_pipeline/test_env/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# get frame from test clip
test_frame = get_frame_of_video(path_to_test_clip, 20)

# %%
inference_on_single_image(test_frame, filter_lying_pigs=False, prefix=None)

# %%
inference_on_single_image(test_frame, filter_lying_pigs=False, prefix=None, save_img=True)
# Out:
# Saving image to: /Users/jan-hendrikwitte/Documents/DigiSchwein/monitoiring_pipeline/pipeline_outputs/plots/test_plots/processed_20240320_100124.jpg
